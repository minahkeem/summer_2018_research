# %%
import numpy as np
import pickle

def load_file(file):
    with open(file, 'rb') as f:
        return pickle.load(f)
    
idx_to_word = load_file("idx_to_word.pkl")
word_to_idx = load_file("word_to_idx.pkl")
vectors = np.load("output.npy")

def get_word_vector(word):
    idx = word_to_idx[word]
    return vectors[idx]

def get_word_at_index(index):
    return idx_to_word[index]

# %%
vectors
# Out:
# array([[-0.02985769, -0.03923954, -0.0193511 , ..., -0.04687731,
#         -0.06903055, -0.05992738],
#        [-0.0058338 , -0.05957004, -0.03742093, ..., -0.05318371,
#         -0.02038277, -0.06202114],
#        [-0.00809794,  0.02141076, -0.03063158, ..., -0.00790764,
#         -0.07618432, -0.07131716],
#        ...,
#        [-0.00058425, -0.05786744, -0.0474753 , ..., -0.03131336,
#         -0.04294971, -0.06015962],
#        [ 0.01150776,  0.00129292, -0.04120871, ..., -0.03023674,
#         -0.06795908, -0.07554299],
#        [-0.03337324, -0.0394639 , -0.0612554 , ..., -0.04322901,
#         -0.04506031, -0.07519749]], dtype=float32)

# %%
idx_to_word
# Out:
# {0: 'sharing priors',
#  1: 'layer neural networks',
#  2: 'solving nonconvex',
#  3: 'unknown',
#  4: 'largely disjoint efforts',
#  5: 'targeting eeg',
#  6: 'apcg method',
#  7: 'entropy estimate',
#  8: 'extended lasso',
#  9: 'unbounded computational power',
#  10: 'methods come',
#  11: 'excluding logarithmic factors',
#  12: 'probabilistic manner',
#  13: 'image restoration',
#  14: 'cost models suffice',
#  15: 'transforms nuisance processes',
#  16: 'consider approximate policy',
#  17: 'obtain provable guarantees',
#  18: 'allowed level sets',
#  19: 'dbn structure learning',
#  20: 'dynamics predictor learns',
#  21: 'complex biological sample',
#  22: 'cell consists',
#  23: 'algorithm runs',
#  24: 'recent models',
#  25: 'linear copula projections',
#  26: 'assuming agents honest',
#  27: 'newton approximations',
#  28: 'low rank',
#  29: 'measure optimization',
#  30: 'two hidden layers',
#  31: 'human learning',
#  32: 'first study',
#  33: 'restricted matrix regression',
#  34: 'sectional data',
#  35: 'parsimonious statistical model',
#  36: 'develop new techniques',
#  37: 'input clips',
#  38: 'using attention',
#  39: 'domain adaptation process',
#  40: 'curvature bound',
#  41: 'require restrictive assumptions',
#  42: '3d shape',
#  43: 'sparsity promoting prior',
#  44: 'polynomial codes',
#  45: 'one function',
#  46: 'unknown correlations',
#  47: 'adjacent feature maps',
#  48: 'sparse linear regression',
#  49: 'biological sequence analysis',
#  50: 'learned via',
#  51: 'main sources',
#  52: 'main message',
#  53: 'produce unique estimates',
#  54: 'lehman difference network',
#  55: 'neighbor learning',
#  56: 'convergence characterization',
#  57: 'algorithms achieve',
#  58: 'popular models',
#  59: 'best model switches',
#  60: 'robust loss function',
#  61: 'natural notion',
#  62: 'unbounded number',
#  63: 'complicated sampler',
#  64: 'norm regularized problems',
#  65: 'variable level',
#  66: 'value prediction network',
#  67: 'current ldl methods',
#  68: 'various performance metrics',
#  69: 'neuron outputs',
#  70: 'natural image sequences',
#  71: 'squared norm ofincrements',
#  72: 'prior methods',
#  73: 'visual effect suffered',
#  74: 'hidden co',
#  75: 'dominant movement',
#  76: 'clustering via',
#  77: 'neural population approximates',
#  78: 'general technique',
#  79: 'unbounded cache model',
#  80: 'cortical dynamics',
#  81: 'reasonable assumptions',
#  82: 'driven learning',
#  83: 'simulator implemented',
#  84: 'recurrent coherent activity',
#  85: 'adjusting model parameters',
#  86: 'asymptotic analysis',
#  87: 'convex methods',
#  88: 'v1 neurons',
#  89: 'language processing',
#  90: 'placing emphasis',
#  91: 'ideal observer model',
#  92: 'team markov games',
#  93: 'suitable prior',
#  94: 'randomized gacv',
#  95: 'product units',
#  96: 'metric data',
#  97: 'geometric framework',
#  98: 'hierarchical feed',
#  99: 'machine learning algorithms',
#  100: 'profit maximizing subset',
#  101: 'convex analysis',
#  102: 'discover features sensitive',
#  103: 'univariate distributions',
#  104: 'narrow prior',
#  105: 'class generalizes',
#  106: 'encode invariances inherent',
#  107: 'samples without',
#  108: 'approximated kernel machines',
#  109: 'extreme uncertainty',
#  110: 'policy regret',
#  111: 'constrained practical applications',
#  112: 'biological control systems',
#  113: 'classical framework',
#  114: 'unseen domains',
#  115: 'projection space required',
#  116: 'select important features',
#  117: 'alexnet',
#  118: 'parametric representation',
#  119: 'robust pca captures',
#  120: 'smoothness classes allow',
#  121: 'based learning rules',
#  122: 'transferring features even',
#  123: 'empirical experiments',
#  124: 'person segmentation',
#  125: 'suitable utility function',
#  126: 'g ., tensorflow',
#  127: 'counterfactual fairness captures',
#  128: 'young duality theorem',
#  129: 'latent state given',
#  130: 'demonstrate using',
#  131: 'probability mass function',
#  132: 'samples scales',
#  133: 'much lower dependency',
#  134: 'optimality',
#  135: 'based transient classification',
#  136: 'physical systems',
#  137: 'strategic interactions form',
#  138: 'weighted majority vote',
#  139: 'nonparametric bayesian technique',
#  140: 'existing marginal',
#  141: 'gaussian copulas network',
#  142: 'convex quadratic program',
#  143: 'maximum labelwise accuracy',
#  144: 'subject budget',
#  145: 'unitary matrices',
#  146: 'step space',
#  147: 'priori }.',
#  148: 'natural setup',
#  149: '2 )$ variables',
#  150: 'underlying similarity measure',
#  151: 'two control parameters',
#  152: 'robust versions',
#  153: 'neural language modeling',
#  154: 'parameter learning',
#  155: 'dimensional neuroimaging data',
#  156: 'shot classification objective',
#  157: 'recurrent neural networks',
#  158: 'unbounded set',
#  159: 'robust adaptive control',
#  160: 'understanding feature construction',
#  161: 'remarkably brittle',
#  162: 'recent achievements',
#  163: 'fire neural model',
#  164: 'temporal architectures',
#  165: 'relevant elements',
#  166: 'induced matching',
#  167: 'norb datasets showing',
#  168: 'heuristic scheme',
#  169: 'distinct feature',
#  170: 'class ($\\ mathcal',
#  171: 'notable robustness',
#  172: 'many recent developments',
#  173: 'optimization problem involved',
#  174: 'integrated clustering',
#  175: 'sampling based',
#  176: 'approachis made',
#  177: 'mediated competitive learning',
#  178: 'possible object regions',
#  179: 'exemplars chosen',
#  180: 'noise input',
#  181: 'like convnets',
#  182: 'real nvp',
#  183: 'dense 3d shape',
#  184: 'embarrassingly parallel mcmc',
#  185: 'learning ensembles',
#  186: 'setting leads',
#  187: 'modeling relational data',
#  188: 'directly estimating',
#  189: 'many models',
#  190: 'image modeling',
#  191: 'approximation ratio',
#  192: 'probabilistic renderers ).',
#  193: 'estimated patterns',
#  194: 'positive semi',
#  195: 'moving objects',
#  196: 'statistical guarantees',
#  197: 'linear eigenproblem yields',
#  198: 'propagating label information',
#  199: 'rigorous analysis',
#  200: 'target prior',
#  201: 'demonstrated extensively',
#  202: 'modified policy iteration',
#  203: 'consider unsupervised estimation',
#  204: 'deep trees',
#  205: 'evaluate models learning',
#  206: 'exponential loss',
#  207: 'synthetic evaluation datasets',
#  208: 'generalized interdependent',
#  209: 'image search system',
#  210: 'convergent optimization algorithm',
#  211: 'highlight issues',
#  212: 'realistic multi',
#  213: 'causal effects',
#  214: 'aalen regression models',
#  215: 'competitive enough',
#  216: '2 f_i',
#  217: 'deep network architecture',
#  218: 'optimal control theory',
#  219: 'english translation task',
#  220: 'lrma models',
#  221: 'systematically',
#  222: 'warped trajectory models',
#  223: 'faster variational approximation',
#  224: 'three simulated datasets',
#  225: 'stoc 2015',
#  226: 'integrated brain networks',
#  227: 'spectral kernel learning',
#  228: '10 recognition dataset',
#  229: 'generative composite model',
#  230: 'supervised topic model',
#  231: 'application demands',
#  232: 'capturing stochastic',
#  233: 'empirical revenue',
#  234: 'cheap computer simulation',
#  235: 'level prediction accuracy',
#  236: 'finding informative positive',
#  237: 'sample scarcity',
#  238: 'variable amplitudes',
#  239: 'two probability densities',
#  240: 'learning agents',
#  241: 'hashing trick ).',
#  242: 'matrix adagrad based',
#  243: 'online variational inference',
#  244: 'topics may',
#  245: 'making high',
#  246: 'policy gradient researches',
#  247: 'produce competitive results',
#  248: 'combinatorial procedure based',
#  249: 'introduce latent attention',
#  250: 'temporal low',
#  251: 'study active learning',
#  252: 'various tasks',
#  253: 'precise bounding boxes',
#  254: 'recovery guarantee',
#  255: 'dependency',
#  256: 'variable scales',
#  257: 'fully bayesian framework',
#  258: 'excellent solution accuracy',
#  259: 'main source',
#  260: 'nonlinear combination rule',
#  261: 'cup task using',
#  262: 'level model outputs',
#  263: 'semantic modeling',
#  264: 'based bayesian optimization',
#  265: 'performing model selection',
#  266: 'shared structure',
#  267: 'learning visual features',
#  268: 'mcmc ).',
#  269: 'population states outperforms',
#  270: 'algorithmic progress',
#  271: 'dynamic programming algorithm',
#  272: 'high score close',
#  273: 'multiple supervised',
#  274: 'subject design',
#  275: 'using linear',
#  276: 'accurate approximation',
#  277: 'visual concepts',
#  278: 'multiple norms',
#  279: 'whole process',
#  280: 'high probability simultaneously',
#  281: 'scalable',
#  282: 'embedding dimension',
#  283: 'naturally produced',
#  284: 'distribution dependent regret',
#  285: 'improvements ."',
#  286: 'phonetic alignment',
#  287: 'auditory map',
#  288: 'experts code',
#  289: 'two objects',
#  290: 'temporal rf components',
#  291: 'local similarity',
#  292: 'bounds suggest',
#  293: 'hierarchical bayesian model',
#  294: 'shortcoming',
#  295: 'batch points simultaneously',
#  296: 'fair prediction',
#  297: 'training using low',
#  298: 'binomial distribution',
#  299: 'independent mathematical interest',
#  300: 'predictive policing',
#  301: 'obtain algorithms',
#  302: 'statistical pattern recognition',
#  303: 'minimizations',
#  304: 'hilbert space induced',
#  305: 'distilled policy',
#  306: 'three structures',
#  307: 'information feedback structure',
#  308: 'nonrandom',
#  309: 'technical applications',
#  310: 'optimal rule',
#  311: 'data demonstrate',
#  312: 'distributed systems',
#  313: 'highly scalable algorithm',
#  314: 'shot prediction games',
#  315: 'recurrent neocortical circuits',
#  316: 'learning classification',
#  317: 'dynamically modified based',
#  318: 'computational efficient',
#  319: 'readily generalized',
#  320: 'method confines application',
#  321: 'tensorized lstm',
#  322: 'several learning applications',
#  323: 'numberof classes',
#  324: 'learning method',
#  325: 'complex nonstationary kernels',
#  326: 'optimal algorithm',
#  327: 'model improves classification',
#  328: 'structure leads',
#  329: 'tight complexity bounds',
#  330: 'measure optimization tasks',
#  331: 'deformable part models',
#  332: 'actions incur costs',
#  333: 'salient image region',
#  334: 'sparse codes',
#  335: 'find designs',
#  336: 'scholkopf1998nonlinear }.',
#  337: 'proposed algorithms improve',
#  338: 'finite sampling effects',
#  339: 'system consists',
#  340: 'bounds showing',
#  341: 'horizon deterministic system',
#  342: 'concept class',
#  343: 'stochastic experts',
#  344: 'higher complexity',
#  345: 'hypergraph partitioning relies',
#  346: 'input image regions',
#  347: 'finally logistic regression',
#  348: 'static scene segmentation',
#  349: 'given classifiers',
#  350: 'illumination estimation results',
#  351: 'class',
#  352: 'require performance',
#  353: 'characterize data groups',
#  354: 'locality',
#  355: 'demonstrate improved robustness',
#  356: 'linear space',
#  357: 'critical points via',
#  358: 'data poisoning attack',
#  359: 'reconstructing patterns',
#  360: 'easily visualizable low',
#  361: 'true data',
#  362: 'mixing performance',
#  363: 'nonparametric statistics',
#  364: 'close theoretical connection',
#  365: 'combined neural networks',
#  366: 'model reduces',
#  367: 'simplified rules',
#  368: 'gan architectures',
#  369: 'attuned',
#  370: 'web search',
#  371: 'kernel hyperparameters',
#  372: 'interventional adaptations',
#  373: 'adversarial prediction',
#  374: 'spectral energy distribution',
#  375: 'segmentations',
#  376: 'several related tasks',
#  377: 'artperformance',
#  378: 'elastic basis pursuit',
#  379: 'misclassification probability',
#  380: 'introduce percentile measures',
#  381: 'undirected topic model',
#  382: 'transient signal detection',
#  383: 'independent measurements tend',
#  384: 'machine',
#  385: 'regressive models',
#  386: 'discriminative training',
#  387: 'suffix tree',
#  388: '27 ],',
#  389: 'model makes',
#  390: 'e )- factor',
#  391: 'distributions used',
#  392: 'measured fmri signals',
#  393: 'general bound matches',
#  394: 'cation loss function',
#  395: 'deterministic policies',
#  396: 'bayesian multiscale model',
#  397: 'differentiated product settings',
#  398: 'originally designed',
#  399: 'field algorithms',
#  400: 'balanced stimuli',
#  401: 'highest performancecompared',
#  402: 'parallelizable',
#  403: 'white gaussian noise',
#  404: 'error matrix',
#  405: 'discriminatively trained model',
#  406: 'high volatility',
#  407: 'attractive compromise',
#  408: 'markov state process',
#  409: 'nonparanormal belief propagation',
#  410: 'single neuron',
#  411: 'combinatorial item sets',
#  412: 'latent path',
#  413: 'temperature expansions',
#  414: 'novel hardness measure',
#  415: 'extracted control rules',
#  416: 'prove reconstruction bounds',
#  417: 'linear classifier',
#  418: 'influence measure',
#  419: 'mapped representation',
#  420: 'art similar approaches',
#  421: 'spatially localized',
#  422: 'spectral mixture density',
#  423: 'influence predictions',
#  424: 'optical flow energy',
#  425: 'gpb contours ).',
#  426: 'algorithm finds solutions',
#  427: 'competitive setting',
#  428: 'time data',
#  429: 'spatial features',
#  430: 'purely stochastic',
#  431: '20 \\%',
#  432: 'despot ), searches',
#  433: 'factor graphs',
#  434: 'produce samples',
#  435: 'rank decomposition',
#  436: 'state estimation based',
#  437: 'theoretical findings',
#  438: 'backward greedy algorithms',
#  439: 'based tests',
#  440: 'cluttered environments',
#  441: 'correction tasks',
#  442: 'tune feature extraction',
#  443: 'method also improves',
#  444: 'new networks',
#  445: 'coderank approach',
#  446: 'observation space given',
#  447: 'varying sizes',
#  448: 'correct labels',
#  449: 'data privacy',
#  450: 'penalties based',
#  451: 'approximately solving',
#  452: 'neural code contributes',
#  453: 'coordinate system matched',
#  454: 'improve complexity bounds',
#  455: 'faster subroutine',
#  456: 'function method',
#  457: 'bit marginal regression',
#  458: 'latter method lies',
#  459: 'enjoys error guarantees',
#  460: 'controlled parameters',
#  461: 'instrumental sampling distribution',
#  462: 'structure model fitting',
#  463: 'fifty thousand points',
#  464: 'optimal value function',
#  465: 'stimulus features within',
#  466: 'demonstrate theeffectiveness',
#  467: 'functions defined based',
#  468: 'online algorithm based',
#  469: 'thresholded affinity graph',
#  470: 'latent tree structures',
#  471: 'parametric components',
#  472: 'new hierarchical model',
#  473: 'action potential width',
#  474: 'body methods developed',
#  475: 'quantify performance',
#  476: 'riemannian samplers',
#  477: 'dynamic trees',
#  478: 'prediction network',
#  479: 'stored patterns',
#  480: 'reduced computational budget',
#  481: 'covariate shift adaptation',
#  482: 'parametric assumptions',
#  483: 'large code base',
#  484: 'cortical thickness measures',
#  485: 'social interactions',
#  486: 'monocular videos',
#  487: 'hill environments',
#  488: 'local role bindings',
#  489: 'several applications',
#  490: 'standard recurrent networks',
#  491: 'common baseline approaches',
#  492: 'distributed unsupervised learning',
#  493: 'lower bounds',
#  494: 'various data sets',
#  495: '2 )$ rate',
#  496: 'tensor biclustering',
#  497: '2014 tac',
#  498: 'gaining attention',
#  499: 'laplacian spectrum',
#  500: 'factored trust region',
#  501: 'present graphsage',
#  502: 'coalescent clustering',
#  503: 'tractable initial distribution',
#  504: 'multiple long short',
#  505: 'time nonlinear complexity',
#  506: 'cost function',
#  507: 'exact recovery',
#  508: 'based fairness allows',
#  509: 'network events',
#  510: 'diverse organisms',
#  511: 'image database',
#  512: 'different approaches',
#  513: 'previous message',
#  514: 'complicated objective functions',
#  515: 'linearly superimposed within',
#  516: 'observed color',
#  517: 'nervous system',
#  518: 'kernel hyperalignment',
#  519: 'bayesian',
#  520: 'membrane',
#  521: 'learn overcomplete features',
#  522: 'significantly improving upon',
#  523: 'stochastic point processes',
#  524: 'density',
#  525: 'embedded',
#  526: 'empirical optimization',
#  527: 'fuse probability distributions',
#  528: 'mapping estimation',
#  529: 'removed',
#  530: 'method turns',
#  531: 'supported',
#  532: 'relationship across channels',
#  533: 'change model',
#  534: 'numerical evidence supports',
#  535: 'represents probability distributions',
#  536: 'optimal prediction based',
#  537: 'error estimation',
#  538: 'several size constraints',
#  539: 'unsupervised learning framework',
#  540: 'underlying true labels',
#  541: 'binomial spiking',
#  542: 'rnn dynamics',
#  543: 'order algorithms',
#  544: 'invalid marginal estimates',
#  545: 'different network states',
#  546: 'three large corpora',
#  547: 'image labeling problem',
#  548: 'classic problems',
#  549: 'overlapping variables',
#  550: '$- sparse problems',
#  551: 'coverage risk generalizes',
#  552: 'common space',
#  553: 'exploits visual attentions',
#  554: 'forthcoming errors',
#  555: 'sampled time series',
#  556: 'model infers',
#  557: 'recovers true subspaces',
#  558: 'previously known algorithms',
#  559: 'compute robust confidences',
#  560: 'global property',
#  561: 'significantly higher accuracy',
#  562: 'making experiment manipulating',
#  563: 'chinese restaurant process',
#  564: 'easily kernelized',
#  565: 'generation linear programming',
#  566: 'knowledge learned',
#  567: 'tight regret bound',
#  568: 'polar response variables',
#  569: 'arm bandit framework',
#  570: 'wise sequential manner',
#  571: 'approximate solution',
#  572: 'investigate different techniques',
#  573: 'videos frames',
#  574: 'sublstm units',
#  575: 'scalable models',
#  576: 'crowdsourcing queries decreases',
#  577: 'extraction',
#  578: 'aggressive smoothing',
#  579: 'diminishing return property',
#  580: 'colored gaussian noise',
#  581: 'counterfactual learning',
#  582: 'approximate bayesian computation',
#  583: 'minimizing misclassification error',
#  584: 'decomposition methods',
#  585: 'considered modeling',
#  586: 'algorithm recovers',
#  587: 'special expert',
#  588: 'perform multitask learning',
#  589: 'triggered stimulus ensemble',
#  590: 'approximate inference algorithm',
#  591: 'realizing',
#  592: 'cue integration',
#  593: 'magnitude less memory',
#  594: 'quantitative analysis shows',
#  595: 'improving information density',
#  596: 'dimensional function',
#  597: 'face recognition using',
#  598: 'theoretic problem',
#  599: 'large speedup',
#  600: 'efficient parallel algorithm',
#  601: 'convex calibrated surrogates',
#  602: 'allow movement along',
#  603: 'search forest',
#  604: 'neural activity patterns',
#  605: 'synthesize novel views',
#  606: 'initial value problem',
#  607: 'sensitive active sensing',
#  608: 'benchmark database',
#  609: 'spike train data',
#  610: 'exemplar',
#  611: 'related tasks',
#  612: 'geq 2 $,',
#  613: 'theoretical upper bound',
#  614: 'slow progression',
#  615: 'minimax analysis',
#  616: 'invariant stel models',
#  617: 'hand tuning',
#  618: 'nonlinear eigenvector',
#  619: 'k $- dimensional',
#  620: 'kernel feature space',
#  621: 'design parameter',
#  622: 'cell account',
#  623: 'guarantees based',
#  624: 'provide practical guidelines',
#  625: 'algorithmically',
#  626: 'prediction error exceeds',
#  627: 'term depression',
#  628: 'natural physical interpretation',
#  629: 'fast em',
#  630: 'outperform previous approaches',
#  631: 'estimation strategies',
#  632: 'anticipatory control',
#  633: 'iterative algorithm based',
#  634: 'feature expectations',
#  635: 'cognitive patterns',
#  636: 'universal algorithm',
#  637: 'point gi',
#  638: '$- concave distributions',
#  639: '2d parsing',
#  640: 'error bars',
#  641: 'geq 2',
#  642: 'bidirectional retrieval',
#  643: 'actions enable',
#  644: 'subspace addition',
#  645: 'submodular set cover',
#  646: 'cursor motion using',
#  647: 'overall prediction accuracy',
#  648: 'neural network recognizer',
#  649: 'matrix approximations',
#  650: 'model learns',
#  651: 'novel parallelisation scheme',
#  652: 'flight data',
#  653: 'method beats',
#  654: 'unbounded environments',
#  655: 'efficiently learnable',
#  656: 'proposed algorithm yields',
#  657: 'linear factor analysis',
#  658: 'memory limitations',
#  659: 'sparse domain',
#  660: 'fixed tree',
#  661: 'nyi classifiers',
#  662: 'incorporating efficient inference',
#  663: 'highly heterogeneous degrees',
#  664: 'organic molecules',
#  665: 'means algorithm',
#  666: 'task learning problem',
#  667: 'novel sparse formulation',
#  668: 'complex tasks',
#  669: 'network scale',
#  670: 'reasonable assumption',
#  671: 'general theoretical guarantee',
#  672: 'computational operations',
#  673: 'vertex identification',
#  674: 'stage relaxation scheme',
#  675: 'adversarial noise',
#  676: 'convenient probabilistic model',
#  677: 'templates',
#  678: 'highly anisotropic dimensions',
#  679: 'backtracking operator',
#  680: 'timing problem faced',
#  681: 'secondary movie dataset',
#  682: 'simple application',
#  683: 'even robust',
#  684: 'computationally expensive algorithms',
#  685: 'transferring',
#  686: 'employ non',
#  687: 'population response',
#  688: 'stochastic data',
#  689: 'novel formulation based',
#  690: 'mathematically equivalent',
#  691: 'largely non',
#  692: 'elliptically symmetric',
#  693: 'gans ).',
#  694: 'finding eulerian circuits',
#  695: 'assigning class labels',
#  696: 'sample complexity compared',
#  697: 'fully continuous systems',
#  698: 'proposal combines constraint',
#  699: 'methods remain hard',
#  700: 'predictive index',
#  701: 'algorithm switches actions',
#  702: 'known problem',
#  703: 'predicting verbal',
#  704: 'search engine receives',
#  705: 'boltzmann perceptron network',
#  706: 'agent following',
#  707: 'fixed confidence algorithms',
#  708: 'task reduce',
#  709: 'local discriminative features',
#  710: 'shallow',
#  711: 'hierarchical probabilistic modeling',
#  712: 'gaze driven model',
#  713: 'sometimes show improvements',
#  714: 'sparse pca provides',
#  715: 'either purely local',
#  716: 'ambient space );',
#  717: 'spectral gap',
#  718: 'better performances',
#  719: 'statistical tasks',
#  720: 'iterative adversarial inference',
#  721: 'pedestrian images',
#  722: 'find stationary points',
#  723: 'large scale settings',
#  724: 'generalized nystr',
#  725: 'iid processes',
#  726: 'random survival forests',
#  727: 'general submodular minimization',
#  728: 'convex optimization problem',
#  729: 'return point estimates',
#  730: 'fully decentralized policies',
#  731: 'simulated annealing method',
#  732: 'connectionist symbol manipulator',
#  733: 'slower convergence',
#  734: 'policy changes',
#  735: 'instead directly estimate',
#  736: 'explicit stochastic model',
#  737: 'dimensional instantaneous correlations',
#  738: 'main computational burden',
#  739: 'implicit systems',
#  740: 'perfectly smooth',
#  741: 'convergent unlearning algorithm',
#  742: 'local intrinsic dimension',
#  743: 'group lar algorithm',
#  744: 'consider learning',
#  745: 'group lasso penalty',
#  746: 'neural basis',
#  747: 'theoretical side',
#  748: 'ensure disentangled semantics',
#  749: 'called density',
#  750: 'converge much faster',
#  751: 'dimensional policies',
#  752: 'disjoint subsets',
#  753: 'poissonian feature affects',
#  754: 'predicted segmentation',
#  755: 'structure hidden',
#  756: 'robustifying',
#  757: 'component mixture',
#  758: 'coding scheme',
#  759: 'arithmetic circuits',
#  760: 'experimental analysis',
#  761: 'segmentation network',
#  762: 'varies spatially',
#  763: 'explicit search statistics',
#  764: 'achieve competitive results',
#  765: 'recently proposed methods',
#  766: '3 })- approximation',
#  767: 'graph clustering',
#  768: 'effective extension',
#  769: 'margin halfspaces',
#  770: 'perform machine learning',
#  771: 'generalizes better',
#  772: 'sparse plus low',
#  773: 'approach substantially outperform',
#  774: 'structures schatten norms',
#  775: 'modeling hetereoskedastic non',
#  776: 'pass decoding',
#  777: 'gan leverages',
#  778: 'many recognition problems',
#  779: 'digital vlsi hardware',
#  780: 'policy iteratively',
#  781: 'statistical relational models',
#  782: 'combining flexible models',
#  783: 'fourier domain',
#  784: 'introspective classification',
#  785: 'features needed',
#  786: 'gaussian processes via',
#  787: 'improved discriminative analysis',
#  788: 'faster inference',
#  789: 'hoc application',
#  790: 'traditional methods',
#  791: 'choose experts',
#  792: 'evidence lower bound',
#  793: 'times competitive',
#  794: 'scales well',
#  795: 'algorithm applied',
#  796: 'rich matching patterns',
#  797: 'random vector',
#  798: 'demonstrate empirical improvements',
#  799: 'puting weighted v',
#  800: 'inferred internal representations',
#  801: 'algorithm recently proposed',
#  802: 'recall analysis abounds',
#  803: 'efficiently extract features',
#  804: 'functional neuroimaging data',
#  805: 'model factor',
#  806: 'unbalanced classification',
#  807: 'reduce memory consumption',
#  808: 'tensor networks',
#  809: 'structured approximations',
#  810: 'proposed learning process',
#  811: 'robotic applications',
#  812: 'network analytics',
#  813: 'various domains demonstrate',
#  814: 'joint distribution matching',
#  815: 'randomized approach converges',
#  816: 'preserving predictive power',
#  817: 'major computational bottleneck',
#  818: 'spectral data onto',
#  819: 'statistical concentration',
#  820: 'update variables used',
#  821: 'absolute scale',
#  822: 'online display advertising',
#  823: 'typically estimated',
#  824: 'high variance',
#  825: 'also estimate',
#  826: 'much larger contexts',
#  827: 'safetynets detects',
#  828: 'basic algorithms',
#  829: 'somewhat novel',
#  830: 'multiply labeled bag',
#  831: 'original signal domain',
#  832: '2 )})$ regret',
#  833: 'connectionist architectures',
#  834: 'noise proportional',
#  835: 'layer neural network',
#  836: 'optimize computationally',
#  837: 'scoring applications',
#  838: 'previously established algorithm',
#  839: 'local proximity',
#  840: 'scratch approach',
#  841: 'partially observable mdps',
#  842: 'stationary policy',
#  843: 'proposal using',
#  844: 'stochastic differential equations',
#  845: 'linear classification',
#  846: 'low regret',
#  847: 'speech recognition models',
#  848: 'online gradient boosting',
#  849: 'gram matrices',
#  850: 'model architecture',
#  851: 'make training faster',
#  852: 'learning sparse perceptrons',
#  853: 'human motions',
#  854: 'softmax representation',
#  855: 'efficient posterior inference',
#  856: 'learn meaningful features',
#  857: 'deterministic computation graph',
#  858: 'discriminant function',
#  859: 'incremental clustering methods',
#  860: 'neuromorphic approach',
#  861: 'multiagent reinforcement learning',
#  862: 'white functionals',
#  863: 'big data challenge',
#  864: 'experimental demonstrations',
#  865: 'fundamental objective',
#  866: 'named entity recognition',
#  867: 'empirical successes',
#  868: 'decision images',
#  869: 'gain novel insights',
#  870: 'generate data',
#  871: 'small corruption noise',
#  872: 'global structures',
#  873: 'active state',
#  874: 'unknown latent dimensionality',
#  875: 'guided mcmc',
#  876: 'based optimization algorithms',
#  877: 'context vectors',
#  878: 'bilinear',
#  879: 'selected features',
#  880: 'first bounds',
#  881: 'based likelihood calculation',
#  882: 'rsc scene network',
#  883: 'compute marginal likelihood',
#  884: 'first marginalizes',
#  885: 'sparse space',
#  886: 'maximum likelihood algorithm',
#  887: 'simple feature',
#  888: 'statistical learning perspective',
#  889: 'policy search method',
#  890: 'computationally suitable',
#  891: 'sample covariance eigenspectrum',
#  892: 'selector variables',
#  893: 'dimensional large',
#  894: 'perfect matchings',
#  895: 'prior assumption',
#  896: 'population ecology',
#  897: 'triangle fixing algorithms',
#  898: 'proof technique',
#  899: 'underlying process',
#  900: 'adaptive skills',
#  901: 'imposes local constancy',
#  902: 'nearly isometric embedding',
#  903: 'biased machine learning',
#  904: 'single point',
#  905: 'regularized objective functions',
#  906: 'perform survey sampling',
#  907: 'perform bayesian inference',
#  908: 'expensive inference step',
#  909: 'existing mogp methods',
#  910: 'structures --',
#  911: 'reducing dimensionality',
#  912: 'scale beyond',
#  913: 'models violate dale',
#  914: 'mab problem',
#  915: 'computational theory',
#  916: 'limited clustering algorithms',
#  917: 'individual synaptic connections',
#  918: 'single exemplars',
#  919: 'region methods',
#  920: 'least squares regression',
#  921: 'symnets',
#  922: 'bethe approximation corresponding',
#  923: 'adversarial outliers',
#  924: 'longitudinal data extracted',
#  925: 'earlier models used',
#  926: 'sigmoidal neural networks',
#  927: 'general purpose algorithm',
#  928: 'clustering dna sequences',
#  929: 'markovian rbf covariance',
#  930: 'blind signal separation',
#  931: 'pixel images',
#  932: 'discrete choice data',
#  933: 'random weight networks',
#  934: 'view features',
#  935: 'demonstrate bilinear svms',
#  936: 'best estimator designed',
#  937: 'balancing premature fine',
#  938: 'synthetic neural ic',
#  939: 'optimal controller',
#  940: 'technique enables us',
#  941: 'telemetry collection leads',
#  942: 'region proposal algorithms',
#  943: 'also favor unsupervised',
#  944: 'markov boundary theorem',
#  945: 'neural firing rate',
#  946: 'constructing stochastic gradients',
#  947: 'dimensional real vector',
#  948: 'image processing architecture',
#  949: 'trivial probability distributions',
#  950: 'many nonparametric regressors',
#  951: 'novel families',
#  952: 'tighter upper bound',
#  953: 'advice refinement',
#  954: 'recently demonstrated',
#  955: 'geometry invariant',
#  956: 'smoothly trade',
#  957: 'gradient estimates',
#  958: 'parallel coordinates',
#  959: 'open question remains',
#  960: 'ring array processor',
#  961: 'new analytic expressions',
#  962: 'arbitrary vectors',
#  963: 'lexicographic decision making',
#  964: 'hardware verification task',
#  965: 'model capacity',
#  966: 'realistic system',
#  967: 'made mathematical contributions',
#  968: 'algorithm obtains',
#  969: 'regularized learning algorithms',
#  970: 'order smoothness term',
#  971: 'original input based',
#  972: 'central node',
#  973: 'development data',
#  974: '67 normal controls',
#  975: 'explosive behavior',
#  976: 'classify accurately',
#  977: 'working memory',
#  978: 'contour motions',
#  979: 'temporal filters',
#  980: 'important k coordinates',
#  981: 'three problems',
#  982: 'reasonable generative model',
#  983: 'structures characterized',
#  984: 'linear non',
#  985: 'case bound',
#  986: 'visual attention system',
#  987: 'whose scoring functions',
#  988: 'free algorithm',
#  989: 'efficient internal representations',
#  990: 'node based',
#  991: 'robot interaction',
#  992: 'sequential hypothesis testing',
#  993: 'sequentially obtained ones',
#  994: 'markov games',
#  995: 'inspired models',
#  996: 'novel computational approach',
#  997: 'general margin',
#  998: 'entire data',
#  999: 'sensor networks',
#  ...}

# %%
word_to_idx
# Out:
# {'learning monotonic transformations': 14104,
#  'flexible transfer learning': 30004,
#  'convex': 25052,
#  'natural situations': 36921,
#  'finding metrics': 1676,
#  'perception encodes': 24141,
#  'matching tasks demonstrates': 29798,
#  'algorithm draws': 36980,
#  'visual contour integration': 34389,
#  'talairach space': 28298,
#  'present applications': 36088,
#  'modern biomedical research': 7180,
#  'count objects': 18919,
#  'noisy labels problem': 9518,
#  'single gamma process': 26422,
#  'search oracle models': 12469,
#  '25': 30040,
#  'pac maximum selection': 16887,
#  'numerous attempts': 3502,
#  'model scales': 39609,
#  'art random projection': 9827,
#  'connectivity based bcis': 11189,
#  'linear plants': 17493,
#  'denoised': 9973,
#  'scale ica': 24367,
#  'neurally': 6487,
#  'excellent approximation': 33198,
#  'algorithm along': 37987,
#  'local image representations': 28670,
#  'approach requires': 25514,
#  'empty convex': 37572,
#  'data stream summaries': 6795,
#  'nonlinear recursive structure': 15115,
#  'many important problems': 22673,
#  'bucy smoothing procedure': 7937,
#  'predicted segmentation': 754,
#  'wise rigid motion': 8592,
#  'medium moving items': 42446,
#  'classical hypothesis': 19124,
#  'algorithm clarans': 42605,
#  'variance reduction problem': 12607,
#  'modeling effort focuses': 14202,
#  'object proposal methods': 34408,
#  'linear hinge loss': 36592,
#  'spatiotemporal responses': 34425,
#  'first demonstration': 19905,
#  'advantages besides adaptiveness': 39597,
#  'motivated behavior': 38232,
#  'mcmc often suffers': 40464,
#  'one based': 25940,
#  'effective split': 35525,
#  'algorithms outperform': 44444,
#  'whereas distributed estimation': 34967,
#  'additional variables': 14711,
#  'based sound segmentation': 29053,
#  'recommender system affects': 18283,
#  'object classification': 16567,
#  'unfactored pomdps': 19853,
#  'large scale non': 43868,
#  'gaze orientation': 43196,
#  'first quantitative analysis': 28085,
#  'phase retrieval problems': 11746,
#  'audio context': 14963,
#  'predictive models': 16983,
#  'sequence clustering': 17606,
#  'double exponential priors': 37721,
#  'particle approach': 27869,
#  'dimension representations': 8773,
#  'efficient dynamic message': 12230,
#  'inspect networks': 44514,
#  'general lsbm': 28080,
#  'static risk measures': 34696,
#  'simple feature': 887,
#  'face images': 37017,
#  'human action recognition': 1124,
#  'receptive field formation': 2801,
#  'emphasizing': 9502,
#  'boundary detection algorithms': 9346,
#  'blind source separation': 34246,
#  'truly infinite depm': 21466,
#  'handwritten digit recognition': 8623,
#  'dendritic architectures': 6771,
#  'unknown costs': 43787,
#  'n vectors': 29950,
#  'axial locomotion': 9115,
#  'stable processs': 19986,
#  'kernel flexibly': 11645,
#  'process 360': 5724,
#  'intractable setting': 18662,
#  'tracking problem': 44164,
#  'towards property': 10104,
#  'probabilities determining': 43664,
#  'recurrent interactions within': 34137,
#  'expert human feedback': 3509,
#  'new acquisition function': 23745,
#  'constructing task': 34370,
#  'parallel implementation': 38897,
#  'robust observation model': 21620,
#  'capturing latent dynamics': 33327,
#  'varying control policy': 11159,
#  'approximate value function': 40159,
#  'analysis exploits': 41473,
#  'adaptive decoder optimize': 25893,
#  'optimization scheme': 19289,
#  'hogwild methods': 25283,
#  'relative reduction': 45281,
#  'interpreting predictions': 45349,
#  'dataset increases': 36664,
#  'local cues': 37574,
#  'rational metareasoning': 43259,
#  'spiking neuron models': 27595,
#  'partitioning process': 28656,
#  'based mainly': 21834,
#  'concrete proposals': 44647,
#  'neural embedding': 18126,
#  'scale data settings': 11988,
#  'first layer responses': 37302,
#  'approach feasible': 27072,
#  'first algorithm combines': 5835,
#  'handwriting recognition': 7121,
#  'exponential complexity': 7407,
#  'hybrid linear': 32646,
#  'kernel features': 7704,
#  'brain slice images': 35567,
#  'local auto': 6760,
#  'like methods': 33621,
#  'training strategy': 11020,
#  'data': 7523,
#  'many domains': 7451,
#  'linear statistical analysis': 38538,
#  'capturing clustering structure': 17450,
#  'regularization parameter': 20852,
#  'strong prior': 14068,
#  'computational problems': 36748,
#  'electronic games': 20668,
#  'recurrent regime': 16813,
#  'one prior': 8103,
#  'neurodynamics': 21675,
#  'probing motion perception': 29591,
#  'unsupervised training algorithm': 37391,
#  'time regularization': 36716,
#  'novel net': 6467,
#  'spike train history': 13860,
#  'adaptive hedge': 31160,
#  'sensory processing': 10175,
#  'underlying features related': 34557,
#  'confidence style algorithm': 4862,
#  'graphical model optimization': 2059,
#  'ensure disentangled semantics': 748,
#  'c data': 10579,
#  'distributed submodular cover': 5217,
#  'alternate model': 5991,
#  'theoretical evidence': 30169,
#  'high computational cost': 3410,
#  'learnable visual markers': 1846,
#  'distributions corresponding': 31162,
#  'partial observations': 44596,
#  'hmms learned': 41032,
#  'valid mcmc algorithm': 17588,
#  'structure matching': 21300,
#  'available source': 2901,
#  'many behavioral experiments': 21858,
#  'task would consist': 28367,
#  'making events': 4662,
#  'direct applications': 16663,
#  'label learning problems': 4705,
#  'current inference': 17396,
#  'visual interaction network': 12089,
#  'feature selection problem': 10447,
#  'efficient sampling': 42738,
#  'initial models': 12475,
#  'adversarial prediction': 373,
#  'using local invariances': 41766,
#  'identifying image': 42263,
#  'densenet': 25277,
#  'natural signal': 43608,
#  'input variable': 36159,
#  'learning tasks jointly': 11222,
#  'truly bayesian treatment': 25465,
#  'label crowdsourcing': 18008,
#  'matrix geometric means': 44383,
#  'intermediate results': 6756,
#  'unknown matrix': 19674,
#  'language modelling': 9323,
#  'two new classes': 34085,
#  'trees grows exponentially': 1647,
#  'using lifting rules': 6005,
#  'sdp approach unscalable': 44702,
#  'real transduction problems': 6440,
#  'shared random effects': 39409,
#  'operator variational inference': 2576,
#  'communication remains': 8792,
#  'linear wavelet transform': 13420,
#  'parameter learning problem': 9067,
#  'powerful regression technique': 18321,
#  'determinant program': 19681,
#  'medical researchers': 29992,
#  'channel equalization problems': 22393,
#  'single boosting stage': 21822,
#  'periodicity extraction': 32353,
#  'term physiological activity': 37055,
#  'crowdsourcing systems suggest': 7352,
#  'one setting': 44756,
#  'group overlaps': 15726,
#  'graph cuts': 12846,
#  'rakhlin2013': 1914,
#  'tensor biclustering': 496,
#  'harmonet': 2634,
#  'general technique': 78,
#  'special actions': 16812,
#  'approximate maximization': 41305,
#  '`` positiveness': 8298,
#  'saddle point problem': 2975,
#  'database using': 14714,
#  'policy parameterization': 40625,
#  'loop improvement': 42012,
#  'layer problems': 43986,
#  'labeled text': 7345,
#  '2016 ).': 20363,
#  'current methods': 24789,
#  'certain pathological case': 35815,
#  'optimal control laws': 13102,
#  'visual model': 30167,
#  'incorporateprior information': 10266,
#  '26 competitive baselines': 11684,
#  'provide bounds': 9119,
#  'missing labels': 11299,
#  'problem number 60': 19519,
#  'complex decision problem': 33636,
#  'value functions': 5268,
#  'response variables': 39902,
#  'sparse coding model': 40568,
#  'memorize': 43600,
#  'pooling schemes': 24736,
#  'reconstructed networks': 44129,
#  'additional convex constraints': 6660,
#  'complete classifier': 7273,
#  'different clustering criteria': 27016,
#  'noise effect': 43854,
#  'visual qa': 11843,
#  'functional architecture': 9262,
#  'provide theoretical motivation': 1298,
#  'inference scales linearly': 9712,
#  'bayesian compression': 1819,
#  'fundamental limitations': 2902,
#  'scalable inference': 31294,
#  'supermodular functions': 4043,
#  'encoder publicly available': 11589,
#  'new metric': 2514,
#  'low probabilities': 10696,
#  'modern data': 3686,
#  'cluster size': 25800,
#  'adversarial objectives': 13599,
#  'single network': 20555,
#  'using variance reduction': 4872,
#  '17m training samples': 24382,
#  'pass decoder polishes': 20009,
#  'standard setting': 43515,
#  'enhance local search': 21251,
#  'exact map estimates': 7807,
#  'diagonal matrix approximation': 42532,
#  'algorithmic implications': 10413,
#  'latter handles': 19319,
#  'stage model includes': 37966,
#  'present two algorithms': 2651,
#  'approach addresses': 32759,
#  'strategy makes': 17254,
#  'computation networks analogous': 12478,
#  'v1 membrane potential': 42075,
#  'rademacher complexity': 35884,
#  'neural hardware': 42822,
#  'moderately sized graphs': 4208,
#  'memory trace': 32044,
#  'incorporating domain knowledge': 13586,
#  'primary setting': 34764,
#  'low rank approximation': 12912,
#  'optimize partition functions': 8378,
#  'scale update rule': 14238,
#  'graph matching algorithm': 29962,
#  'sample efficiency': 30007,
#  'pool resource appropriation': 30178,
#  'rational parametrizations': 5265,
#  'positive peak': 45310,
#  'data covariance matrix': 22049,
#  'neuromorphic vlsi system': 35134,
#  'external fields': 19316,
#  'output vector': 21250,
#  'forward filtering': 37011,
#  'sample efficiently': 13876,
#  'bayesian optimization setting': 40306,
#  'rank truncation': 4033,
#  'desired bound': 19477,
#  'stronger generalisation': 10363,
#  'function approximation': 2582,
#  'original deep models': 27617,
#  'applying stochastic approximation': 10451,
#  'ground truth segmentations': 35912,
#  'local sentiment flow': 3812,
#  'summary representations': 36231,
#  'pcs estimation upon': 39815,
#  'regularization functionals based': 41930,
#  'category size information': 32359,
#  'drive simulations': 7037,
#  'soslasso compared': 40587,
#  'linear models ),': 19696,
#  'providing features': 27680,
#  'bounded distributions': 44362,
#  'genetics': 14470,
#  'consider tractable representations': 34031,
#  'present new methods': 19358,
#  'simple alternating optimization': 32489,
#  'researchers': 10989,
#  'many practical situations': 21188,
#  'variational bound': 24336,
#  'ground labeling': 12354,
#  'higher dimensional operator': 29611,
#  'modulated renewal processes': 36503,
#  'optimal margin hyperplane': 45423,
#  'challenge problem': 38198,
#  'heuristic evaluation function': 24797,
#  'incremental q': 45010,
#  'environment setting': 14739,
#  'minimization algorithms consist': 24142,
#  'covariate shift adaptation': 481,
#  'present algorithms': 9522,
#  'dependent tensor factorization': 3304,
#  'e ., functions': 42227,
#  'world applications compared': 34849,
#  'identifying unknown parameters': 7278,
#  'observations given': 42292,
#  'robust interference suppression': 26727,
#  'given budget': 33839,
#  'horizontal connections': 14613,
#  'new computational paradigms': 18399,
#  'latent representations': 3387,
#  'mwis problem': 19082,
#  'new model outperforms': 38853,
#  'state systems': 3605,
#  'exogenous state variable': 14648,
#  'random walk approach': 12287,
#  'piecewise linear': 15588,
#  'original graph': 16333,
#  'neural nets become': 3306,
#  '1 classification problems': 6052,
#  'corresponding distribution': 32861,
#  'correct labels': 448,
#  'planar ultrametrics': 10440,
#  'data distributions': 33375,
#  'single subset': 19577,
#  'following estimation problem': 22475,
#  'bayesian active learning': 44770,
#  'navigation': 21966,
#  'matrix normal prior': 34691,
#  'human labeling': 32676,
#  'connected subgraphs': 3037,
#  'designated semantics': 3350,
#  'haptic input device': 41778,
#  'crowdsourcing services': 41202,
#  'step forward looking': 19130,
#  'task relationships based': 15509,
#  'baseline policy': 44531,
#  'discriminative training': 386,
#  'transient optimization phase': 35807,
#  'binary belief network': 21475,
#  'internal appearance': 27949,
#  'discrete factor analysis': 40363,
#  'strong theoretical guarantees': 36439,
#  'greedy learning': 43264,
#  'simple prior': 3830,
#  'specific models': 18618,
#  'semidefinite programs': 36300,
#  'mathematical equivalence': 39349,
#  'algorithms referred': 7205,
#  'practice draw samples': 26608,
#  'dependent nonparametric trees': 18102,
#  'based alternative': 15748,
#  'describe new algorithms': 5821,
#  'sequence generation': 22840,
#  'like structure amenable': 39606,
#  'metric learning method': 19380,
#  'art semi': 9555,
#  'time stochastic process': 1614,
#  'carefully studying': 26946,
#  'probability': 16395,
#  'spiking activity across': 12531,
#  'nonlinear data modeling': 17900,
#  'video recognition tasks': 16620,
#  'output dependency structures': 2488,
#  'torrent algorithm': 9430,
#  'updates asynchronously': 5125,
#  'variational framework': 26213,
#  'motion slowness': 3962,
#  'latent space recovery': 7218,
#  'probabilistic semantics make': 15934,
#  'heterogeneous compute systems': 14329,
#  'monotonic feature abstraction': 26187,
#  'fraction': 12620,
#  'revealing simple': 30061,
#  'trace regression': 16765,
#  'contextual processing': 40548,
#  'classification parameters': 1412,
#  'localized rademacher': 22191,
#  'image similarity': 30648,
#  'original input features': 33581,
#  'coexpression': 13567,
#  'learn low': 28089,
#  'stem': 19473,
#  'temporal windows': 24622,
#  'programming time': 5922,
#  'joint factor analysis': 18493,
#  'variance terms': 12181,
#  'original intractable model': 28124,
#  'mnist database': 20187,
#  'poisoned data': 6020,
#  'classical conditioning': 27230,
#  'neither effective': 17253,
#  'positive advantage': 8616,
#  'large ensemble': 20087,
#  'box reduction': 8962,
#  'underly neural representations': 5985,
#  'correct response': 32714,
#  'detectors invariant': 1482,
#  'approach exploits': 31834,
#  'data driven estimation': 32074,
#  'natural actor': 21557,
#  'one sample u': 19540,
#  'unbounded state spaces': 6694,
#  'armed case': 38390,
#  'robot experiments': 33794,
#  'ladder variational autoencoder': 27658,
#  'minimizing estimation error': 10392,
#  'investigate active learning': 13281,
#  'processing experiment': 16612,
#  'sparse pca method': 14251,
#  'high probability provided': 3688,
#  'conquer matrix factorization': 32215,
#  'random atomic measures': 14392,
#  'selective prediction': 15346,
#  'highlight issues': 211,
#  'inferring causal effects': 17364,
#  'adaptive gradient methods': 41053,
#  'stochastic process': 22171,
#  'supports': 2666,
#  'experimental datasets': 40573,
#  'general black': 40104,
#  'vector $\\ bx': 34030,
#  'novel formulation provides': 6352,
#  'natural images results': 15929,
#  'infinite linear programming': 14070,
#  'connected problems': 42629,
#  'regression function': 12766,
#  'one shortcoming': 41091,
#  'linear systems': 44463,
#  'assigned based': 37632,
#  'neural emulation': 36236,
#  'automated theorem proving': 3222,
#  'use feature congestion': 42319,
#  'parameter vectors': 40007,
#  'minimax estimation': 39969,
#  'optimal local minima': 19354,
#  'submodular knapsack constraints': 31982,
#  'find effective partitions': 9044,
#  'statistical debugging': 2660,
#  'algorithms thereby benefit': 27400,
#  'dirichlet mixture': 34601,
#  'show bounds': 22296,
#  'efficient bayesian inference': 5050,
#  'visual interaction networks': 6773,
#  'four real': 17872,
#  'efficient optimization problem': 30325,
#  'information theoretic approach': 40801,
#  'instructional policy specifies': 27520,
#  'two potential functions': 15022,
#  'dynamic probabilistic model': 37798,
#  'parameterized unitary matrices': 33494,
#  'two concrete models': 21703,
#  'simple formalization': 34636,
#  'constrained sampling': 8216,
#  'de finetti representation': 39283,
#  'linear data': 17514,
#  'auxiliary function values': 38134,
#  'optimal regret algorithm': 25676,
#  'many computational models': 20611,
#  'distributed version': 7624,
#  'sequential manner': 41110,
#  'novel noisy': 38317,
#  'recurrent architectures': 28474,
#  'decomposition trees': 24149,
#  'highly variable neurons': 35686,
#  'local correlation': 31742,
#  'ranking algorithm': 28552,
#  '}$, thus implementing': 17922,
#  'constraint discovery algorithms': 37149,
#  'method outperforms': 26373,
#  'two graphs': 6178,
#  'allows envisioning using': 9280,
#  'evolving learnable languages': 9409,
#  'wise measurements': 4128,
#  'linear gaussian': 18724,
#  'supplementary motor area': 37700,
#  'multiple scales': 8926,
#  'eeg connectivity patterns': 18984,
#  'statistical network modeling': 30345,
#  'constructing feature maps': 41351,
#  'batch size': 3256,
#  'formulation allows us': 29681,
#  'halfspace': 10425,
#  'auditory signal': 5401,
#  'balancing premature fine': 937,
#  'maximal margin labeling': 12253,
#  'backward simulation': 23461,
#  'sparse convolutional coding': 18587,
#  'probability computed based': 24558,
#  'n objects': 14421,
#  'smooth expression': 23617,
#  'deep networks': 29300,
#  'necessarily bounded': 10028,
#  'crafted representations used': 31288,
#  'dimensional sparse recovery': 5190,
#  'first approximate': 23546,
#  'regression affect': 40139,
#  'attentional bayes': 11937,
#  'language learning': 14466,
#  'high probability': 3915,
#  'diverse domains': 26929,
#  'batch rpca methods': 19302,
#  'outperforms existing methods': 25807,
#  'denoising dynamics': 28038,
#  'style algorithm': 21027,
#  'policy constraints comes': 40920,
#  'special distributions': 2882,
#  'low dimensionality': 37307,
#  'empirically verifying': 44712,
#  'boosting classifier cascades': 2765,
#  'generalizing contextual bandits': 39163,
#  'optimization constraints': 3551,
#  'recurrent feature': 32491,
#  'natural framework': 8626,
#  'training graph': 23130,
#  'statistics derived': 19006,
#  'bound tree': 3501,
#  'quite effective': 30770,
#  'functionally desirable': 16823,
#  'learn optimal controllers': 23519,
#  'generalized performance metrics': 12517,
#  'adaptive skills': 900,
#  'effective characterization': 1016,
#  'linear dynamical state': 7454,
#  'bt data': 8042,
#  'parse trees': 39440,
#  'sided error': 12664,
#  'compressive sampling': 4046,
#  'alternating minimization scheme': 9429,
#  'unimportant connections': 5567,
#  'stage progressive encoders': 12109,
#  'resulting optimization problems': 24709,
#  'rank restriction': 36155,
#  'supervised problems': 23807,
#  'sparse nonnegative deconvolution': 25967,
#  'spatially localized': 421,
#  'domain transfer': 35217,
#  'empirically validate': 7079,
#  'observation graph': 27157,
#  'unknown graph': 7166,
#  'help matrix recovery': 7043,
#  'visualization': 7534,
#  'model shrinkage': 20808,
#  'connectionist technique': 29790,
#  'weak connection': 20794,
#  'online procedure': 5431,
#  'approximate likelihood computations': 6725,
#  'practical level': 32564,
#  'poisson regression models': 18411,
#  'corrects empirical frequencies': 34485,
#  'uses trajectory optimization': 10449,
#  'user systems': 37852,
#  'chip compensation': 18557,
#  'discriminant power': 33995,
#  'mixing weights': 3184,
#  'sparse network': 24512,
#  'whole regularization term': 30471,
#  'face recognition dataset': 38462,
#  'confidence frank': 10784,
#  'contextual learning model': 12290,
#  'ml objective function': 1861,
#  '5 imagenet classification': 23712,
#  'unlabeled conditional entropy': 2639,
#  'high coherence': 16493,
#  'dimensional generalizations': 13630,
#  'acquiring labels': 29405,
#  'sample confidence intervals': 10986,
#  'almost local': 4792,
#  'linearized variant': 44656,
#  'algorithmic consequences': 38587,
#  'general likelihood models': 7527,
#  'degenerate functions': 24422,
#  'wise independence': 21065,
#  'continuous function': 12921,
#  'driven simulation': 27276,
#  'ipomdp utility': 39613,
#  'adaptive spatial filters': 29508,
#  'tracking moving distributions': 14664,
#  'optimal regression function': 30707,
#  'spike clustering': 41337,
#  'popular measure': 18269,
#  'pose model solves': 29183,
#  'therefore demonstrates': 25403,
#  'allow one path': 29960,
#  'subsequent computation': 7502,
#  'highly corrupted entries': 16771,
#  'optimalpredictions involves': 39533,
#  'aggregate sufficient statistics': 31607,
#  'artificial goals': 33597,
#  'otherwise intractable problems': 5058,
#  'pure strategy epsilon': 20548,
#  'metric learning loss': 3589,
#  'several independent regions': 30373,
#  'code': 38097,
#  'design match kernels': 19031,
#  'words document representations': 6992,
#  'enables flexible handling': 5276,
#  'database contains': 32740,
#  'convex program': 41447,
#  'paper investigates connections': 20428,
#  'manifold learning': 5346,
#  'bayesian regret discounted': 10349,
#  'continuous attributes': 18510,
#  'action $\\ gamma': 14185,
#  'song learning': 38722,
#  'stochastic combinatorial multi': 28199,
#  'parametric density estimation': 13319,
#  'many samples': 17242,
#  'past observations': 33357,
#  'theoretical upper': 26232,
#  'hmm speech recognition': 27830,
#  'several objective functions': 38782,
#  '2 log': 5011,
#  'monograph': 9275,
#  'matching models show': 2694,
#  'dimensionality reduction using': 37682,
#  'modeling sets': 12967,
#  'partition function computation': 23200,
#  'images bases': 20342,
#  'requiring expert experience': 33847,
#  'lower dimensional mapping': 2010,
#  'strong pattern': 26544,
#  'monaural speech separation': 17046,
#  'consider estimating': 20021,
#  'based optimization': 41680,
#  'lower bound asymptotically': 8822,
#  'better exploit parallelism': 15416,
#  'obtain bayesian estimates': 8655,
#  'vc dimension methods': 20316,
#  'using thirteen datasets': 11195,
#  'learned pruner': 43679,
#  'corresponding lower bound': 11478,
#  'segmentation tree': 12392,
#  'likelihood ), handling': 12868,
#  'standard robust mdp': 31248,
#  'policy space': 9987,
#  'hypergraphs via graphs': 9021,
#  'unbounded layers': 30972,
#  'topics may': 244,
#  'decoded outputs': 31325,
#  'limited knowledge': 39509,
#  'estimating predictive uncertainty': 45042,
#  'critical applications': 38172,
#  'adaptive control scheme': 35186,
#  'predictive performance': 3165,
#  'tree depths grow': 29786,
#  'entire regularization path': 7728,
#  'prior corresponds': 30677,
#  'step schemes': 14639,
#  'bayesian interpretation': 17206,
#  'histogram rule error': 4214,
#  'indicating latent variables': 35427,
#  'treatment effects using': 16525,
#  'environment insteadof observations': 7470,
#  'efficient kernel learning': 13123,
#  'allow labelers': 43253,
#  'popular adam optimization': 38750,
#  'norm regularization instead': 22206,
#  'pose classes': 26241,
#  'improves predictive performance': 31604,
#  'statistically learnable': 25801,
#  'meaningful document representations': 43197,
#  'expert': 7036,
#  'multi item auctions': 14606,
#  'mmd gan': 20454,
#  'online dictionary': 40374,
#  'cause substantial reorganization': 41450,
#  'critical points via': 357,
#  'compressive measurements correspond': 28171,
#  'rademacher complexity ).': 38367,
#  'allow sum': 2179,
#  'proposed algorithms surpasses': 42359,
#  'typical image components': 5917,
#  'certain subpopulations': 41211,
#  'based interpretation': 33883,
#  'pca setting': 17306,
#  'active primal': 35383,
#  'safe screening rules': 9478,
#  'semantic segmentation': 6268,
#  'health record data': 15379,
#  'adaptive numerical format': 24252,
#  'bounded moments': 6835,
#  'bilingual data': 10984,
#  'scale climate dataset': 26554,
#  'second term': 19566,
#  'memristive material': 35703,
#  'bits per point': 14092,
#  'measures information gain': 16051,
#  'computational modelling': 41831,
#  'computational modulus': 35981,
#  'matching models': 3627,
#  'learning model': 24197,
#  'fmri data': 14626,
#  'weighted set': 2175,
#  'kernel boosting algorithms': 38227,
#  'past data': 14700,
#  'strong convexity modulus': 14404,
#  'image labels': 26785,
#  'novel hypothesis': 4399,
#  'adaptively selecting stimuli': 4457,
#  'overall algorithm': 24594,
#  'um2l': 30946,
#  'markovian environments': 39424,
#  'measure remains': 20542,
#  'rapidly sampling': 40538,
#  'online inference': 9572,
#  'undesirable effects': 16111,
#  'stochastic ratio matching': 23398,
#  'approximate algorithm': 45261,
#  'short term memories': 16185,
#  'best sampling': 9117,
#  'dirichlet': 43372,
#  'multiple objects': 34676,
#  'neighbor classifier': 33335,
#  'subclass': 14607,
#  '`` topics ).': 1692,
#  'classical ddp': 44080,
#  'angular variables': 10400,
#  'highest ventral area': 37507,
#  'computational behavior': 7408,
#  'generally provide': 41912,
#  'based clustering algorithm': 28456,
#  'image search': 27129,
#  'weighted majority votes': 45234,
#  'model guarantees consistency': 13419,
#  'many applications due': 25871,
#  'fully exploiting': 32726,
#  'annealing technique': 37563,
#  'connectionist approaches': 25836,
#  'learning error analysis': 1522,
#  'contours': 40730,
#  'repeated structure': 16322,
#  'dimensional setting': 33140,
#  'route information hierarchically': 19315,
#  'result requires assumptions': 28224,
#  'posterior predictive inference': 37877,
#  'probabilistic methods': 7791,
#  'hippocampal neurons': 3766,
#  'observations': 11151,
#  'cases superior performance': 15343,
#  'unconstrained domains': 35012,
#  'single units': 4841,
#  'scale factors': 10771,
#  'population neural data': 13105,
#  'memory linear': 27158,
#  'enormous parameter space': 42534,
#  'unbounded': 6207,
#  'shared across data': 10660,
#  'white noise': 42643,
#  'universal low': 42847,
#  'stochastic online approaches': 20407,
#  '2 )$ time': 36383,
#  'contain elements': 13212,
#  'dimensional latent vector': 31235,
#  'determinantal point processes': 6225,
#  'projection kernel': 29289,
#  'individual treatment effects': 36627,
#  'importance sampling perspective': 6817,
#  'machine learning perspective': 25857,
#  'dependent model': 20881,
#  'neural analog diffusion': 10438,
#  'neural binding': 40708,
#  'previous models suffer': 20917,
#  'still retaining guarantees': 7019,
#  'better clustering': 33130,
#  'network topology': 11835,
#  'input features': 24593,
#  'factorization machine': 36201,
#  'univariate marginal distributions': 29138,
#  'interactive view': 4250,
#  'uniformly convex': 3956,
#  'considerable effect': 15473,
#  'given dynamics models': 37072,
#  'approximation tasks': 38200,
#  'weak prediction computed': 13234,
#  'process models': 37521,
#  'simple weight decay': 6985,
#  'smooth structure': 8224,
#  'randomized rounding': 16197,
#  'sensory evidence': 33890,
#  'cooperative strategy': 33087,
#  'sized data sets': 8668,
#  'scale datasets': 34231,
#  'standard supervised methods': 16218,
#  'strong loss bounds': 5374,
#  'randomized variants': 17770,
#  'poisson ),': 22387,
#  'boltzmann distribution': 2524,
#  'dps based': 3653,
#  'node label information': 3567,
#  'method requires': 45265,
#  'belief distribution': 23870,
#  'learning rate proportional': 8099,
#  'hypothesize object locations': 3714,
#  'aggregating features': 28972,
#  'alternating direction': 35086,
#  'also robust': 35658,
#  'distribution level': 44829,
#  'highly impractical': 11392,
#  'competitive results': 40333,
#  'cup task using': 261,
#  'policy improves within': 1499,
#  'order logical rules': 3118,
#  'label tree': 24297,
#  'essential requirement': 9187,
#  'measurement process': 28120,
#  'practical optimization routine': 29204,
#  'also bound': 18053,
#  'approximate joint diagonalization': 13418,
#  'product computation': 30201,
#  'factor nmf': 23467,
#  'point instant': 40665,
#  'finite mixtures': 23122,
#  'relaxation error analysis': 16264,
#  'kernel version': 17213,
#  'learning pomdp models': 11163,
#  'defined statistic': 29516,
#  'algorithmic improvements': 32928,
#  'proposed methods': 24223,
#  'model enables us': 15466,
#  'hyperoctahedral groups': 29328,
#  'generation process': 40283,
#  'randomized learning': 42378,
#  'support vector machines': 17983,
#  'computational bottleneck': 12855,
#  'overall network activity': 33094,
#  'bad critical points': 22612,
#  'allows later classifiers': 19148,
#  'bounded relu networks': 35796,
#  'estimation amounts': 29673,
#  'matrix approximation': 10700,
#  'drifting distribution': 40678,
#  'efficient high': 43504,
#  'active portfolio': 25970,
#  'core inference step': 21857,
#  'every possible class': 38631,
#  'image motion': 26767,
#  'graphical model inference': 5090,
#  'integrated': 34638,
#  'represent 3d spaces': 23292,
#  'day techniques': 20633,
#  'quick approximation': 15318,
#  'target marginals': 15778,
#  'conditioned problems': 37245,
#  'minimum risk functions': 42491,
#  'mixture identification': 44220,
#  '2d convolution': 8348,
#  'use data': 1706,
#  'absolutely continuous distribution': 35092,
#  'fast classification rates': 33324,
#  'robust influence maximization': 21881,
#  'neuron model': 26029,
#  'distributions efficiently': 19368,
#  'lowest': 14619,
#  'localist network': 32795,
#  'converge slowly': 3741,
#  'observation leads': 29663,
#  'conjugate hierarchical model': 23206,
#  'infinite state bayes': 39317,
#  'ising model': 41478,
#  'quadratic function subject': 14599,
#  'bayesian networks designed': 34801,
#  'promising technique': 29038,
#  'facebookresearch': 14529,
#  'achievable scheme': 36197,
#  'injecting noise': 38921,
#  'noise reduction methods': 18651,
#  'explicit stochastic model': 736,
#  'iteratively learn': 17815,
#  'target classes may': 18076,
#  'nonlinear classification': 40075,
#  'towards social robots': 43512,
#  'many motor skills': 13050,
#  'jointly models': 43578,
#  'covariance matrices': 26920,
#  'computer vision tasks': 40962,
#  'neural networks augmented': 16380,
#  'art nac algorithm': 23844,
#  'adaptive polynomial expansions': 42760,
#  'response modeling': 29432,
#  'methods depends critically': 41367,
#  'convergent unlearning algorithm': 741,
#  'unit recordings': 44236,
#  'conditional independence testing': 6632,
#  'sparse markov structure': 35853,
#  'informative visualization': 1728,
#  'several techniques': 21321,
#  'partition function ).': 43323,
#  'fastest open': 8737,
#  'problem lies': 15402,
#  'structure regularization': 15771,
#  'typical data': 38977,
#  'learning sparse polynomials': 4241,
#  'convex regularization': 35307,
#  'tensorizing neural networks': 18918,
#  'scale results': 25564,
#  'recognition templates': 32224,
#  'parallel rounding procedures': 35705,
#  'problem': 31403,
#  'kronecker product structure': 42849,
#  'central problem': 21787,
#  'various optimization procedures': 28845,
#  'computational challenge faced': 39932,
#  'much broader class': 12044,
#  'tensor multilinear rank': 24839,
#  'hence effectively resolve': 27627,
#  'generalization study': 44311,
#  'balanced excitation': 38785,
#  'robust estimator': 20738,
#  'armed bandit framework': 28175,
#  'histogram density estimates': 15846,
#  'simple experts': 20291,
#  'achieve comparable performance': 2385,
#  'generalized hamming distance': 19400,
#  'barrett wam robot': 16139,
#  'sift features': 18103,
#  'gallery image bank': 14268,
#  'unknown true labels': 12613,
#  'respective settings': 24931,
#  'general purpose optimizers': 14291,
#  'structure gives us': 37392,
#  'lasso risk': 34802,
#  'instrumental sampling distribution': 461,
#  'stable sampling process': 26567,
#  'grouped norms': 3515,
#  'e approximation guarantee': 22798,
#  'large speedups': 30168,
#  '3d motion segmentation': 33202,
#  'dynamic samplers': 3744,
#  'sample prediction': 11347,
#  'active': 34328,
#  'allows optimal discrimination': 44522,
#  'effective interval': 1798,
#  'clustered structure': 15875,
#  'input space': 41048,
#  'scales benchmarks': 7088,
#  'edge labels': 4996,
#  'poisson distributed node': 41394,
#  'sensitive boosting algorithm': 11332,
#  'transductive learning theory': 2989,
#  'making applications': 20762,
#  'process eigenspectrum': 17706,
#  'genomic sequence analysis': 17835,
#  'allowing continual learning': 27933,
#  'specified indicator functions': 8186,
#  'ranking measures': 5068,
#  'class visualization': 13190,
#  'controlled': 36405,
#  'machine': 384,
#  'scale learning': 14687,
#  'modeling high': 18228,
#  'sound network': 24100,
#  'generative gaussian graph': 16749,
#  'electronic implementation': 4359,
#  'solver features': 34139,
#  'projected gradient algorithms': 40041,
#  'three problems': 981,
#  'visual area v1': 25587,
#  'order smoothness compared': 17217,
#  'tight empirically across': 13162,
#  'low textured regions': 3033,
#  'information diffusion kernels': 2342,
#  'asymptotically optimal regularization': 8680,
#  'optimal statistical solution': 29243,
#  'recently proposed algorithms': 43302,
#  'interpolation error': 23865,
#  'inherently interactive': 23311,
#  'scalable influence estimation': 21629,
#  'salient image region': 333,
#  'dictionary representations': 21577,
#  'error sign': 41746,
#  '55 million observations': 14936,
#  'poisson link': 31848,
#  'highly incomplete': 27404,
#  'termed boostmetric': 18442,
#  'robust problem': 32624,
#  ...}

# %%
from scipy.cluster.vq import kmeans2

# %%
km = kmeans2(vectors, 30, iter=25)

# %%
words = []

for i in range(len(vectors)):
    if vectors[i] in km[0]:
        words.append(get_word_at_index(i))
        
words
# Out:
# ['given model',
#  'likelihood terms need',
#  'kernelized version',
#  'particular distributions',
#  'tractable aggregation',
#  'genomic sequence analysis',
#  'form tighter bounds',
#  'implicit metric spaces',
#  'rademacher complexities',
#  'recent design',
#  'empirically verifying',
#  'tackle nonsmooth',
#  'mode estimation']

# %%
km[0]
# Out:
# array([[-0.01120191, -0.0135988 , -0.03626807, ..., -0.04667561,
#         -0.04127087, -0.0700739 ],
#        [-0.00658421, -0.03381037, -0.03812243, ..., -0.01622671,
#         -0.03997023, -0.03461964],
#        [ 0.0064937 , -0.02490102, -0.03834748, ..., -0.02256488,
#         -0.07598568, -0.04546002],
#        ...,
#        [-0.0166932 , -0.03061913, -0.04167364, ..., -0.02399887,
#         -0.02608895, -0.05251006],
#        [ 0.00027969, -0.00051671, -0.02910781, ..., -0.02948768,
#         -0.02899347, -0.05866459],
#        [ 0.02487311,  0.04015868, -0.04608824, ...,  0.01881651,
#         -0.08632889, -0.06493115]], dtype=float32)

# %%
import math

def euc_distance(centroid, vec):
    val = 0
    for i in range(len(centroid)):
        val += math.pow(centroid[i]-vec[i], 2)
    return math.sqrt(val)

# %%
def cos_similarity(centroid, vec):
    top = 0
    for i in range(len(centroid)):
        top += centroid[i]*vec[i]
    bottom1 = 0
    for e in centroid:
        bottom1 += math.pow(e, 2)
    bottom2 = 0
    for e in vec:
        bottom2 += math.pow(e, 2)
    return top/(bottom1*bottom2)

# %%
clusters = []

for i in range(len(km[1])):
    clusters.append({
        'cluster': km[1][i],
        'keyword': idx_to_word[i],
        'euc_distance': euc_distance(km[0][km[1][i]], vectors[i]),
        'cos_similarity': cos_similarity(km[0][km[1][i]], vectors[i])
    })

clusters
# Out:
# [{'cluster': 9,
#   'cos_similarity': 1.243229900955704,
#   'euc_distance': 0.6799743641516682,
#   'keyword': 'sharing priors'},
#  {'cluster': 27,
#   'cos_similarity': 1.1382539904530344,
#   'euc_distance': 0.4066224491552771,
#   'keyword': 'layer neural networks'},
#  {'cluster': 3,
#   'cos_similarity': 1.077206775653366,
#   'euc_distance': 0.5424483790860379,
#   'keyword': 'solving nonconvex'},
#  {'cluster': 26,
#   'cos_similarity': 1.0024547651959406,
#   'euc_distance': 0.723367113922304,
#   'keyword': 'unknown'},
#  {'cluster': 8,
#   'cos_similarity': 1.0828208678971727,
#   'euc_distance': 0.6398383091346004,
#   'keyword': 'largely disjoint efforts'},
#  {'cluster': 28,
#   'cos_similarity': 1.0407526915259884,
#   'euc_distance': 0.6524782371500798,
#   'keyword': 'targeting eeg'},
#  {'cluster': 19,
#   'cos_similarity': 1.172238332113973,
#   'euc_distance': 0.5274207338152221,
#   'keyword': 'apcg method'},
#  {'cluster': 24,
#   'cos_similarity': 0.8485048699969868,
#   'euc_distance': 0.7423386275900694,
#   'keyword': 'entropy estimate'},
#  {'cluster': 25,
#   'cos_similarity': 0.9993681593338883,
#   'euc_distance': 0.7502031355720183,
#   'keyword': 'extended lasso'},
#  {'cluster': 27,
#   'cos_similarity': 1.061240889618845,
#   'euc_distance': 0.5158037041208438,
#   'keyword': 'unbounded computational power'},
#  {'cluster': 19,
#   'cos_similarity': 1.1305010730026266,
#   'euc_distance': 0.5683209839157769,
#   'keyword': 'methods come'},
#  {'cluster': 3,
#   'cos_similarity': 0.9120885898053266,
#   'euc_distance': 0.7043720360694542,
#   'keyword': 'excluding logarithmic factors'},
#  {'cluster': 22,
#   'cos_similarity': 1.1818906733925658,
#   'euc_distance': 0.5262324182436291,
#   'keyword': 'probabilistic manner'},
#  {'cluster': 25,
#   'cos_similarity': 0.7915063914971987,
#   'euc_distance': 0.8630104918268089,
#   'keyword': 'image restoration'},
#  {'cluster': 16,
#   'cos_similarity': 0.9591496220866841,
#   'euc_distance': 0.6861035253516621,
#   'keyword': 'cost models suffice'},
#  {'cluster': 5,
#   'cos_similarity': 0.9870623872927714,
#   'euc_distance': 0.6284357212539524,
#   'keyword': 'transforms nuisance processes'},
#  {'cluster': 4,
#   'cos_similarity': 0.8973299016935193,
#   'euc_distance': 0.7418209347006781,
#   'keyword': 'consider approximate policy'},
#  {'cluster': 9,
#   'cos_similarity': 1.017173183974933,
#   'euc_distance': 0.7911315645903726,
#   'keyword': 'obtain provable guarantees'},
#  {'cluster': 14,
#   'cos_similarity': 0.9886189997390474,
#   'euc_distance': 0.804363707693668,
#   'keyword': 'allowed level sets'},
#  {'cluster': 18,
#   'cos_similarity': 1.1020492408087903,
#   'euc_distance': 0.5645703042875607,
#   'keyword': 'dbn structure learning'},
#  {'cluster': 18,
#   'cos_similarity': 1.0026124895932524,
#   'euc_distance': 0.6567032844998324,
#   'keyword': 'dynamics predictor learns'},
#  {'cluster': 6,
#   'cos_similarity': 1.0394435477014126,
#   'euc_distance': 0.6658251149250255,
#   'keyword': 'complex biological sample'},
#  {'cluster': 28,
#   'cos_similarity': 0.8857360773616605,
#   'euc_distance': 0.7683446024020317,
#   'keyword': 'cell consists'},
#  {'cluster': 21,
#   'cos_similarity': 1.02698626417217,
#   'euc_distance': 0.4546796411923627,
#   'keyword': 'algorithm runs'},
#  {'cluster': 16,
#   'cos_similarity': 1.0226685721501203,
#   'euc_distance': 0.6304916609883232,
#   'keyword': 'recent models'},
#  {'cluster': 0,
#   'cos_similarity': 1.088273905047945,
#   'euc_distance': 0.5672860758040987,
#   'keyword': 'linear copula projections'},
#  {'cluster': 9,
#   'cos_similarity': 0.9419234664425024,
#   'euc_distance': 0.824816991683571,
#   'keyword': 'assuming agents honest'},
#  {'cluster': 0,
#   'cos_similarity': 0.9409610245769469,
#   'euc_distance': 0.7011718126803986,
#   'keyword': 'newton approximations'},
#  {'cluster': 14,
#   'cos_similarity': 1.0572874262386924,
#   'euc_distance': 0.7729113817372013,
#   'keyword': 'low rank'},
#  {'cluster': 5,
#   'cos_similarity': 0.993441558144901,
#   'euc_distance': 0.6220986685406708,
#   'keyword': 'measure optimization'},
#  {'cluster': 25,
#   'cos_similarity': 1.0048578473238292,
#   'euc_distance': 0.7469929869226594,
#   'keyword': 'two hidden layers'},
#  {'cluster': 18,
#   'cos_similarity': 1.1249672705858929,
#   'euc_distance': 0.5411158052726156,
#   'keyword': 'human learning'},
#  {'cluster': 18,
#   'cos_similarity': 0.7932890311096495,
#   'euc_distance': 0.81738803295167,
#   'keyword': 'first study'},
#  {'cluster': 24,
#   'cos_similarity': 0.981867708447942,
#   'euc_distance': 0.6158511835576447,
#   'keyword': 'restricted matrix regression'},
#  {'cluster': 11,
#   'cos_similarity': 1.0907494030382072,
#   'euc_distance': 0.5142149269337581,
#   'keyword': 'sectional data'},
#  {'cluster': 4,
#   'cos_similarity': 1.1094110953696794,
#   'euc_distance': 0.5570124031330481,
#   'keyword': 'parsimonious statistical model'},
#  {'cluster': 19,
#   'cos_similarity': 0.8353658123100727,
#   'euc_distance': 0.7999345147654335,
#   'keyword': 'develop new techniques'},
#  {'cluster': 12,
#   'cos_similarity': 0.8690030913456318,
#   'euc_distance': 0.8224013864946838,
#   'keyword': 'input clips'},
#  {'cluster': 26,
#   'cos_similarity': 1.069428849082781,
#   'euc_distance': 0.6780217552917656,
#   'keyword': 'using attention'},
#  {'cluster': 24,
#   'cos_similarity': 0.8841500512041003,
#   'euc_distance': 0.7107387753515985,
#   'keyword': 'domain adaptation process'},
#  {'cluster': 0,
#   'cos_similarity': 1.0146331908385078,
#   'euc_distance': 0.63773787302744,
#   'keyword': 'curvature bound'},
#  {'cluster': 8,
#   'cos_similarity': 1.0169504836604035,
#   'euc_distance': 0.6900314721267301,
#   'keyword': 'require restrictive assumptions'},
#  {'cluster': 0,
#   'cos_similarity': 0.9380992176970838,
#   'euc_distance': 0.7035205126783128,
#   'keyword': '3d shape'},
#  {'cluster': 17,
#   'cos_similarity': 0.9095178043985737,
#   'euc_distance': 0.7697975392793447,
#   'keyword': 'sparsity promoting prior'},
#  {'cluster': 3,
#   'cos_similarity': 0.8974910411739365,
#   'euc_distance': 0.7169298203548541,
#   'keyword': 'polynomial codes'},
#  {'cluster': 2,
#   'cos_similarity': 1.1801652558710227,
#   'euc_distance': 0.5544231009377122,
#   'keyword': 'one function'},
#  {'cluster': 22,
#   'cos_similarity': 1.1159436213505964,
#   'euc_distance': 0.58894063975668,
#   'keyword': 'unknown correlations'},
#  {'cluster': 12,
#   'cos_similarity': 1.0525968256987899,
#   'euc_distance': 0.7178525971026559,
#   'keyword': 'adjacent feature maps'},
#  {'cluster': 4,
#   'cos_similarity': 1.0989489728335076,
#   'euc_distance': 0.567541981076062,
#   'keyword': 'sparse linear regression'},
#  {'cluster': 24,
#   'cos_similarity': 0.9655750922705783,
#   'euc_distance': 0.632661302380877,
#   'keyword': 'biological sequence analysis'},
#  {'cluster': 26,
#   'cos_similarity': 1.0165225477057072,
#   'euc_distance': 0.7140813331989893,
#   'keyword': 'learned via'},
#  {'cluster': 8,
#   'cos_similarity': 0.7127321651740197,
#   'euc_distance': 0.885678207624111,
#   'keyword': 'main sources'},
#  {'cluster': 26,
#   'cos_similarity': 0.8536550817523065,
#   'euc_distance': 0.8151345563470797,
#   'keyword': 'main message'},
#  {'cluster': 5,
#   'cos_similarity': 0.8965088632144185,
#   'euc_distance': 0.7123373036418534,
#   'keyword': 'produce unique estimates'},
#  {'cluster': 15,
#   'cos_similarity': 0.999562818661731,
#   'euc_distance': 0.6947906899634522,
#   'keyword': 'lehman difference network'},
#  {'cluster': 18,
#   'cos_similarity': 0.8068313304822834,
#   'euc_distance': 0.807959852854405,
#   'keyword': 'neighbor learning'},
#  {'cluster': 24,
#   'cos_similarity': 0.879897402821978,
#   'euc_distance': 0.7145822214717397,
#   'keyword': 'convergence characterization'},
#  {'cluster': 21,
#   'cos_similarity': 1.0406361407385072,
#   'euc_distance': 0.43149348062034953,
#   'keyword': 'algorithms achieve'},
#  {'cluster': 16,
#   'cos_similarity': 0.9696016328238624,
#   'euc_distance': 0.6772665824217494,
#   'keyword': 'popular models'},
#  {'cluster': 16,
#   'cos_similarity': 0.6410083486572608,
#   'euc_distance': 0.9151282081594346,
#   'keyword': 'best model switches'},
#  {'cluster': 23,
#   'cos_similarity': 1.0233822074750019,
#   'euc_distance': 0.6506662451217435,
#   'keyword': 'robust loss function'},
#  {'cluster': 8,
#   'cos_similarity': 1.0068731346447266,
#   'euc_distance': 0.6973918649883506,
#   'keyword': 'natural notion'},
#  {'cluster': 3,
#   'cos_similarity': 0.90007159685599,
#   'euc_distance': 0.714725913239918,
#   'keyword': 'unbounded number'},
#  {'cluster': 6,
#   'cos_similarity': 0.9910376864700149,
#   'euc_distance': 0.7023356326210028,
#   'keyword': 'complicated sampler'},
#  {'cluster': 26,
#   'cos_similarity': 0.841846184277449,
#   'euc_distance': 0.8219786417546078,
#   'keyword': 'norm regularized problems'},
#  {'cluster': 23,
#   'cos_similarity': 1.063206986218652,
#   'euc_distance': 0.6160274504397637,
#   'keyword': 'variable level'},
#  {'cluster': 13,
#   'cos_similarity': 0.983256299614396,
#   'euc_distance': 0.6572626480321755,
#   'keyword': 'value prediction network'},
#  {'cluster': 28,
#   'cos_similarity': 0.8550277353773331,
#   'euc_distance': 0.7892815045276084,
#   'keyword': 'current ldl methods'},
#  {'cluster': 10,
#   'cos_similarity': 1.175305620583226,
#   'euc_distance': 0.6181583852684174,
#   'keyword': 'various performance metrics'},
#  {'cluster': 28,
#   'cos_similarity': 1.2046900687766766,
#   'euc_distance': 0.5016258908351531,
#   'keyword': 'neuron outputs'},
#  {'cluster': 25,
#   'cos_similarity': 1.144289574478395,
#   'euc_distance': 0.6602472856789543,
#   'keyword': 'natural image sequences'},
#  {'cluster': 20,
#   'cos_similarity': 0.7461339685472326,
#   'euc_distance': 0.9062798758011275,
#   'keyword': 'squared norm ofincrements'},
#  {'cluster': 19,
#   'cos_similarity': 1.0876226734435068,
#   'euc_distance': 0.6074785060503362,
#   'keyword': 'prior methods'},
#  {'cluster': 25,
#   'cos_similarity': 0.9212666893821001,
#   'euc_distance': 0.7944698286992309,
#   'keyword': 'visual effect suffered'},
#  {'cluster': 20,
#   'cos_similarity': 1.0549585103207064,
#   'euc_distance': 0.7727757413485298,
#   'keyword': 'hidden co'},
#  {'cluster': 14,
#   'cos_similarity': 0.9520048877254961,
#   'euc_distance': 0.8206415243335022,
#   'keyword': 'dominant movement'},
#  {'cluster': 5,
#   'cos_similarity': 1.1361815756028504,
#   'euc_distance': 0.45791214371312744,
#   'keyword': 'clustering via'},
#  {'cluster': 28,
#   'cos_similarity': 1.0706465034119912,
#   'euc_distance': 0.6276790901440588,
#   'keyword': 'neural population approximates'},
#  {'cluster': 19,
#   'cos_similarity': 1.0059500141023276,
#   'euc_distance': 0.6758162076167591,
#   'keyword': 'general technique'},
#  {'cluster': 5,
#   'cos_similarity': 1.030816748396844,
#   'euc_distance': 0.5835891326988579,
#   'keyword': 'unbounded cache model'},
#  {'cluster': 28,
#   'cos_similarity': 1.037104852535702,
#   'euc_distance': 0.6554401645743747,
#   'keyword': 'cortical dynamics'},
#  {'cluster': 8,
#   'cos_similarity': 1.054810762171103,
#   'euc_distance': 0.6616474704141191,
#   'keyword': 'reasonable assumptions'},
#  {'cluster': 18,
#   'cos_similarity': 1.0785439455679715,
#   'euc_distance': 0.5876542523471803,
#   'keyword': 'driven learning'},
#  {'cluster': 23,
#   'cos_similarity': 0.8903099943023844,
#   'euc_distance': 0.754968956832948,
#   'keyword': 'simulator implemented'},
#  {'cluster': 28,
#   'cos_similarity': 1.0472023996475799,
#   'euc_distance': 0.6472081200560543,
#   'keyword': 'recurrent coherent activity'},
#  {'cluster': 23,
#   'cos_similarity': 1.1245866547236494,
#   'euc_distance': 0.5584488340637002,
#   'keyword': 'adjusting model parameters'},
#  {'cluster': 24,
#   'cos_similarity': 1.0920168619721027,
#   'euc_distance': 0.48721858246305383,
#   'keyword': 'asymptotic analysis'},
#  {'cluster': 0,
#   'cos_similarity': 1.096311886375273,
#   'euc_distance': 0.5590590492625082,
#   'keyword': 'convex methods'},
#  {'cluster': 28,
#   'cos_similarity': 1.2145261749159708,
#   'euc_distance': 0.49110357531845267,
#   'keyword': 'v1 neurons'},
#  {'cluster': 18,
#   'cos_similarity': 0.9144007276520766,
#   'euc_distance': 0.7287502437454091,
#   'keyword': 'language processing'},
#  {'cluster': 20,
#   'cos_similarity': 1.093099520313189,
#   'euc_distance': 0.7546506604359,
#   'keyword': 'placing emphasis'},
#  {'cluster': 16,
#   'cos_similarity': 1.0126674120699466,
#   'euc_distance': 0.6395686658971612,
#   'keyword': 'ideal observer model'},
#  {'cluster': 14,
#   'cos_similarity': 0.689104255881558,
#   'euc_distance': 0.9291840820817421,
#   'keyword': 'team markov games'},
#  {'cluster': 26,
#   'cos_similarity': 0.9826621377362685,
#   'euc_distance': 0.7362334201115353,
#   'keyword': 'suitable prior'},
#  {'cluster': 2,
#   'cos_similarity': 0.9161703039528886,
#   'euc_distance': 0.759086347718484,
#   'keyword': 'randomized gacv'},
#  {'cluster': 3,
#   'cos_similarity': 0.8455004121710132,
#   'euc_distance': 0.7599718499258145,
#   'keyword': 'product units'},
#  {'cluster': 7,
#   'cos_similarity': 1.1201796608779475,
#   'euc_distance': 0.6492688560886547,
#   'keyword': 'metric data'},
#  {'cluster': 27,
#   'cos_similarity': 0.9798652788572784,
#   'euc_distance': 0.6103032357770071,
#   'keyword': 'geometric framework'},
#  {'cluster': 17,
#   'cos_similarity': 0.9892450679477682,
#   'euc_distance': 0.7164293479443293,
#   'keyword': 'hierarchical feed'},
#  {'cluster': 21,
#   'cos_similarity': 1.0024011731983187,
#   'euc_distance': 0.49370156239080476,
#   'keyword': 'machine learning algorithms'},
#  {'cluster': 4,
#   'cos_similarity': 0.9339578720383573,
#   'euc_distance': 0.7133319182055704,
#   'keyword': 'profit maximizing subset'},
#  {'cluster': 0,
#   'cos_similarity': 1.108062003943773,
#   'euc_distance': 0.5468098115450365,
#   'keyword': 'convex analysis'},
#  {'cluster': 12,
#   'cos_similarity': 1.0604181675848967,
#   'euc_distance': 0.713058318771665,
#   'keyword': 'discover features sensitive'},
#  {'cluster': 3,
#   'cos_similarity': 0.9684579253502021,
#   'euc_distance': 0.6536186059833091,
#   'keyword': 'univariate distributions'},
#  {'cluster': 26,
#   'cos_similarity': 1.0957660428638776,
#   'euc_distance': 0.6593361842742751,
#   'keyword': 'narrow prior'},
#  {'cluster': 8,
#   'cos_similarity': 0.944739909426008,
#   'euc_distance': 0.7411603627441129,
#   'keyword': 'class generalizes'},
#  {'cluster': 1,
#   'cos_similarity': 0.9624993250030428,
#   'euc_distance': 0.6916013423505809,
#   'keyword': 'encode invariances inherent'},
#  {'cluster': 6,
#   'cos_similarity': 1.0749131703805557,
#   'euc_distance': 0.6377462896357272,
#   'keyword': 'samples without'},
#  {'cluster': 1,
#   'cos_similarity': 1.1251174452240802,
#   'euc_distance': 0.5430315381584458,
#   'keyword': 'approximated kernel machines'},
#  {'cluster': 26,
#   'cos_similarity': 1.0059662402831333,
#   'euc_distance': 0.7210604740872847,
#   'keyword': 'extreme uncertainty'},
#  {'cluster': 9,
#   'cos_similarity': 1.030902986193643,
#   'euc_distance': 0.7848295267276973,
#   'keyword': 'policy regret'},
#  {'cluster': 27,
#   'cos_similarity': 0.9455156527647818,
#   'euc_distance': 0.646057090596345,
#   'keyword': 'constrained practical applications'},
#  {'cluster': 28,
#   'cos_similarity': 0.9538466719906894,
#   'euc_distance': 0.7197366836744705,
#   'keyword': 'biological control systems'},
#  {'cluster': 27,
#   'cos_similarity': 0.855488846381688,
#   'euc_distance': 0.7315187810997439,
#   'keyword': 'classical framework'},
#  {'cluster': 15,
#   'cos_similarity': 0.9897683675001915,
#   'euc_distance': 0.7020510276466999,
#   'keyword': 'unseen domains'},
#  {'cluster': 0,
#   'cos_similarity': 0.9668652908123,
#   'euc_distance': 0.6795427855655697,
#   'keyword': 'projection space required'},
#  {'cluster': 12,
#   'cos_similarity': 1.0962773018704401,
#   'euc_distance': 0.690651725769926,
#   'keyword': 'select important features'},
#  {'cluster': 29,
#   'cos_similarity': 1.0789942268110666,
#   'euc_distance': 0.34949969703837264,
#   'keyword': 'alexnet'},
#  {'cluster': 0,
#   'cos_similarity': 1.1222055820007406,
#   'euc_distance': 0.5316913395553605,
#   'keyword': 'parametric representation'},
#  {'cluster': 11,
#   'cos_similarity': 0.968502742743205,
#   'euc_distance': 0.6454725355798686,
#   'keyword': 'robust pca captures'},
#  {'cluster': 23,
#   'cos_similarity': 0.8074805238093002,
#   'euc_distance': 0.8131636026406335,
#   'keyword': 'smoothness classes allow'},
#  {'cluster': 18,
#   'cos_similarity': 0.941592728746878,
#   'euc_distance': 0.7073240247872468,
#   'keyword': 'based learning rules'},
#  {'cluster': 12,
#   'cos_similarity': 0.9580534743218331,
#   'euc_distance': 0.7734579247335928,
#   'keyword': 'transferring features even'},
#  {'cluster': 22,
#   'cos_similarity': 1.0640813505373639,
#   'euc_distance': 0.6339132469538323,
#   'keyword': 'empirical experiments'},
#  {'cluster': 2,
#   'cos_similarity': 0.9495440676355692,
#   'euc_distance': 0.7363609456179387,
#   'keyword': 'person segmentation'},
#  {'cluster': 5,
#   'cos_similarity': 0.9229341500445316,
#   'euc_distance': 0.688909850227284,
#   'keyword': 'suitable utility function'},
#  {'cluster': 20,
#   'cos_similarity': 1.1538882663765475,
#   'euc_distance': 0.7248268725822801,
#   'keyword': 'g ., tensorflow'},
#  {'cluster': 9,
#   'cos_similarity': 0.9388191261806715,
#   'euc_distance': 0.8261771354653504,
#   'keyword': 'counterfactual fairness captures'},
#  {'cluster': 24,
#   'cos_similarity': 1.0130632130621549,
#   'euc_distance': 0.5823122851985444,
#   'keyword': 'young duality theorem'},
#  {'cluster': 2,
#   'cos_similarity': 1.049270692743858,
#   'euc_distance': 0.6638338805728695,
#   'keyword': 'latent state given'},
#  {'cluster': 19,
#   'cos_similarity': 1.06752700197689,
#   'euc_distance': 0.6249865725083663,
#   'keyword': 'demonstrate using'},
#  {'cluster': 3,
#   'cos_similarity': 1.0106027429173254,
#   'euc_distance': 0.6129330047163186,
#   'keyword': 'probability mass function'},
#  {'cluster': 6,
#   'cos_similarity': 1.1366283105399158,
#   'euc_distance': 0.5856907055242837,
#   'keyword': 'samples scales'},
#  {'cluster': 10,
#   'cos_similarity': 0.8982759823639198,
#   'euc_distance': 0.7972401623510752,
#   'keyword': 'much lower dependency'},
#  {'cluster': 29,
#   'cos_similarity': 1.0993808646135594,
#   'euc_distance': 0.3020604789338162,
#   'keyword': 'optimality'},
#  {'cluster': 22,
#   'cos_similarity': 0.9962093135334131,
#   'euc_distance': 0.6883442279326872,
#   'keyword': 'based transient classification'},
#  {'cluster': 27,
#   'cos_similarity': 0.7902151688542851,
#   'euc_distance': 0.7877052107670889,
#   'keyword': 'physical systems'},
#  {'cluster': 2,
#   'cos_similarity': 1.030243976070723,
#   'euc_distance': 0.6782701540574394,
#   'keyword': 'strategic interactions form'},
#  {'cluster': 9,
#   'cos_similarity': 0.933293746573129,
#   'euc_distance': 0.8285925138666653,
#   'keyword': 'weighted majority vote'},
#  {'cluster': 24,
#   'cos_similarity': 1.051696886080928,
#   'euc_distance': 0.5378855484529511,
#   'keyword': 'nonparametric bayesian technique'},
#  {'cluster': 9,
#   'cos_similarity': 1.1876986149856565,
#   'euc_distance': 0.7088971264481453,
#   'keyword': 'existing marginal'},
#  {'cluster': 27,
#   'cos_similarity': 1.057451938496889,
#   'euc_distance': 0.5205845789046618,
#   'keyword': 'gaussian copulas network'},
#  {'cluster': 3,
#   'cos_similarity': 1.0332365826054501,
#   'euc_distance': 0.589925859936108,
#   'keyword': 'convex quadratic program'},
#  {'cluster': 10,
#   'cos_similarity': 0.9838497782203648,
#   'euc_distance': 0.7465219029370644,
#   'keyword': 'maximum labelwise accuracy'},
#  {'cluster': 9,
#   'cos_similarity': 0.875537015123774,
#   'euc_distance': 0.8534315546931928,
#   'keyword': 'subject budget'},
#  {'cluster': 3,
#   'cos_similarity': 1.096531494214103,
#   'euc_distance': 0.5202133620880052,
#   'keyword': 'unitary matrices'},
#  {'cluster': 25,
#   'cos_similarity': 0.8187252997588977,
#   'euc_distance': 0.8490918593158546,
#   'keyword': 'step space'},
#  {'cluster': 20,
#   'cos_similarity': 1.1529548674068488,
#   'euc_distance': 0.725294090433816,
#   'keyword': 'priori }.'},
#  {'cluster': 25,
#   'cos_similarity': 0.979903509897834,
#   'euc_distance': 0.7614761876790578,
#   'keyword': 'natural setup'},
#  {'cluster': 3,
#   'cos_similarity': 0.8956871432110123,
#   'euc_distance': 0.7184664156416061,
#   'keyword': '2 )$ variables'},
#  {'cluster': 22,
#   'cos_similarity': 1.1181343250609352,
#   'euc_distance': 0.5869651151702804,
#   'keyword': 'underlying similarity measure'},
#  {'cluster': 23,
#   'cos_similarity': 1.0767175846335,
#   'euc_distance': 0.6038249823264312,
#   'keyword': 'two control parameters'},
#  {'cluster': 1,
#   'cos_similarity': 0.9448753663946355,
#   'euc_distance': 0.705827030063389,
#   'keyword': 'robust versions'},
#  {'cluster': 27,
#   'cos_similarity': 0.9427372303209116,
#   'euc_distance': 0.6488629851156034,
#   'keyword': 'neural language modeling'},
#  {'cluster': 18,
#   'cos_similarity': 1.0687409737073852,
#   'euc_distance': 0.5970177860636108,
#   'keyword': 'parameter learning'},
#  {'cluster': 0,
#   'cos_similarity': 1.0883443125245247,
#   'euc_distance': 0.5672145610850374,
#   'keyword': 'dimensional neuroimaging data'},
#  {'cluster': 14,
#   'cos_similarity': 1.0223793889548658,
#   'euc_distance': 0.7890570414544403,
#   'keyword': 'shot classification objective'},
#  {'cluster': 27,
#   'cos_similarity': 1.1321127855732716,
#   'euc_distance': 0.4163805113772599,
#   'keyword': 'recurrent neural networks'},
#  {'cluster': 23,
#   'cos_similarity': 1.0223265334724814,
#   'euc_distance': 0.6515593831251054,
#   'keyword': 'unbounded set'},
#  {'cluster': 10,
#   'cos_similarity': 1.1259966375941983,
#   'euc_distance': 0.6536327155882773,
#   'keyword': 'robust adaptive control'},
#  {'cluster': 5,
#   'cos_similarity': 1.0090426508914823,
#   'euc_distance': 0.6063215806393573,
#   'keyword': 'understanding feature construction'},
#  {'cluster': 20,
#   'cos_similarity': 1.0300903780569526,
#   'euc_distance': 0.7843678630915834,
#   'keyword': 'remarkably brittle'},
#  {'cluster': 12,
#   'cos_similarity': 0.6948486487415381,
#   'euc_distance': 0.9105473689215943,
#   'keyword': 'recent achievements'},
#  {'cluster': 16,
#   'cos_similarity': 0.9002875396567626,
#   'euc_distance': 0.7338858254801576,
#   'keyword': 'fire neural model'},
#  {'cluster': 1,
#   'cos_similarity': 1.0717676222014216,
#   'euc_distance': 0.5958695644201832,
#   'keyword': 'temporal architectures'},
#  {'cluster': 2,
#   'cos_similarity': 0.9202822299274485,
#   'euc_distance': 0.7563232720933416,
#   'keyword': 'relevant elements'},
#  {'cluster': 2,
#   'cos_similarity': 0.9400570525523377,
#   'euc_distance': 0.742891722281755,
#   'keyword': 'induced matching'},
#  {'cluster': 11,
#   'cos_similarity': 1.0706909732020906,
#   'euc_distance': 0.5379527564913976,
#   'keyword': 'norb datasets showing'},
#  {'cluster': 17,
#   'cos_similarity': 1.11231736815047,
#   'euc_distance': 0.6251653074994726,
#   'keyword': 'heuristic scheme'},
#  {'cluster': 12,
#   'cos_similarity': 1.1669658375678045,
#   'euc_distance': 0.6442035740729127,
#   'keyword': 'distinct feature'},
#  {'cluster': 23,
#   'cos_similarity': 0.8285972103925889,
#   'euc_distance': 0.7987301453782377,
#   'keyword': 'class ($\\ mathcal'},
#  {'cluster': 2,
#   'cos_similarity': 0.9878874130911017,
#   'euc_distance': 0.7093534141547047,
#   'keyword': 'notable robustness'},
#  {'cluster': 26,
#   'cos_similarity': 0.9686533339092707,
#   'euc_distance': 0.7452056795188384,
#   'keyword': 'many recent developments'},
#  {'cluster': 3,
#   'cos_similarity': 0.9888790086925323,
#   'euc_distance': 0.6342305769777976,
#   'keyword': 'optimization problem involved'},
#  {'cluster': 27,
#   'cos_similarity': 1.0586631612524873,
#   'euc_distance': 0.5190610989603316,
#   'keyword': 'integrated clustering'},
#  {'cluster': 6,
#   'cos_similarity': 1.2146138399308366,
#   'euc_distance': 0.5124028684079017,
#   'keyword': 'sampling based'},
#  {'cluster': 29,
#   'cos_similarity': 0.9746179641869828,
#   'euc_distance': 0.5295295100099582,
#   'keyword': 'approachis made'},
#  {'cluster': 18,
#   'cos_similarity': 1.1002666257117524,
#   'euc_distance': 0.5663539512746807,
#   'keyword': 'mediated competitive learning'},
#  {'cluster': 23,
#   'cos_similarity': 0.8796719804821924,
#   'euc_distance': 0.7626916109793388,
#   'keyword': 'possible object regions'},
#  {'cluster': 2,
#   'cos_similarity': 0.9939330918954858,
#   'euc_distance': 0.7050006577887091,
#   'keyword': 'exemplars chosen'},
#  {'cluster': 10,
#   'cos_similarity': 0.8598322617024554,
#   'euc_distance': 0.8190033529586949,
#   'keyword': 'noise input'},
#  {'cluster': 26,
#   'cos_similarity': 0.9742908965657421,
#   'euc_distance': 0.7416080250517045,
#   'keyword': 'like convnets'},
#  {'cluster': 29,
#   'cos_similarity': 0.9225055339375605,
#   'euc_distance': 0.5995102441619918,
#   'keyword': 'real nvp'},
#  {'cluster': 0,
#   'cos_similarity': 0.9485060234654809,
#   'euc_distance': 0.6949415137784465,
#   'keyword': 'dense 3d shape'},
#  {'cluster': 0,
#   'cos_similarity': 0.9064646108925953,
#   'euc_distance': 0.7289792830917868,
#   'keyword': 'embarrassingly parallel mcmc'},
#  {'cluster': 18,
#   'cos_similarity': 1.0646319065070922,
#   'euc_distance': 0.6008992843027248,
#   'keyword': 'learning ensembles'},
#  {'cluster': 19,
#   'cos_similarity': 0.9378030845142157,
#   'euc_distance': 0.7279433117472323,
#   'keyword': 'setting leads'},
#  {'cluster': 17,
#   'cos_similarity': 1.0402210916588372,
#   'euc_distance': 0.6801155391042389,
#   'keyword': 'modeling relational data'},
#  {'cluster': 7,
#   'cos_similarity': 1.1367486205785482,
#   'euc_distance': 0.6372565865254564,
#   'keyword': 'directly estimating'},
#  {'cluster': 16,
#   'cos_similarity': 1.0260335164844414,
#   'euc_distance': 0.6274081171497734,
#   'keyword': 'many models'},
#  {'cluster': 16,
#   'cos_similarity': 0.9231032109036356,
#   'euc_distance': 0.7157435084880291,
#   'keyword': 'image modeling'},
#  {'cluster': 4,
#   'cos_similarity': 1.118897978533119,
#   'euc_distance': 0.5472892280963978,
#   'keyword': 'approximation ratio'},
#  {'cluster': 24,
#   'cos_similarity': 1.089890726444685,
#   'euc_distance': 0.4900211605624785,
#   'keyword': 'probabilistic renderers ).'},
#  {'cluster': 7,
#   'cos_similarity': 1.0098332265383905,
#   'euc_distance': 0.7242041527883525,
#   'keyword': 'estimated patterns'},
#  {'cluster': 20,
#   'cos_similarity': 0.9021864129573357,
#   'euc_distance': 0.8414703154747482,
#   'keyword': 'positive semi'},
#  {'cluster': 25,
#   'cos_similarity': 1.0131802904330103,
#   'euc_distance': 0.7420998961040414,
#   'keyword': 'moving objects'},
#  {'cluster': 4,
#   'cos_similarity': 1.0346856408434797,
#   'euc_distance': 0.6283611867221769,
#   'keyword': 'statistical guarantees'},
#  {'cluster': 3,
#   'cos_similarity': 1.1064959286755571,
#   'euc_distance': 0.5083683922690831,
#   'keyword': 'linear eigenproblem yields'},
#  {'cluster': 23,
#   'cos_similarity': 1.0476608186089258,
#   'euc_distance': 0.6297759351686243,
#   'keyword': 'propagating label information'},
#  {'cluster': 22,
#   'cos_similarity': 1.1645498905287093,
#   'euc_distance': 0.5434232151790906,
#   'keyword': 'rigorous analysis'},
#  {'cluster': 20,
#   'cos_similarity': 0.8787192289458484,
#   'euc_distance': 0.8515315429177891,
#   'keyword': 'target prior'},
#  {'cluster': 8,
#   'cos_similarity': 1.040881759530902,
#   'euc_distance': 0.6722294646880427,
#   'keyword': 'demonstrated extensively'},
#  {'cluster': 23,
#   'cos_similarity': 1.0631661220486068,
#   'euc_distance': 0.6160639896826581,
#   'keyword': 'modified policy iteration'},
#  {'cluster': 7,
#   'cos_similarity': 0.8545144374138378,
#   'euc_distance': 0.8181317621493126,
#   'keyword': 'consider unsupervised estimation'},
#  {'cluster': 25,
#   'cos_similarity': 0.9995974878949706,
#   'euc_distance': 0.7500692909284763,
#   'keyword': 'deep trees'},
#  {'cluster': 18,
#   'cos_similarity': 1.0054520487575287,
#   'euc_distance': 0.6542522819232678,
#   'keyword': 'evaluate models learning'},
#  {'cluster': 3,
#   'cos_similarity': 0.9084386524970578,
#   'euc_distance': 0.7075328482302984,
#   'keyword': 'exponential loss'},
#  {'cluster': 24,
#   'cos_similarity': 0.9745344732988218,
#   'euc_distance': 0.6234734798767538,
#   'keyword': 'synthetic evaluation datasets'},
#  {'cluster': 22,
#   'cos_similarity': 1.10231527767241,
#   'euc_distance': 0.6010845448890157,
#   'keyword': 'generalized interdependent'},
#  {'cluster': 12,
#   'cos_similarity': 0.8923314856498821,
#   'euc_distance': 0.8098657145407457,
#   'keyword': 'image search system'},
#  {'cluster': 21,
#   'cos_similarity': 1.0085127510485519,
#   'euc_distance': 0.4842949053267987,
#   'keyword': 'convergent optimization algorithm'},
#  {'cluster': 12,
#   'cos_similarity': 0.8779111255100481,
#   'euc_distance': 0.8176372822303345,
#   'keyword': 'highlight issues'},
#  {'cluster': 2,
#   'cos_similarity': 0.9349216238612436,
#   'euc_distance': 0.7464030729569443,
#   'keyword': 'realistic multi'},
#  {'cluster': 22,
#   'cos_similarity': 0.982151800451442,
#   'euc_distance': 0.6990882765070863,
#   'keyword': 'causal effects'},
#  {'cluster': 4,
#   'cos_similarity': 1.033031668624741,
#   'euc_distance': 0.6298490052663677,
#   'keyword': 'aalen regression models'},
#  {'cluster': 14,
#   'cos_similarity': 1.0627321599881618,
#   'euc_distance': 0.7703625530552375,
#   'keyword': 'competitive enough'},
#  {'cluster': 20,
#   'cos_similarity': 0.9995256233756272,
#   'euc_distance': 0.7983848544291324,
#   'keyword': '2 f_i'},
#  {'cluster': 15,
#   'cos_similarity': 1.0831669230485388,
#   'euc_distance': 0.6294182240578721,
#   'keyword': 'deep network architecture'},
#  {'cluster': 24,
#   'cos_similarity': 0.9597853027918651,
#   'euc_distance': 0.6385284449865374,
#   'keyword': 'optimal control theory'},
#  {'cluster': 9,
#   'cos_similarity': 0.6213114921862625,
#   'euc_distance': 0.9551157561449595,
#   'keyword': 'english translation task'},
#  {'cluster': 16,
#   'cos_similarity': 1.0906448646545155,
#   'euc_distance': 0.5649455011789136,
#   'keyword': 'lrma models'},
#  {'cluster': 29,
#   'cos_similarity': 0.9054036913054884,
#   'euc_distance': 0.6207589280450586,
#   'keyword': 'systematically'},
#  {'cluster': 16,
#   'cos_similarity': 0.9225255542951434,
#   'euc_distance': 0.7162085121128693,
#   'keyword': 'warped trajectory models'},
#  {'cluster': 7,
#   'cos_similarity': 1.0881725254116645,
#   'euc_distance': 0.6718657080791841,
#   'keyword': 'faster variational approximation'},
#  {'cluster': 11,
#   'cos_similarity': 1.038055178957198,
#   'euc_distance': 0.5744826128258945,
#   'keyword': 'three simulated datasets'},
#  {'cluster': 29,
#   'cos_similarity': 0.9344692465539197,
#   'euc_distance': 0.5841862216312266,
#   'keyword': 'stoc 2015'},
#  {'cluster': 15,
#   'cos_similarity': 1.01713959029549,
#   'euc_distance': 0.6815676503334308,
#   'keyword': 'integrated brain networks'},
#  {'cluster': 1,
#   'cos_similarity': 1.0222644324439916,
#   'euc_distance': 0.6410139334033913,
#   'keyword': 'spectral kernel learning'},
#  {'cluster': 11,
#   'cos_similarity': 1.071979705000481,
#   'euc_distance': 0.5364591040737848,
#   'keyword': '10 recognition dataset'},
#  {'cluster': 16,
#   'cos_similarity': 1.0636921511557262,
#   'euc_distance': 0.5918039070756269,
#   'keyword': 'generative composite model'},
#  {'cluster': 16,
#   'cos_similarity': 0.9371276703129592,
#   'euc_distance': 0.7043598295012146,
#   'keyword': 'supervised topic model'},
#  {'cluster': 9,
#   'cos_similarity': 1.1696183419886603,
#   'euc_distance': 0.7180626767613257,
#   'keyword': 'application demands'},
#  {'cluster': 24,
#   'cos_similarity': 1.0370281775977839,
#   'euc_distance': 0.555172640790218,
#   'keyword': 'capturing stochastic'},
#  {'cluster': 4,
#   'cos_similarity': 0.9229866008340172,
#   'euc_distance': 0.7219832487110768,
#   'keyword': 'empirical revenue'},
#  {'cluster': 27,
#   'cos_similarity': 0.8231083034322773,
#   'euc_distance': 0.7599108131852176,
#   'keyword': 'cheap computer simulation'},
#  {'cluster': 13,
#   'cos_similarity': 0.9588187814271273,
#   'euc_distance': 0.6787616386060693,
#   'keyword': 'level prediction accuracy'},
#  {'cluster': 4,
#   'cos_similarity': 0.8683959395579758,
#   'euc_distance': 0.7635745119671669,
#   'keyword': 'finding informative positive'},
#  {'cluster': 6,
#   'cos_similarity': 0.9870720622265358,
#   'euc_distance': 0.7052429748510601,
#   'keyword': 'sample scarcity'},
#  {'cluster': 3,
#   'cos_similarity': 1.036366441718194,
#   'euc_distance': 0.5866733724868941,
#   'keyword': 'variable amplitudes'},
#  {'cluster': 4,
#   'cos_similarity': 0.9653849847476235,
#   'euc_distance': 0.6879483372371737,
#   'keyword': 'two probability densities'},
#  {'cluster': 18,
#   'cos_similarity': 0.967306306794828,
#   'euc_distance': 0.6864477998202976,
#   'keyword': 'learning agents'},
#  {'cluster': 21,
#   'cos_similarity': 0.8003640013139608,
#   'euc_distance': 0.7401793707548631,
#   'keyword': 'hashing trick ).'},
#  {'cluster': 2,
#   'cos_similarity': 0.9921992346939529,
#   'euc_distance': 0.7062517416840387,
#   'keyword': 'matrix adagrad based'},
#  {'cluster': 22,
#   'cos_similarity': 0.9351503088618085,
#   'euc_distance': 0.7338698663630636,
#   'keyword': 'online variational inference'},
#  {'cluster': 9,
#   'cos_similarity': 0.767647517990683,
#   'euc_distance': 0.8979922880912617,
#   'keyword': 'topics may'},
#  {'cluster': 26,
#   'cos_similarity': 0.9169229020734541,
#   'euc_distance': 0.7774409690803298,
#   'keyword': 'making high'},
#  {'cluster': 17,
#   'cos_similarity': 1.005046623882455,
#   'euc_distance': 0.7053727547883564,
#   'keyword': 'policy gradient researches'},
#  {'cluster': 17,
#   'cos_similarity': 0.9088309703917352,
#   'euc_distance': 0.7702412357930022,
#   'keyword': 'produce competitive results'},
#  {'cluster': 23,
#   'cos_similarity': 1.0895536130508465,
#   'euc_distance': 0.5919988134608863,
#   'keyword': 'combinatorial procedure based'},
#  {'cluster': 26,
#   'cos_similarity': 0.8003895955453183,
#   'euc_distance': 0.8455671479848317,
#   'keyword': 'introduce latent attention'},
#  {'cluster': 20,
#   'cos_similarity': 1.1463207344412403,
#   'euc_distance': 0.7286061390649494,
#   'keyword': 'temporal low'},
#  {'cluster': 18,
#   'cos_similarity': 1.0821622874558268,
#   'euc_distance': 0.584160185792317,
#   'keyword': 'study active learning'},
#  {'cluster': 2,
#   'cos_similarity': 1.0065691321386208,
#   'euc_distance': 0.6958150586509028,
#   'keyword': 'various tasks'},
#  {'cluster': 5,
#   'cos_similarity': 0.9713449435653463,
#   'euc_distance': 0.6437833402256385,
#   'keyword': 'precise bounding boxes'},
#  {'cluster': 10,
#   'cos_similarity': 0.8518046378156197,
#   'euc_distance': 0.8234752499202157,
#   'keyword': 'recovery guarantee'},
#  {'cluster': 9,
#   'cos_similarity': 1.0008189569319346,
#   'euc_distance': 0.7985734055146714,
#   'keyword': 'dependency'},
#  {'cluster': 7,
#   'cos_similarity': 1.1608394095262828,
#   'euc_distance': 0.6193756170380949,
#   'keyword': 'variable scales'},
#  {'cluster': 27,
#   'cos_similarity': 1.023725386274086,
#   'euc_distance': 0.5613494860030945,
#   'keyword': 'fully bayesian framework'},
#  {'cluster': 26,
#   'cos_similarity': 0.9947158079997249,
#   'euc_distance': 0.7284249230564952,
#   'keyword': 'excellent solution accuracy'},
#  {'cluster': 8,
#   'cos_similarity': 0.6852973955730408,
#   'euc_distance': 0.9012364779131011,
#   'keyword': 'main source'},
#  {'cluster': 3,
#   'cos_similarity': 1.079962105109037,
#   'euc_distance': 0.5393340952310071,
#   'keyword': 'nonlinear combination rule'},
#  {'cluster': 14,
#   'cos_similarity': 0.9360079701413843,
#   'euc_distance': 0.8276529669717421,
#   'keyword': 'cup task using'},
#  {'cluster': 16,
#   'cos_similarity': 0.9832038357378892,
#   'euc_distance': 0.6655905218868033,
#   'keyword': 'level model outputs'},
#  {'cluster': 16,
#   'cos_similarity': 1.0095081566364623,
#   'euc_distance': 0.6424093412381429,
#   'keyword': 'semantic modeling'},
#  {'cluster': 5,
#   'cos_similarity': 1.0549736825702731,
#   'euc_distance': 0.5572849695871214,
#   'keyword': 'based bayesian optimization'},
#  {'cluster': 16,
#   'cos_similarity': 0.960829771188372,
#   'euc_distance': 0.6846906930351293,
#   'keyword': 'performing model selection'},
#  {'cluster': 2,
#   'cos_similarity': 1.0780031316292216,
#   'euc_distance': 0.6414180088007059,
#   'keyword': 'shared structure'},
#  {'cluster': 18,
#   'cos_similarity': 0.980031185162013,
#   'euc_distance': 0.675878326805562,
#   'keyword': 'learning visual features'},
#  {'cluster': 29,
#   'cos_similarity': 1.0834728542267804,
#   'euc_distance': 0.33964658975513584,
#   'keyword': 'mcmc ).'},
#  {'cluster': 4,
#   'cos_similarity': 0.7297011315008126,
#   'euc_distance': 0.8602453754593258,
#   'keyword': 'population states outperforms'},
#  {'cluster': 27,
#   'cos_similarity': 1.0471071440952737,
#   'euc_distance': 0.5334195986881322,
#   'keyword': 'algorithmic progress'},
#  {'cluster': 21,
#   'cos_similarity': 1.0408144413147689,
#   'euc_distance': 0.43118219315880557,
#   'keyword': 'dynamic programming algorithm'},
#  {'cluster': 14,
#   'cos_similarity': 0.9861112985283361,
#   'euc_distance': 0.8054890420105824,
#   'keyword': 'high score close'},
#  {'cluster': 9,
#   'cos_similarity': 1.1139621856943325,
#   'euc_distance': 0.745569804467043,
#   'keyword': 'multiple supervised'},
#  {'cluster': 25,
#   'cos_similarity': 1.1269781631303484,
#   'euc_distance': 0.6716268017140645,
#   'keyword': 'subject design'},
#  {'cluster': 3,
#   'cos_similarity': 1.0472435555287307,
#   'euc_distance': 0.5752270771248184,
#   'keyword': 'using linear'},
#  {'cluster': 7,
#   'cos_similarity': 1.0106982638666095,
#   'euc_distance': 0.7236468953756969,
#   'keyword': 'accurate approximation'},
#  {'cluster': 25,
#   'cos_similarity': 1.20493627077746,
#   'euc_distance': 0.6187329658087969,
#   'keyword': 'visual concepts'},
#  {'cluster': 2,
#   'cos_similarity': 0.9762634901929176,
#   'euc_distance': 0.7176482066200998,
#   'keyword': 'multiple norms'},
#  {'cluster': 19,
#   'cos_similarity': 0.8722867248119789,
#   'euc_distance': 0.774758525336463,
#   'keyword': 'whole process'},
#  {'cluster': 26,
#   'cos_similarity': 1.0116725950601577,
#   'euc_distance': 0.7172962394895819,
#   'keyword': 'high probability simultaneously'},
#  {'cluster': 17,
#   'cos_similarity': 1.1259282562763353,
#   'euc_distance': 0.6142399836750405,
#   'keyword': 'scalable'},
#  {'cluster': 0,
#   'cos_similarity': 1.024229760768905,
#   'euc_distance': 0.6290041774270109,
#   'keyword': 'embedding dimension'},
#  {'cluster': 20,
#   'cos_similarity': 0.9675672346557697,
#   'euc_distance': 0.8127825387787331,
#   'keyword': 'naturally produced'},
#  {'cluster': 9,
#   'cos_similarity': 0.8984398022315028,
#   'euc_distance': 0.8436694241256649,
#   'keyword': 'distribution dependent regret'},
#  {'cluster': 10,
#   'cos_similarity': 0.9117239065737492,
#   'euc_distance': 0.7894856021618019,
#   'keyword': 'improvements ."'},
#  {'cluster': 23,
#   'cos_similarity': 0.7649866860916412,
#   'euc_distance': 0.8414584855183133,
#   'keyword': 'phonetic alignment'},
#  {'cluster': 28,
#   'cos_similarity': 0.8284991244820807,
#   'euc_distance': 0.8069314243074223,
#   'keyword': 'auditory map'},
#  {'cluster': 17,
#   'cos_similarity': 0.8588323590870671,
#   'euc_distance': 0.8018809451041207,
#   'keyword': 'experts code'},
#  {'cluster': 2,
#   'cos_similarity': 0.9969847991645474,
#   'euc_distance': 0.7027932543173526,
#   'keyword': 'two objects'},
#  {'cluster': 0,
#   'cos_similarity': 0.980733506820152,
#   'euc_distance': 0.6676754696441326,
#   'keyword': 'temporal rf components'},
#  {'cluster': 26,
#   'cos_similarity': 1.0075807321195747,
#   'euc_distance': 0.7199974622130995,
#   'keyword': 'local similarity'},
#  {'cluster': 2,
#   'cos_similarity': 1.0599385822886602,
#   'euc_distance': 0.6556007079751488,
#   'keyword': 'bounds suggest'},
#  {'cluster': 24,
#   'cos_similarity': 1.0784415764953028,
#   'euc_distance': 0.5048456140567104,
#   'keyword': 'hierarchical bayesian model'},
#  {'cluster': 29,
#   'cos_similarity': 1.0646170161915625,
#   'euc_distance': 0.37940516738024427,
#   'keyword': 'shortcoming'},
#  {'cluster': 1,
#   'cos_similarity': 0.9227003100838255,
#   'euc_distance': 0.7233289045456589,
#   'keyword': 'batch points simultaneously'},
#  {'cluster': 13,
#   'cos_similarity': 1.0418301181745406,
#   'euc_distance': 0.602617767845624,
#   'keyword': 'fair prediction'},
#  {'cluster': 14,
#   'cos_similarity': 1.3050865899084139,
#   'euc_distance': 0.6468163389926599,
#   'keyword': 'training using low'},
#  {'cluster': 4,
#   'cos_similarity': 1.0339607723965927,
#   'euc_distance': 0.6290136605482419,
#   'keyword': 'binomial distribution'},
#  {'cluster': 3,
#   'cos_similarity': 0.9656109329851629,
#   'euc_distance': 0.6562760798511961,
#   'keyword': 'independent mathematical interest'},
#  {'cluster': 9,
#   'cos_similarity': 1.0127073833275857,
#   'euc_distance': 0.7931706267246657,
#   'keyword': 'predictive policing'},
#  {'cluster': 21,
#   'cos_similarity': 1.016146202733894,
#   'euc_distance': 0.47228280111778054,
#   'keyword': 'obtain algorithms'},
#  {'cluster': 4,
#   'cos_similarity': 1.0718738251014557,
#   'euc_distance': 0.5939257982228152,
#   'keyword': 'statistical pattern recognition'},
#  {'cluster': 29,
#   'cos_similarity': 1.077661136229877,
#   'euc_distance': 0.3523794628110343,
#   'keyword': 'minimizations'},
#  {'cluster': 0,
#   'cos_similarity': 1.0473859262969019,
#   'euc_distance': 0.6074132451194307,
#   'keyword': 'hilbert space induced'},
#  {'cluster': 9,
#   'cos_similarity': 1.067145144021976,
#   'euc_distance': 0.7679457447076175,
#   'keyword': 'distilled policy'},
#  {'cluster': 2,
#   'cos_similarity': 0.9106924290976436,
#   'euc_distance': 0.7627517427810634,
#   'keyword': 'three structures'},
#  {'cluster': 17,
#   'cos_similarity': 0.9369415333899589,
#   'euc_distance': 0.7518680489868882,
#   'keyword': 'information feedback structure'},
#  {'cluster': 29,
#   'cos_similarity': 1.0718155274087076,
#   'euc_distance': 0.36473850211666103,
#   'keyword': 'nonrandom'},
#  {'cluster': 17,
#   'cos_similarity': 0.9114902675377184,
#   'euc_distance': 0.7685219050325794,
#   'keyword': 'technical applications'},
#  {'cluster': 2,
#   'cos_similarity': 1.0008757215986728,
#   'euc_distance': 0.6999687255150234,
#   'keyword': 'optimal rule'},
#  {'cluster': 11,
#   'cos_similarity': 1.0947119991054135,
#   'euc_distance': 0.5093945760450999,
#   'keyword': 'data demonstrate'},
#  {'cluster': 27,
#   'cos_similarity': 0.9746230106032585,
#   'euc_distance': 0.6158940428359011,
#   'keyword': 'distributed systems'},
#  {'cluster': 21,
#   'cos_similarity': 1.0634540191725756,
#   'euc_distance': 0.3896654664136067,
#   'keyword': 'highly scalable algorithm'},
#  {'cluster': 13,
#   'cos_similarity': 0.8970981680981033,
#   'euc_distance': 0.7302479172158174,
#   'keyword': 'shot prediction games'},
#  {'cluster': 0,
#   'cos_similarity': 1.0488677218152935,
#   'euc_distance': 0.6060054558047185,
#   'keyword': 'recurrent neocortical circuits'},
#  {'cluster': 18,
#   'cos_similarity': 1.1398448561944814,
#   'euc_distance': 0.5253296944452869,
#   'keyword': 'learning classification'},
#  {'cluster': 23,
#   'cos_similarity': 1.1079101164668743,
#   'euc_distance': 0.5746637216999186,
#   'keyword': 'dynamically modified based'},
#  {'cluster': 27,
#   'cos_similarity': 1.0813552189310427,
#   'euc_distance': 0.48964226648669307,
#   'keyword': 'computational efficient'},
#  {'cluster': 8,
#   'cos_similarity': 1.1719013207878424,
#   'euc_distance': 0.5649093489999341,
#   'keyword': 'readily generalized'},
#  {'cluster': 19,
#   'cos_similarity': 1.0950831564589423,
#   'euc_distance': 0.6008488235633445,
#   'keyword': 'method confines application'},
#  {'cluster': 29,
#   'cos_similarity': 0.8897865750758054,
#   'euc_distance': 0.6395465397083815,
#   'keyword': 'tensorized lstm'},
#  {'cluster': 18,
#   'cos_similarity': 1.0530622404668073,
#   'euc_distance': 0.6116958480920627,
#   'keyword': 'several learning applications'},
#  {'cluster': 18,
#   'cos_similarity': 0.9105720247184642,
#   'euc_distance': 0.7317167186556225,
#   'keyword': 'numberof classes'},
#  {'cluster': 18,
#   'cos_similarity': 1.181355370938114,
#   'euc_distance': 0.47853871155447336,
#   'keyword': 'learning method'},
#  {'cluster': 1,
#   'cos_similarity': 1.108644044888589,
#   'euc_distance': 0.5598793127181622,
#   'keyword': 'complex nonstationary kernels'},
#  {'cluster': 21,
#   'cos_similarity': 1.0880039809546662,
#   'euc_distance': 0.33894593720914523,
#   'keyword': 'optimal algorithm'},
#  {'cluster': 16,
#   'cos_similarity': 1.0485340094133038,
#   'euc_distance': 0.6063865427529033,
#   'keyword': 'model improves classification'},
#  {'cluster': 17,
#   'cos_similarity': 1.0590126458702356,
#   'euc_distance': 0.6662298699607568,
#   'keyword': 'structure leads'},
#  {'cluster': 2,
#   'cos_similarity': 1.0612592035773472,
#   'euc_distance': 0.6545742642260867,
#   'keyword': 'tight complexity bounds'},
#  {'cluster': 5,
#   'cos_similarity': 1.0218391269176534,
#   'euc_distance': 0.5930674289637689,
#   'keyword': 'measure optimization tasks'},
#  {'cluster': 16,
#   'cos_similarity': 1.1217293848019363,
#   'euc_distance': 0.5322896764435383,
#   'keyword': 'deformable part models'},
#  {'cluster': 9,
#   'cos_similarity': 1.0622924486789316,
#   'euc_distance': 0.7702278866019419,
#   'keyword': 'actions incur costs'},
#  {'cluster': 25,
#   'cos_similarity': 1.0435024660885772,
#   'euc_distance': 0.7239925965412463,
#   'keyword': 'salient image region'},
#  {'cluster': 12,
#   'cos_similarity': 0.794654470585849,
#   'euc_distance': 0.8611364090223191,
#   'keyword': 'sparse codes'},
#  {'cluster': 25,
#   'cos_similarity': 0.9899389560944991,
#   'euc_distance': 0.7556851066659541,
#   'keyword': 'find designs'},
#  {'cluster': 20,
#   'cos_similarity': 1.2828683605471605,
#   'euc_distance': 0.6570795720029249,
#   'keyword': 'scholkopf1998nonlinear }.'},
#  {'cluster': 21,
#   'cos_similarity': 0.9687403970224079,
#   'euc_distance': 0.5425960094345478,
#   'keyword': 'proposed algorithms improve'},
#  {'cluster': 6,
#   'cos_similarity': 1.1161909671965768,
#   'euc_distance': 0.6034267657478594,
#   'keyword': 'finite sampling effects'},
#  {'cluster': 1,
#   'cos_similarity': 0.825620615049821,
#   'euc_distance': 0.795429538003628,
#   'keyword': 'system consists'},
#  {'cluster': 23,
#   'cos_similarity': 1.0451076523282365,
#   'euc_distance': 0.6320052761665016,
#   'keyword': 'bounds showing'},
#  {'cluster': 24,
#   'cos_similarity': 0.9586979367206454,
#   'euc_distance': 0.6396243336953895,
#   'keyword': 'horizon deterministic system'},
#  {'cluster': 25,
#   'cos_similarity': 0.9717102717700267,
#   'euc_distance': 0.7661717280018282,
#   'keyword': 'concept class'},
#  {'cluster': 24,
#   'cos_similarity': 0.945996224721675,
#   'euc_distance': 0.6522892190068067,
#   'keyword': 'stochastic experts'},
#  {'cluster': 2,
#   'cos_similarity': 1.042366616479848,
#   'euc_distance': 0.6691082709022372,
#   'keyword': 'higher complexity'},
#  {'cluster': 1,
#   'cos_similarity': 1.0185147512836896,
#   'euc_distance': 0.6443046116772699,
#   'keyword': 'hypergraph partitioning relies'},
#  {'cluster': 23,
#   'cos_similarity': 0.88926517410765,
#   'euc_distance': 0.7557309309670628,
#   'keyword': 'input image regions'},
#  {'cluster': 4,
#   'cos_similarity': 1.0534866831712644,
#   'euc_distance': 0.6111944046410206,
#   'keyword': 'finally logistic regression'},
#  {'cluster': 5,
#   'cos_similarity': 0.9493020177101981,
#   'euc_distance': 0.6647108362146696,
#   'keyword': 'static scene segmentation'},
#  {'cluster': 3,
#   'cos_similarity': 1.0826311467785972,
#   'euc_distance': 0.5363001670164051,
#   'keyword': 'given classifiers'},
#  {'cluster': 4,
#   'cos_similarity': 0.9214136312854317,
#   'euc_distance': 0.7232151149920321,
#   'keyword': 'illumination estimation results'},
#  {'cluster': 26,
#   'cos_similarity': 0.9160464196266748,
#   'euc_distance': 0.7779756310888085,
#   'keyword': 'class'},
#  {'cluster': 10,
#   'cos_similarity': 1.148140415929695,
#   'euc_distance': 0.6379459020333292,
#   'keyword': 'require performance'},
#  {'cluster': 11,
#   'cos_similarity': 0.9809171485206464,
#   'euc_distance': 0.6333851515600588,
#   'keyword': 'characterize data groups'},
#  {'cluster': 20,
#   'cos_similarity': 1.0297449337373277,
#   'euc_distance': 0.784527679246076,
#   'keyword': 'locality'},
#  {'cluster': 19,
#   'cos_similarity': 1.0187696803615238,
#   'euc_distance': 0.6655540649286648,
#   'keyword': 'demonstrate improved robustness'},
#  {'cluster': 0,
#   'cos_similarity': 1.0968144631920398,
#   'euc_distance': 0.5585405993310869,
#   'keyword': 'linear space'},
#  {'cluster': 26,
#   'cos_similarity': 1.0841556204159672,
#   'euc_distance': 0.6676379422857817,
#   'keyword': 'critical points via'},
#  {'cluster': 11,
#   'cos_similarity': 0.8257358251036429,
#   'euc_distance': 0.7709758451945286,
#   'keyword': 'data poisoning attack'},
#  {'cluster': 25,
#   'cos_similarity': 1.0797710507839702,
#   'euc_distance': 0.70172091357039,
#   'keyword': 'reconstructing patterns'},
#  {'cluster': 7,
#   'cos_similarity': 0.9430377156252254,
#   'euc_distance': 0.766010910943499,
#   'keyword': 'easily visualizable low'},
#  {'cluster': 11,
#   'cos_similarity': 0.9307125593144109,
#   'euc_distance': 0.6809478256932124,
#   'keyword': 'true data'},
#  {'cluster': 6,
#   'cos_similarity': 0.9396264653518659,
#   'euc_distance': 0.7391407042047251,
#   'keyword': 'mixing performance'},
#  {'cluster': 4,
#   'cos_similarity': 1.1248667618554848,
# ...
#   'keyword': 'selected features'},
#  {'cluster': 2,
#   'cos_similarity': 1.0275356945345986,
#   'euc_distance': 0.6803001262672904,
#   'keyword': 'first bounds'},
#  {'cluster': 4,
#   'cos_similarity': 0.9756929840475805,
#   'euc_distance': 0.679416088410699,
#   'keyword': 'based likelihood calculation'},
#  {'cluster': 15,
#   'cos_similarity': 0.6893726741619949,
#   'euc_distance': 0.8966138961427067,
#   'keyword': 'rsc scene network'},
#  {'cluster': 4,
#   'cos_similarity': 1.1126828908405897,
#   'euc_distance': 0.5536784069260979,
#   'keyword': 'compute marginal likelihood'},
#  {'cluster': 20,
#   'cos_similarity': 0.97687574553537,
#   'euc_distance': 0.8086153753501161,
#   'keyword': 'first marginalizes'},
#  {'cluster': 25,
#   'cos_similarity': 1.0467869422754956,
#   'euc_distance': 0.7220039723358244,
#   'keyword': 'sparse space'},
#  {'cluster': 21,
#   'cos_similarity': 1.0661780279885256,
#   'euc_distance': 0.3843678946536616,
#   'keyword': 'maximum likelihood algorithm'},
#  {'cluster': 12,
#   'cos_similarity': 1.2447896123040916,
#   'euc_distance': 0.5888448964241663,
#   'keyword': 'simple feature'},
#  {'cluster': 18,
#   'cos_similarity': 1.0207493869603705,
#   'euc_distance': 0.6408869137485563,
#   'keyword': 'statistical learning perspective'},
#  {'cluster': 23,
#   'cos_similarity': 0.9392811216388127,
#   'euc_distance': 0.7183484222925215,
#   'keyword': 'policy search method'},
#  {'cluster': 24,
#   'cos_similarity': 0.9382647522306572,
#   'euc_distance': 0.6598793094634062,
#   'keyword': 'computationally suitable'},
#  {'cluster': 23,
#   'cos_similarity': 1.0883556683145248,
#   'euc_distance': 0.5931124564081092,
#   'keyword': 'sample covariance eigenspectrum'},
#  {'cluster': 23,
#   'cos_similarity': 1.061629151783014,
#   'euc_distance': 0.6174367707407185,
#   'keyword': 'selector variables'},
#  {'cluster': 7,
#   'cos_similarity': 1.045366607612204,
#   'euc_distance': 0.7009487834122006,
#   'keyword': 'dimensional large'},
#  {'cluster': 26,
#   'cos_similarity': 1.0578862037812442,
#   'euc_distance': 0.6860505957528614,
#   'keyword': 'perfect matchings'},
#  {'cluster': 8,
#   'cos_similarity': 1.0338295189860949,
#   'euc_distance': 0.6775241012340504,
#   'keyword': 'prior assumption'},
#  {'cluster': 4,
#   'cos_similarity': 0.795190495723915,
#   'euc_distance': 0.8160273485393503,
#   'keyword': 'population ecology'},
#  {'cluster': 21,
#   'cos_similarity': 0.9764489250427073,
#   'euc_distance': 0.5317958386676437,
#   'keyword': 'triangle fixing algorithms'},
#  {'cluster': 19,
#   'cos_similarity': 0.9578323462849481,
#   'euc_distance': 0.7130180282023911,
#   'keyword': 'proof technique'},
#  {'cluster': 19,
#   'cos_similarity': 1.0426851280996516,
#   'euc_distance': 0.6459741337508643,
#   'keyword': 'underlying process'},
#  {'cluster': 18,
#   'cos_similarity': 0.9482575599773069,
#   'euc_distance': 0.7019726272300604,
#   'keyword': 'adaptive skills'},
#  {'cluster': 26,
#   'cos_similarity': 1.0164088706990972,
#   'euc_distance': 0.7141568525414178,
#   'keyword': 'imposes local constancy'},
#  {'cluster': 25,
#   'cos_similarity': 1.199995087763932,
#   'euc_distance': 0.6222189847854404,
#   'keyword': 'nearly isometric embedding'},
#  {'cluster': 27,
#   'cos_similarity': 0.9229641647524435,
#   'euc_distance': 0.6684914741484632,
#   'keyword': 'biased machine learning'},
#  {'cluster': 2,
#   'cos_similarity': 1.1060525673517372,
#   'euc_distance': 0.6187521427016964,
#   'keyword': 'single point'},
#  {'cluster': 5,
#   'cos_similarity': 1.0312902882027326,
#   'euc_distance': 0.5830849032315428,
#   'keyword': 'regularized objective functions'},
#  {'cluster': 6,
#   'cos_similarity': 0.9945927328901271,
#   'euc_distance': 0.6997190307964963,
#   'keyword': 'perform survey sampling'},
#  {'cluster': 24,
#   'cos_similarity': 1.0993794606405956,
#   'euc_distance': 0.4773862255805491,
#   'keyword': 'perform bayesian inference'},
#  {'cluster': 8,
#   'cos_similarity': 0.9353960386099187,
#   'euc_distance': 0.7475208260348577,
#   'keyword': 'expensive inference step'},
#  {'cluster': 19,
#   'cos_similarity': 1.0659317933586991,
#   'euc_distance': 0.6263553932007171,
#   'keyword': 'existing mogp methods'},
#  {'cluster': 20,
#   'cos_similarity': 1.2370084075546637,
#   'euc_distance': 0.6819392196108341,
#   'keyword': 'structures --'},
#  {'cluster': 5,
#   'cos_similarity': 1.0586221064282497,
#   'euc_distance': 0.5532035592120744,
#   'keyword': 'reducing dimensionality'},
#  {'cluster': 7,
#   'cos_similarity': 1.052673503766182,
#   'euc_distance': 0.6960703643753513,
#   'keyword': 'scale beyond'},
#  {'cluster': 16,
#   'cos_similarity': 0.9564022336687502,
#   'euc_distance': 0.6884075666783204,
#   'keyword': 'models violate dale'},
#  {'cluster': 26,
#   'cos_similarity': 0.9191734773981409,
#   'euc_distance': 0.7760664063642407,
#   'keyword': 'mab problem'},
#  {'cluster': 27,
#   'cos_similarity': 1.0266339562815106,
#   'euc_distance': 0.5579513195114089,
#   'keyword': 'computational theory'},
#  {'cluster': 21,
#   'cos_similarity': 1.0333617553713896,
#   'euc_distance': 0.44400072392051304,
#   'keyword': 'limited clustering algorithms'},
#  {'cluster': 15,
#   'cos_similarity': 1.0425780275377425,
#   'euc_distance': 0.6619626582250393,
#   'keyword': 'individual synaptic connections'},
#  {'cluster': 2,
#   'cos_similarity': 1.0256539065618626,
#   'euc_distance': 0.6817070443876293,
#   'keyword': 'single exemplars'},
#  {'cluster': 23,
#   'cos_similarity': 0.9313147830633745,
#   'euc_distance': 0.724431723646862,
#   'keyword': 'region methods'},
#  {'cluster': 4,
#   'cos_similarity': 1.0685098527520895,
#   'euc_distance': 0.5971224783067391,
#   'keyword': 'least squares regression'},
#  {'cluster': 29,
#   'cos_similarity': 1.0542824877131443,
#   'euc_distance': 0.3995210211665267,
#   'keyword': 'symnets'},
#  {'cluster': 3,
#   'cos_similarity': 1.0936594481977993,
#   'euc_distance': 0.5235776337661106,
#   'keyword': 'bethe approximation corresponding'},
#  {'cluster': 22,
#   'cos_similarity': 1.0968503449768503,
#   'euc_distance': 0.6058858406066348,
#   'keyword': 'adversarial outliers'},
#  {'cluster': 11,
#   'cos_similarity': 0.9750887370065578,
#   'euc_distance': 0.6390884862202239,
#   'keyword': 'longitudinal data extracted'},
#  {'cluster': 16,
#   'cos_similarity': 0.9835588922441472,
#   'euc_distance': 0.6652830054377818,
#   'keyword': 'earlier models used'},
#  {'cluster': 27,
#   'cos_similarity': 1.1501586735196783,
#   'euc_distance': 0.3870062255075396,
#   'keyword': 'sigmoidal neural networks'},
#  {'cluster': 21,
#   'cos_similarity': 1.0434355620689943,
#   'euc_distance': 0.42658258140240635,
#   'keyword': 'general purpose algorithm'},
#  {'cluster': 24,
#   'cos_similarity': 0.981891642058503,
#   'euc_distance': 0.6158261782808304,
#   'keyword': 'clustering dna sequences'},
#  {'cluster': 23,
#   'cos_similarity': 0.9690826439279313,
#   'euc_distance': 0.6951192684212145,
#   'keyword': 'markovian rbf covariance'},
#  {'cluster': 25,
#   'cos_similarity': 0.8403822900922785,
#   'euc_distance': 0.8378522507250444,
#   'keyword': 'blind signal separation'},
#  {'cluster': 25,
#   'cos_similarity': 1.1584799037416187,
#   'euc_distance': 0.6507709946889642,
#   'keyword': 'pixel images'},
#  {'cluster': 11,
#   'cos_similarity': 1.0581748030848803,
#   'euc_distance': 0.5522480607857414,
#   'keyword': 'discrete choice data'},
#  {'cluster': 15,
#   'cos_similarity': 0.785093341505491,
#   'euc_distance': 0.8395259083132112,
#   'keyword': 'random weight networks'},
#  {'cluster': 12,
#   'cos_similarity': 1.2056262663335635,
#   'euc_distance': 0.6173239316216481,
#   'keyword': 'view features'},
#  {'cluster': 3,
#   'cos_similarity': 1.0677984533978486,
#   'euc_distance': 0.5529500884845943,
#   'keyword': 'demonstrate bilinear svms'},
#  {'cluster': 17,
#   'cos_similarity': 0.8949113073345151,
#   'euc_distance': 0.779178820381621,
#   'keyword': 'best estimator designed'},
#  {'cluster': 10,
#   'cos_similarity': 0.8842379939618016,
#   'euc_distance': 0.8052553235322019,
#   'keyword': 'balancing premature fine'},
#  {'cluster': 28,
#   'cos_similarity': 1.1242751606654766,
#   'euc_distance': 0.5805412214122839,
#   'keyword': 'synthetic neural ic'},
#  {'cluster': 23,
#   'cos_similarity': 0.8051659978281247,
#   'euc_distance': 0.8147300348382382,
#   'keyword': 'optimal controller'},
#  {'cluster': 19,
#   'cos_similarity': 1.0103666094040993,
#   'euc_distance': 0.6722984071155103,
#   'keyword': 'technique enables us'},
#  {'cluster': 11,
#   'cos_similarity': 0.8485836521730945,
#   'euc_distance': 0.752299371781718,
#   'keyword': 'telemetry collection leads'},
#  {'cluster': 21,
#   'cos_similarity': 0.9162992348388158,
#   'euc_distance': 0.6110232982600211,
#   'keyword': 'region proposal algorithms'},
#  {'cluster': 9,
#   'cos_similarity': 0.9114943226876121,
#   'euc_distance': 0.8380541661840519,
#   'keyword': 'also favor unsupervised'},
#  {'cluster': 24,
#   'cos_similarity': 1.041528517643301,
#   'euc_distance': 0.5499267498014443,
#   'keyword': 'markov boundary theorem'},
#  {'cluster': 0,
#   'cos_similarity': 0.8419209205011924,
#   'euc_distance': 0.7783440325958049,
#   'keyword': 'neural firing rate'},
#  {'cluster': 24,
#   'cos_similarity': 1.0930051990594671,
#   'euc_distance': 0.4859102024971958,
#   'keyword': 'constructing stochastic gradients'},
#  {'cluster': 0,
#   'cos_similarity': 1.0894968947703385,
#   'euc_distance': 0.5660420595740273,
#   'keyword': 'dimensional real vector'},
#  {'cluster': 27,
#   'cos_similarity': 0.9128623464517674,
#   'euc_distance': 0.6783002294732323,
#   'keyword': 'image processing architecture'},
#  {'cluster': 4,
#   'cos_similarity': 1.0385281694429311,
#   'euc_distance': 0.6248910111703263,
#   'keyword': 'trivial probability distributions'},
#  {'cluster': 20,
#   'cos_similarity': 1.0989187026859486,
#   'euc_distance': 0.7518468982083331,
#   'keyword': 'many nonparametric regressors'},
#  {'cluster': 9,
#   'cos_similarity': 0.8243054200094534,
#   'euc_distance': 0.8748743672704707,
#   'keyword': 'novel families'},
#  {'cluster': 7,
#   'cos_similarity': 0.9557618801129961,
#   'euc_distance': 0.7582247300583254,
#   'keyword': 'tighter upper bound'},
#  {'cluster': 26,
#   'cos_similarity': 1.0592175155747372,
#   'euc_distance': 0.6851293575919937,
#   'keyword': 'advice refinement'},
#  {'cluster': 26,
#   'cos_similarity': 1.092503943454072,
#   'euc_distance': 0.6616791896569121,
#   'keyword': 'recently demonstrated'},
#  {'cluster': 0,
#   'cos_similarity': 1.0172364571909605,
#   'euc_distance': 0.6353805431927568,
#   'keyword': 'geometry invariant'},
#  {'cluster': 9,
#   'cos_similarity': 0.8978330558048142,
#   'euc_distance': 0.8439295041942146,
#   'keyword': 'smoothly trade'},
#  {'cluster': 5,
#   'cos_similarity': 0.9393316848083576,
#   'euc_distance': 0.6739632311954438,
#   'keyword': 'gradient estimates'},
#  {'cluster': 0,
#   'cos_similarity': 1.0456433915332954,
#   'euc_distance': 0.6090646612885657,
#   'keyword': 'parallel coordinates'},
#  {'cluster': 26,
#   'cos_similarity': 0.9723260519328134,
#   'euc_distance': 0.7428638875208025,
#   'keyword': 'open question remains'},
#  {'cluster': 1,
#   'cos_similarity': 0.9969632459522252,
#   'euc_distance': 0.6629011737096694,
#   'keyword': 'ring array processor'},
#  {'cluster': 24,
#   'cos_similarity': 0.968258029179169,
#   'euc_distance': 0.6299240163185487,
#   'keyword': 'new analytic expressions'},
#  {'cluster': 0,
#   'cos_similarity': 1.04061125325807,
#   'euc_distance': 0.6138085999297341,
#   'keyword': 'arbitrary vectors'},
#  {'cluster': 14,
#   'cos_similarity': 1.0679693714729952,
#   'euc_distance': 0.7679029190148847,
#   'keyword': 'lexicographic decision making'},
#  {'cluster': 1,
#   'cos_similarity': 0.7992951036488775,
#   'euc_distance': 0.8138812298742253,
#   'keyword': 'hardware verification task'},
#  {'cluster': 16,
#   'cos_similarity': 0.9898011778360972,
#   'euc_distance': 0.65985301391635,
#   'keyword': 'model capacity'},
#  {'cluster': 25,
#   'cos_similarity': 0.9019811837031336,
#   'euc_distance': 0.8050259195565556,
#   'keyword': 'realistic system'},
#  {'cluster': 24,
#   'cos_similarity': 0.8498132144738441,
#   'euc_distance': 0.7412025866677621,
#   'keyword': 'made mathematical contributions'},
#  {'cluster': 21,
#   'cos_similarity': 1.0607811189329996,
#   'euc_distance': 0.3947943752475529,
#   'keyword': 'algorithm obtains'},
#  {'cluster': 21,
#   'cos_similarity': 1.0248845985462698,
#   'euc_distance': 0.45814546417517227,
#   'keyword': 'regularized learning algorithms'},
#  {'cluster': 20,
#   'cos_similarity': 0.8533450010076916,
#   'euc_distance': 0.8622782699929266,
#   'keyword': 'order smoothness term'},
#  {'cluster': 2,
#   'cos_similarity': 0.8333346497600763,
#   'euc_distance': 0.81275086774165,
#   'keyword': 'original input based'},
#  {'cluster': 15,
#   'cos_similarity': 0.9739219177448722,
#   'euc_distance': 0.7136411166825838,
#   'keyword': 'central node'},
#  {'cluster': 11,
#   'cos_similarity': 1.0524801219961213,
#   'euc_distance': 0.5586310836595172,
#   'keyword': 'development data'},
#  {'cluster': 12,
#   'cos_similarity': 0.92234566428666,
#   'euc_distance': 0.7934461520385934,
#   'keyword': '67 normal controls'},
#  {'cluster': 14,
#   'cos_similarity': 1.0319354136875694,
#   'euc_distance': 0.7846702169152334,
#   'keyword': 'explosive behavior'},
#  {'cluster': 8,
#   'cos_similarity': 1.109476022573309,
#   'euc_distance': 0.6183702883919632,
#   'keyword': 'classify accurately'},
#  {'cluster': 28,
#   'cos_similarity': 0.8269983550404806,
#   'euc_distance': 0.8079183883584145,
#   'keyword': 'working memory'},
#  {'cluster': 0,
#   'cos_similarity': 0.8120702886040032,
#   'euc_distance': 0.8001452877714236,
#   'keyword': 'contour motions'},
#  {'cluster': 12,
#   'cos_similarity': 0.994890193767413,
#   'euc_distance': 0.7522814292200409,
#   'keyword': 'temporal filters'},
#  {'cluster': 2,
#   'cos_similarity': 0.8715014862871465,
#   'euc_distance': 0.7884786167831096,
#   'keyword': 'important k coordinates'},
#  {'cluster': 26,
#   'cos_similarity': 1.0596371149365444,
#   'euc_distance': 0.6848387479718234,
#   'keyword': 'three problems'},
#  {'cluster': 16,
#   'cos_similarity': 1.0254362349856818,
#   'euc_distance': 0.6279565695481808,
#   'keyword': 'reasonable generative model'},
#  {'cluster': 22,
#   'cos_similarity': 0.9540076903846466,
#   'euc_distance': 0.7201170346115833,
#   'keyword': 'structures characterized'},
#  {'cluster': 20,
#   'cos_similarity': 1.0802875933871086,
#   'euc_distance': 0.7607872160765773,
#   'keyword': 'linear non'},
#  {'cluster': 23,
#   'cos_similarity': 0.9848141995428457,
#   'euc_distance': 0.6825383805026705,
#   'keyword': 'case bound'},
#  {'cluster': 25,
#   'cos_similarity': 1.0398691638808657,
#   'euc_distance': 0.7261860720544309,
#   'keyword': 'visual attention system'},
#  {'cluster': 22,
#   'cos_similarity': 0.7880577177344545,
#   'euc_distance': 0.833392175245232,
#   'keyword': 'whose scoring functions'},
#  {'cluster': 21,
#   'cos_similarity': 1.0041909107534772,
#   'euc_distance': 0.4909655934054891,
#   'keyword': 'free algorithm'},
#  {'cluster': 5,
#   'cos_similarity': 1.080881286868923,
#   'euc_distance': 0.527619189450858,
#   'keyword': 'efficient internal representations'},
#  {'cluster': 5,
#   'cos_similarity': 1.0192488092045542,
#   'euc_distance': 0.5957742282877171,
#   'keyword': 'node based'},
#  {'cluster': 20,
#   'cos_similarity': 0.8978692835861549,
#   'euc_distance': 0.8433301918244144,
#   'keyword': 'robot interaction'},
#  {'cluster': 22,
#   'cos_similarity': 1.078287653745667,
#   'euc_distance': 0.6219176898559332,
#   'keyword': 'sequential hypothesis testing'},
#  {'cluster': 2,
#   'cos_similarity': 0.8660652591520268,
#   'euc_distance': 0.7919812116270483,
#   'keyword': 'sequentially obtained ones'},
#  {'cluster': 20,
#   'cos_similarity': 0.7891021259948916,
#   'euc_distance': 0.8889064601513375,
#   'keyword': 'markov games'},
#  {'cluster': 16,
#   'cos_similarity': 1.0020062460141879,
#   'euc_distance': 0.6491049452121989,
#   'keyword': 'inspired models'},
#  {'cluster': 27,
#   'cos_similarity': 0.9725984627398776,
#   'euc_distance': 0.618039650656261,
#   'keyword': 'novel computational approach'},
#  {'cluster': 7,
#   'cos_similarity': 0.8700980375941262,
#   'euc_distance': 0.809199947055255,
#   'keyword': 'general margin'},
#  {'cluster': 11,
#   'cos_similarity': 1.0512906275136285,
#   'euc_distance': 0.5599552411498407,
#   'keyword': 'entire data'},
#  {'cluster': 15,
#   'cos_similarity': 1.117984831192291,
#   'euc_distance': 0.600096278338237,
#   'keyword': 'sensor networks'},
#  ...]

# %%
with open('cluster_kmeans2_sz30.csv', 'w', newline='') as f:
    header_present = False
    for word in clusters:
        if not header_present:
            w = csv.DictWriter(f, word.keys())
            w.writeheader()
            header_present = True
        w.writerow(word)

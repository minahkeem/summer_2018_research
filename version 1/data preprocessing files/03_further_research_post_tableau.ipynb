# %%
from elasticsearch import Elasticsearch

es = Elasticsearch([{'host':'nyuvis-web.poly.edu', 'port': 80, 'url_prefix':'es'}])

# %%
doc_count_year = [] #list of doc_counts by year (each entry = dictionary)

curr_yr = '1987'
done = False

while not done:
    my_dict = es.count(index="nips_papers", body={
        'query': {
            'match': {
                'year': curr_yr
            }
        }
    })
    doc_count_year.append({curr_yr:my_dict['count']})
    temp = int(curr_yr) + 1
    if temp == 2018:
        done = True
    curr_yr = str(temp)
    
doc_count_year
# Out:
# [{'1987': 90},
#  {'1988': 94},
#  {'1989': 101},
#  {'1990': 143},
#  {'1991': 144},
#  {'1992': 127},
#  {'1993': 158},
#  {'1994': 140},
#  {'1995': 152},
#  {'1996': 152},
#  {'1997': 150},
#  {'1998': 151},
#  {'1999': 150},
#  {'2000': 152},
#  {'2001': 197},
#  {'2002': 207},
#  {'2003': 198},
#  {'2004': 207},
#  {'2005': 207},
#  {'2006': 204},
#  {'2007': 217},
#  {'2008': 250},
#  {'2009': 262},
#  {'2010': 292},
#  {'2011': 306},
#  {'2012': 368},
#  {'2013': 360},
#  {'2014': 411},
#  {'2015': 403},
#  {'2016': 569},
#  {'2017': 679}]

# %%
#multi-set analysis: each year in aggregation of years contains an aggregation of significant terms
sig_terms_res = es.search(index = "nips_papers", body = {
    "size": 0,
    "aggs": {
        "keywords_by_years": {
            "terms": {
                "field": "year",
                "size": 50
            },
            "aggs": {
                "keywords": {
                    "significant_terms": {
                        "field": "title",
                        "gnd": {},
                        "size": 30
                    }
                }
            }
        }
    }
})

words_list = []
data = sig_terms_res['aggregations']['keywords_by_years']['buckets']

for year in data:
    words = year['keywords']['buckets']
    for word in words:
        if word['key'] not in words_list:
            words_list.append(word['key'])

sig_terms_res = es.search(index = "nips_papers", body = {
    "size": 0,
    "aggs": {
        "keywords_by_years": {
            "terms": {
                "field": "year",
                "size": 50
            },
            "aggs": {
                "keywords": {
                    "terms": {
                        "field": "title",
                        "include": words_list,
                        "size": len(words_list)
                    }
                }
            }
        }
    }
})

sig_terms_res
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 5, 'total': 5},
#  'aggregations': {'keywords_by_years': {'buckets': [{'doc_count': 679,
#      'key': '2017',
#      'keywords': {'buckets': [{'doc_count': 180, 'key': 'learning'},
#        {'doc_count': 85, 'key': 'network'},
#        {'doc_count': 66, 'key': 'model'},
#        {'doc_count': 63, 'key': 'neural'},
#        {'doc_count': 61, 'key': 'deep'},
#        {'doc_count': 33, 'key': 'data'},
#        {'doc_count': 32, 'key': 'algorithm'},
#        {'doc_count': 32, 'key': 'multi'},
#        {'doc_count': 29, 'key': 'optimization'},
#        {'doc_count': 27, 'key': 'gaussian'},
#        {'doc_count': 27, 'key': 'online'},
#        {'doc_count': 25, 'key': 'adversarial'},
#        {'doc_count': 25, 'key': 'inference'},
#        {'doc_count': 25, 'key': 'stochastic'},
#        {'doc_count': 24, 'key': 'reinforcement'},
#        {'doc_count': 22, 'key': 'dynamic'},
#        {'doc_count': 22, 'key': 'efficient'},
#        {'doc_count': 22, 'key': 'method'},
#        {'doc_count': 22, 'key': 'variational'},
#        {'doc_count': 21, 'key': 'analysi'},
#        {'doc_count': 20, 'key': 'bayesian'},
#        {'doc_count': 20, 'key': 'estimation'},
#        {'doc_count': 20, 'key': 'kernel'},
#        {'doc_count': 19, 'key': 'based'},
#        {'doc_count': 19, 'key': 'generative'},
#        {'doc_count': 19, 'key': 'linear'},
#        {'doc_count': 19, 'key': 'recurrent'},
#        {'doc_count': 18, 'key': 'clustering'},
#        {'doc_count': 18, 'key': 'image'},
#        {'doc_count': 18, 'key': 'processe'},
#        {'doc_count': 18, 'key': 'representation'},
#        {'doc_count': 17, 'key': 'adaptive'},
#        {'doc_count': 17, 'key': 'bandit'},
#        {'doc_count': 17, 'key': 'graph'},
#        {'doc_count': 17, 'key': 'prediction'},
#        {'doc_count': 17, 'key': 'regression'},
#        {'doc_count': 17, 'key': 'time'},
#        {'doc_count': 16, 'key': 'approximation'},
#        {'doc_count': 16, 'key': 'training'},
#        {'doc_count': 15, 'key': 'sparse'},
#        {'doc_count': 15, 'key': 'structured'},
#        {'doc_count': 14, 'key': 'gan'},
#        {'doc_count': 14, 'key': 'system'},
#        {'doc_count': 13, 'key': 'application'},
#        {'doc_count': 13, 'key': 'bound'},
#        {'doc_count': 13, 'key': 'function'},
#        {'doc_count': 13, 'key': 'scalable'},
#        {'doc_count': 12, 'key': 'matrix'},
#        {'doc_count': 12, 'key': 'sampling'},
#        {'doc_count': 11, 'key': 'approach'},
#        {'doc_count': 11, 'key': 'embedding'},
#        {'doc_count': 11, 'key': 'large'},
#        {'doc_count': 11, 'key': 'minimization'},
#        {'doc_count': 11, 'key': 'process'},
#        {'doc_count': 11, 'key': 'random'},
#        {'doc_count': 11, 'key': 'scale'},
#        {'doc_count': 11, 'key': 'visual'},
#        {'doc_count': 10, 'key': 'convex'},
#        {'doc_count': 10, 'key': 'fast'},
#        {'doc_count': 10, 'key': 'hierarchical'},
#        {'doc_count': 10, 'key': 'machine'},
#        {'doc_count': 10, 'key': 'net'},
#        {'doc_count': 10, 'key': 'policy'},
#        {'doc_count': 10, 'key': 'problem'},
#        {'doc_count': 10, 'key': 'robust'},
#        {'doc_count': 10, 'key': 'sample'},
#        {'doc_count': 10, 'key': 'supervised'},
#        {'doc_count': 9, 'key': 'agent'},
#        {'doc_count': 9, 'key': 'continuous'},
#        {'doc_count': 9, 'key': 'convolutional'},
#        {'doc_count': 9, 'key': 'distribution'},
#        {'doc_count': 9, 'key': 'selection'},
#        {'doc_count': 9, 'key': 'semi'},
#        {'doc_count': 8, 'key': 'attention'},
#        {'doc_count': 8, 'key': 'classification'},
#        {'doc_count': 8, 'key': 'dimensional'},
#        {'doc_count': 8, 'key': 'graphical'},
#        {'doc_count': 8, 'key': 'high'},
#        {'doc_count': 8, 'key': 'latent'},
#        {'doc_count': 8, 'key': 'low'},
#        {'doc_count': 8, 'key': 'markov'},
#        {'doc_count': 8, 'key': 'matching'},
#        {'doc_count': 8, 'key': 'rank'},
#        {'doc_count': 8, 'key': 'search'},
#        {'doc_count': 8, 'key': 'submodular'},
#        {'doc_count': 7, 'key': 'coordinate'},
#        {'doc_count': 7, 'key': 'decision'},
#        {'doc_count': 7, 'key': 'domain'},
#        {'doc_count': 7, 'key': 'error'},
#        {'doc_count': 7, 'key': 'filtering'},
#        {'doc_count': 7, 'key': 'label'},
#        {'doc_count': 7, 'key': 'metric'},
#        {'doc_count': 7, 'key': 'point'},
#        {'doc_count': 7, 'key': 'polynomial'},
#        {'doc_count': 7, 'key': 'probabilistic'},
#        {'doc_count': 7, 'key': 'risk'},
#        {'doc_count': 7, 'key': 'state'},
#        {'doc_count': 7, 'key': 'structure'},
#        {'doc_count': 7, 'key': 'task'},
#        {'doc_count': 6, 'key': 'approximate'},
#        {'doc_count': 6, 'key': 'fairness'},
#        {'doc_count': 6, 'key': 'inverse'},
#        {'doc_count': 6, 'key': 'language'},
#        {'doc_count': 6, 'key': 'memory'},
#        {'doc_count': 6, 'key': 'mixture'},
#        {'doc_count': 6, 'key': 'modeling'},
#        {'doc_count': 6, 'key': 'noise'},
#        {'doc_count': 6, 'key': 'order'},
#        {'doc_count': 6, 'key': 'parallel'},
#        {'doc_count': 6, 'key': 'recognition'},
#        {'doc_count': 6, 'key': 'regularized'},
#        {'doc_count': 6, 'key': 'sequential'},
#        {'doc_count': 6, 'key': 'spectral'},
#        {'doc_count': 6, 'key': 'streaming'},
#        {'doc_count': 6, 'key': 'transfer'},
#        {'doc_count': 5, 'key': 'active'},
#        {'doc_count': 5, 'key': 'boosting'},
#        {'doc_count': 5, 'key': 'case'},
#        {'doc_count': 5, 'key': 'collaborative'},
#        {'doc_count': 5, 'key': 'conditional'},
#        {'doc_count': 5, 'key': 'constrained'},
#        {'doc_count': 5, 'key': 'correlation'},
#        {'doc_count': 5, 'key': 'decomposition'},
#        {'doc_count': 5, 'key': 'density'},
#        {'doc_count': 5, 'key': 'design'},
#        {'doc_count': 5, 'key': 'detection'},
#        {'doc_count': 5, 'key': 'discriminative'},
#        {'doc_count': 5, 'key': 'distributed'},
#        {'doc_count': 5, 'key': 'dynamical'},
#        {'doc_count': 5, 'key': 'factorization'},
#        {'doc_count': 5, 'key': 'finite'},
#        {'doc_count': 5, 'key': 'gated'},
#        {'doc_count': 5, 'key': 'general'},
#        {'doc_count': 5, 'key': 'generalization'},
#        {'doc_count': 5, 'key': 'guarantees'},
#        {'doc_count': 5, 'key': 'identification'},
#        {'doc_count': 5, 'key': 'invariant'},
#        {'doc_count': 5, 'key': 'local'},
#        {'doc_count': 5, 'key': 'multiple'},
#        {'doc_count': 5, 'key': 'objective'},
#        {'doc_count': 5, 'key': 'output'},
#        {'doc_count': 5, 'key': 'parameter'},
#        {'doc_count': 5, 'key': 'population'},
#        {'doc_count': 5, 'key': 'predicting'},
#        {'doc_count': 5, 'key': 'predictive'},
#        {'doc_count': 5, 'key': 'propagation'},
#        {'doc_count': 5, 'key': 'ranking'},
#        {'doc_count': 5, 'key': 'reduction'},
#        {'doc_count': 5, 'key': 'safe'},
#        {'doc_count': 5, 'key': 'simple'},
#        {'doc_count': 5, 'key': 'space'},
#        {'doc_count': 5, 'key': 'tensor'},
#        {'doc_count': 5, 'key': 'theory'},
#        {'doc_count': 5, 'key': 'variable'},
#        {'doc_count': 4, 'key': 'acceleration'},
#        {'doc_count': 4, 'key': 'accuracy'},
#        {'doc_count': 4, 'key': 'action'},
#        {'doc_count': 4, 'key': 'coding'},
#        {'doc_count': 4, 'key': 'computation'},
#        {'doc_count': 4, 'key': 'disentangled'},
#        {'doc_count': 4, 'key': 'evaluation'},
#        {'doc_count': 4, 'key': 'feedback'},
#        {'doc_count': 4, 'key': 'generation'},
#        {'doc_count': 4, 'key': 'geometric'},
#        {'doc_count': 4, 'key': 'interpretable'},
#        {'doc_count': 4, 'key': 'knowledge'},
#        {'doc_count': 4, 'key': 'margin'},
#        {'doc_count': 4, 'key': 'nonparametric'},
#        {'doc_count': 4, 'key': 'parametric'},
#        {'doc_count': 4, 'key': 'practical'},
#        {'doc_count': 4, 'key': 'programming'},
#        {'doc_count': 4, 'key': 'property'},
#        {'doc_count': 4, 'key': 'real'},
#        {'doc_count': 4, 'key': 'regularization'},
#        {'doc_count': 4, 'key': 'rule'},
#        {'doc_count': 4, 'key': 'set'},
#        {'doc_count': 4, 'key': 'shot'},
#        {'doc_count': 4, 'key': 'size'},
#        {'doc_count': 4, 'key': 'stable'},
#        {'doc_count': 4, 'key': 'study'},
#        {'doc_count': 4, 'key': 'testing'},
#        {'doc_count': 4, 'key': 'tree'},
#        {'doc_count': 4, 'key': 'video'},
#        {'doc_count': 3, 'key': 'activity'},
#        {'doc_count': 3, 'key': 'additive'},
#        {'doc_count': 3, 'key': 'assumption'},
#        {'doc_count': 3, 'key': 'baye'},
#        {'doc_count': 3, 'key': 'cold'},
#        {'doc_count': 3, 'key': 'component'},
#        {'doc_count': 3, 'key': 'contextual'},
#        {'doc_count': 3, 'key': 'control'},
#        {'doc_count': 3, 'key': 'covariance'},
#        {'doc_count': 3, 'key': 'estimate'},
#        {'doc_count': 3, 'key': 'estimating'},
#        {'doc_count': 3, 'key': 'expectation'},
#        {'doc_count': 3, 'key': 'expert'},
#        {'doc_count': 3, 'key': 'exponential'},
#        {'doc_count': 3, 'key': 'frank'},
#        {'doc_count': 3, 'key': 'group'},
#        {'doc_count': 3, 'key': 'hidden'},
#        {'doc_count': 3, 'key': 'implicit'},
#        {'doc_count': 3, 'key': 'independent'},
#        {'doc_count': 3, 'key': 'joint'},
#        {'doc_count': 3, 'key': 'manifold'},
#        {'doc_count': 3, 'key': 'natural'},
#        {'doc_count': 3, 'key': 'object'},
#        {'doc_count': 3, 'key': 'prior'},
#        {'doc_count': 3, 'key': 'private'},
#        {'doc_count': 3, 'key': 'product'},
#        {'doc_count': 3, 'key': 'response'},
#        {'doc_count': 3, 'key': 'reward'},
#        {'doc_count': 3, 'key': 'robustness'},
#        {'doc_count': 3, 'key': 'sparsity'},
#        {'doc_count': 3, 'key': 'speech'},
#        {'doc_count': 3, 'key': 'statistical'},
#        {'doc_count': 3, 'key': 'strategy'},
#        {'doc_count': 3, 'key': 'subset'},
#        {'doc_count': 3, 'key': 'subspace'},
#        {'doc_count': 3, 'key': 'symmetric'},
#        {'doc_count': 3, 'key': 'transformation'},
#        {'doc_count': 3, 'key': 'trees'},
#        {'doc_count': 3, 'key': 'unified'},
#        {'doc_count': 3, 'key': 'unknown'},
#        {'doc_count': 3, 'key': 'vector'},
#        {'doc_count': 3, 'key': 'weighted'},
#        {'doc_count': 3, 'key': 'wolfe'},
#        {'doc_count': 2, 'key': '2'},
#        {'doc_count': 2, 'key': '3d'},
#        {'doc_count': 2, 'key': 'adaptation'},
#        {'doc_count': 2, 'key': 'armed'},
#        {'doc_count': 2, 'key': 'associative'},
#        {'doc_count': 2, 'key': 'asynchronous'},
#        {'doc_count': 2, 'key': 'average'},
#        {'doc_count': 2, 'key': 'backpropagation'},
#        {'doc_count': 2, 'key': 'behavior'},
#        {'doc_count': 2, 'key': 'carlo'},
#        {'doc_count': 2, 'key': 'cascade'},
#        {'doc_count': 2, 'key': 'class'},
#        {'doc_count': 2, 'key': 'classifier'},
#        {'doc_count': 2, 'key': 'code'},
#        {'doc_count': 2, 'key': 'comparison'},
#        {'doc_count': 2, 'key': 'completion'},
#        {'doc_count': 2, 'key': 'computer'},
#        {'doc_count': 2, 'key': 'constraint'},
#        {'doc_count': 2, 'key': 'context'},
#        {'doc_count': 2, 'key': 'crowdsourcing'},
#        {'doc_count': 2, 'key': 'dataset'},
#        {'doc_count': 2, 'key': 'dependent'},
#        {'doc_count': 2, 'key': 'differential'},
#        {'doc_count': 2, 'key': 'direction'},
#        {'doc_count': 2, 'key': 'discrimination'},
#        {'doc_count': 2, 'key': 'driven'},
#        {'doc_count': 2, 'key': 'eeg'},
#        {'doc_count': 2, 'key': 'effect'},
#        {'doc_count': 2, 'key': 'em'},
#        {'doc_count': 2, 'key': 'factor'},
#        {'doc_count': 2, 'key': 'field'},
#        {'doc_count': 2, 'key': 'filter'},
#        {'doc_count': 2, 'key': 'fmri'},
#        {'doc_count': 2, 'key': 'forest'},
#        {'doc_count': 2, 'key': 'functional'},
#        {'doc_count': 2, 'key': 'hashing'},
#        {'doc_count': 2, 'key': 'human'},
#        {'doc_count': 2, 'key': 'hybrid'},
#        {'doc_count': 2, 'key': 'improving'},
#        {'doc_count': 2, 'key': 'infinite'},
#        {'doc_count': 2, 'key': 'interface'},
#        {'doc_count': 2, 'key': 'layer'},
#        {'doc_count': 2, 'key': 'mapping'},
#        {'doc_count': 2, 'key': 'maximum'},
#        {'doc_count': 2, 'key': 'mcmc'},
#        {'doc_count': 2, 'key': 'monte'},
#        {'doc_count': 2, 'key': 'motion'},
#        {'doc_count': 2, 'key': 'neighbor'},
#        {'doc_count': 2, 'key': 'optimizing'},
#        {'doc_count': 2, 'key': 'path'},
#        {'doc_count': 2, 'key': 'penalty'},
#        {'doc_count': 2, 'key': 'permutation'},
#        {'doc_count': 2, 'key': 'positive'},
#        {'doc_count': 2, 'key': 'posterior'},
#        {'doc_count': 2, 'key': 'probability'},
#        {'doc_count': 2, 'key': 'processing'},
#        {'doc_count': 2, 'key': 'recovery'},
#        {'doc_count': 2, 'key': 'selective'},
#        {'doc_count': 2, 'key': 'setting'},
#        {'doc_count': 2, 'key': 'sgd'},
#        {'doc_count': 2, 'key': 'signal'},
#        {'doc_count': 2, 'key': 'similarity'},
#        {'doc_count': 2, 'key': 'slow'},
#        {'doc_count': 2, 'key': 'solving'},
#        {'doc_count': 2, 'key': 'source'},
#        {'doc_count': 2, 'key': 'spatial'},
#        {'doc_count': 2, 'key': 'spike'},
#        {'doc_count': 2, 'key': 'statistic'},
#        {'doc_count': 2, 'key': 'support'},
#        {'doc_count': 2, 'key': 'temporal'},
#        {'doc_count': 2, 'key': 'uncertainty'},
#        {'doc_count': 2, 'key': 'unlabeled'},
#        {'doc_count': 2, 'key': 'weight'},
#        {'doc_count': 2, 'key': 'word'},
#        {'doc_count': 1, 'key': 'alignment'},
#        {'doc_count': 1, 'key': 'architecture'},
#        {'doc_count': 1, 'key': 'array'},
#        {'doc_count': 1, 'key': 'attribute'},
#        {'doc_count': 1, 'key': 'augmented'},
#        {'doc_count': 1, 'key': 'automatic'},
#        {'doc_count': 1, 'key': 'balanced'},
#        {'doc_count': 1, 'key': 'belief'},
#        {'doc_count': 1, 'key': 'budget'},
#        {'doc_count': 1, 'key': 'circuit'},
#        {'doc_count': 1, 'key': 'competitive'},
#        {'doc_count': 1, 'key': 'computational'},
#        {'doc_count': 1, 'key': 'conjugate'},
#        {'doc_count': 1, 'key': 'connection'},
#        {'doc_count': 1, 'key': 'contour'},
#        {'doc_count': 1, 'key': 'cortical'},
#        {'doc_count': 1, 'key': 'cover'},
#        {'doc_count': 1, 'key': 'critic'},
#        {'doc_count': 1, 'key': 'curve'},
#        {'doc_count': 1, 'key': 'decomposable'},
#        {'doc_count': 1, 'key': 'delay'},
#        {'doc_count': 1, 'key': 'dependence'},
#        {'doc_count': 1, 'key': 'dictionary'},
#        {'doc_count': 1, 'key': 'dimension'},
#        {'doc_count': 1, 'key': 'dirichlet'},
#        {'doc_count': 1, 'key': 'distance'},
#        {'doc_count': 1, 'key': 'dropout'},
#        {'doc_count': 1, 'key': 'electronic'},
#        {'doc_count': 1, 'key': 'environment'},
#        {'doc_count': 1, 'key': 'factored'},
#        {'doc_count': 1, 'key': 'guided'},
#        {'doc_count': 1, 'key': 'hmm'},
#        {'doc_count': 1, 'key': 'identifying'},
#        {'doc_count': 1, 'key': 'incremental'},
#        {'doc_count': 1, 'key': 'induction'},
#        {'doc_count': 1, 'key': 'inferring'},
#        {'doc_count': 1, 'key': 'input'},
#        {'doc_count': 1, 'key': 'laplacian'},
#        {'doc_count': 1, 'key': 'lasso'},
#        {'doc_count': 1, 'key': 'law'},
#        {'doc_count': 1, 'key': 'learn'},
#        {'doc_count': 1, 'key': 'localization'},
#        {'doc_count': 1, 'key': 'making'},
#        {'doc_count': 1, 'key': 'map'},
#        {'doc_count': 1, 'key': 'matrice'},
#        {'doc_count': 1, 'key': 'maximizing'},
#        {'doc_count': 1, 'key': 'measure'},
#        {'doc_count': 1, 'key': 'mirror'},
#        {'doc_count': 1, 'key': 'modelling'},
#        {'doc_count': 1, 'key': 'movement'},
#        {'doc_count': 1, 'key': 'multiclass'},
#        {'doc_count': 1, 'key': 'navigation'},
#        {'doc_count': 1, 'key': 'neuron'},
#        {'doc_count': 1, 'key': 'neuronal'},
#        {'doc_count': 1, 'key': 'newton'},
#        {'doc_count': 1, 'key': 'noisy'},
#        {'doc_count': 1, 'key': 'observation'},
#        {'doc_count': 1, 'key': 'optimistic'},
#        {'doc_count': 1, 'key': 'overlapping'},
#        {'doc_count': 1, 'key': 'partially'},
#        {'doc_count': 1, 'key': 'pattern'},
#        {'doc_count': 1, 'key': 'perceptron'},
#        {'doc_count': 1, 'key': 'performance'},
#        {'doc_count': 1, 'key': 'poisson'},
#        {'doc_count': 1, 'key': 'pomdp'},
#        {'doc_count': 1, 'key': 'primal'},
#        {'doc_count': 1, 'key': 'protein'},
#        {'doc_count': 1, 'key': 'recording'},
#        {'doc_count': 1, 'key': 'relational'},
#        {'doc_count': 1, 'key': 'relaxation'},
#        {'doc_count': 1, 'key': 'resolution'},
#        {'doc_count': 1, 'key': 'scaling'},
#        {'doc_count': 1, 'key': 'second'},
#        {'doc_count': 1, 'key': 'segmentation'},
#        {'doc_count': 1, 'key': 'sensing'},
#        {'doc_count': 1, 'key': 'sensory'},
#        {'doc_count': 1, 'key': 'sery'},
#        {'doc_count': 1, 'key': 'simulation'},
#        {'doc_count': 1, 'key': 'smooth'},
#        {'doc_count': 1, 'key': 'sound'},
#        {'doc_count': 1, 'key': 'specific'},
#        {'doc_count': 1, 'key': 'stimulus'},
#        {'doc_count': 1, 'key': 'string'},
#        {'doc_count': 1, 'key': 'thompson'},
#        {'doc_count': 1, 'key': 'topic'},
#        {'doc_count': 1, 'key': 'tracking'},
#        {'doc_count': 1, 'key': 'unit'}],
#       'doc_count_error_upper_bound': 0,
#       'sum_other_doc_count': 0}},
#     {'doc_count': 569,
#      'key': '2016',
#      'keywords': {'buckets': [{'doc_count': 121, 'key': 'learning'},
#        {'doc_count': 73, 'key': 'network'},
#        {'doc_count': 61, 'key': 'model'},
#        {'doc_count': 47, 'key': 'neural'},
#        {'doc_count': 43, 'key': 'deep'},
#        {'doc_count': 39, 'key': 'optimization'},
#        {'doc_count': 38, 'key': 'stochastic'},
#        {'doc_count': 26, 'key': 'inference'},
#        {'doc_count': 26, 'key': 'method'},
#        {'doc_count': 23, 'key': 'bayesian'},
#        {'doc_count': 22, 'key': 'data'},
#        {'doc_count': 21, 'key': 'based'},
#        {'doc_count': 20, 'key': 'fast'},
#        {'doc_count': 19, 'key': 'bandit'},
#        {'doc_count': 19, 'key': 'estimation'},
#        {'doc_count': 19, 'key': 'online'},
#        {'doc_count': 18, 'key': 'efficient'},
#        {'doc_count': 18, 'key': 'linear'},
#        {'doc_count': 18, 'key': 'sparse'},
#        {'doc_count': 18, 'key': 'structured'},
#        {'doc_count': 18, 'key': 'variational'},
#        {'doc_count': 17, 'key': 'dynamic'},
#        {'doc_count': 16, 'key': 'adaptive'},
#        {'doc_count': 16, 'key': 'image'},
#        {'doc_count': 16, 'key': 'matrix'},
#        {'doc_count': 16, 'key': 'prediction'},
#        {'doc_count': 15, 'key': 'convex'},
#        {'doc_count': 15, 'key': 'convolutional'},
#        {'doc_count': 15, 'key': 'multi'},
#        {'doc_count': 15, 'key': 'training'},
#        {'doc_count': 14, 'key': 'function'},
#        {'doc_count': 14, 'key': 'kernel'},
#        {'doc_count': 14, 'key': 'probabilistic'},
#        {'doc_count': 13, 'key': 'representation'},
#        {'doc_count': 12, 'key': 'analysi'},
#        {'doc_count': 12, 'key': 'random'},
#        {'doc_count': 12, 'key': 'regression'},
#        {'doc_count': 11, 'key': 'adversarial'},
#        {'doc_count': 11, 'key': 'algorithm'},
#        {'doc_count': 11, 'key': 'approach'},
#        {'doc_count': 11, 'key': 'bound'},
#        {'doc_count': 11, 'key': 'gaussian'},
#        {'doc_count': 11, 'key': 'generative'},
#        {'doc_count': 11, 'key': 'large'},
#        {'doc_count': 11, 'key': 'problem'},
#        {'doc_count': 11, 'key': 'recovery'},
#        {'doc_count': 11, 'key': 'recurrent'},
#        {'doc_count': 11, 'key': 'submodular'},
#        {'doc_count': 11, 'key': 'supervised'},
#        {'doc_count': 11, 'key': 'time'},
#        {'doc_count': 10, 'key': 'clustering'},
#        {'doc_count': 10, 'key': 'constraint'},
#        {'doc_count': 10, 'key': 'embedding'},
#        {'doc_count': 10, 'key': 'graph'},
#        {'doc_count': 10, 'key': 'local'},
#        {'doc_count': 10, 'key': 'metric'},
#        {'doc_count': 10, 'key': 'sampling'},
#        {'doc_count': 10, 'key': 'space'},
#        {'doc_count': 9, 'key': 'application'},
#        {'doc_count': 9, 'key': 'decision'},
#        {'doc_count': 9, 'key': 'robust'},
#        {'doc_count': 9, 'key': 'sample'},
#        {'doc_count': 9, 'key': 'spectral'},
#        {'doc_count': 9, 'key': 'structure'},
#        {'doc_count': 8, 'key': 'distributed'},
#        {'doc_count': 8, 'key': 'finite'},
#        {'doc_count': 8, 'key': 'graphical'},
#        {'doc_count': 8, 'key': 'joint'},
#        {'doc_count': 8, 'key': 'latent'},
#        {'doc_count': 8, 'key': 'markov'},
#        {'doc_count': 8, 'key': 'object'},
#        {'doc_count': 8, 'key': 'order'},
#        {'doc_count': 8, 'key': 'process'},
#        {'doc_count': 8, 'key': 'recognition'},
#        {'doc_count': 8, 'key': 'statistical'},
#        {'doc_count': 8, 'key': 'tensor'},
#        {'doc_count': 8, 'key': 'visual'},
#        {'doc_count': 7, 'key': 'active'},
#        {'doc_count': 7, 'key': 'completion'},
#        {'doc_count': 7, 'key': 'conditional'},
#        {'doc_count': 7, 'key': 'decomposition'},
#        {'doc_count': 7, 'key': 'domain'},
#        {'doc_count': 7, 'key': 'high'},
#        {'doc_count': 7, 'key': 'machine'},
#        {'doc_count': 7, 'key': 'matching'},
#        {'doc_count': 7, 'key': 'minimization'},
#        {'doc_count': 7, 'key': 'modeling'},
#        {'doc_count': 7, 'key': 'neuron'},
#        {'doc_count': 7, 'key': 'processe'},
#        {'doc_count': 7, 'key': 'rank'},
#        {'doc_count': 7, 'key': 'reinforcement'},
#        {'doc_count': 7, 'key': 'system'},
#        {'doc_count': 6, 'key': '3d'},
#        {'doc_count': 6, 'key': 'factorization'},
#        {'doc_count': 6, 'key': 'general'},
#        {'doc_count': 6, 'key': 'hierarchical'},
#        {'doc_count': 6, 'key': 'memory'},
#        {'doc_count': 6, 'key': 'multiple'},
#        {'doc_count': 6, 'key': 'parameter'},
#        {'doc_count': 6, 'key': 'reduction'},
#        {'doc_count': 6, 'key': 'scale'},
#        {'doc_count': 6, 'key': 'selection'},
#        {'doc_count': 6, 'key': 'sparsity'},
#        {'doc_count': 6, 'key': 'variable'},
#        {'doc_count': 5, 'key': 'attention'},
#        {'doc_count': 5, 'key': 'budget'},
#        {'doc_count': 5, 'key': 'carlo'},
#        {'doc_count': 5, 'key': 'chain'},
#        {'doc_count': 5, 'key': 'classification'},
#        {'doc_count': 5, 'key': 'cluster'},
#        {'doc_count': 5, 'key': 'detection'},
#        {'doc_count': 5, 'key': 'interpretable'},
#        {'doc_count': 5, 'key': 'making'},
#        {'doc_count': 5, 'key': 'monte'},
#        {'doc_count': 5, 'key': 'net'},
#        {'doc_count': 5, 'key': 'observation'},
#        {'doc_count': 5, 'key': 'oracle'},
#        {'doc_count': 5, 'key': 'pca'},
#        {'doc_count': 5, 'key': 'regularization'},
#        {'doc_count': 5, 'key': 'risk'},
#        {'doc_count': 5, 'key': 'robustness'},
#        {'doc_count': 5, 'key': 'scalable'},
#        {'doc_count': 5, 'key': 'segmentation'},
#        {'doc_count': 5, 'key': 'set'},
#        {'doc_count': 5, 'key': 'single'},
#        {'doc_count': 4, 'key': 'action'},
#        {'doc_count': 4, 'key': 'approximate'},
#        {'doc_count': 4, 'key': 'architecture'},
#        {'doc_count': 4, 'key': 'asynchronous'},
#        {'doc_count': 4, 'key': 'belief'},
#        {'doc_count': 4, 'key': 'contextual'},
#        {'doc_count': 4, 'key': 'continuous'},
#        {'doc_count': 4, 'key': 'dimensional'},
#        {'doc_count': 4, 'key': 'estimating'},
#        {'doc_count': 4, 'key': 'feedback'},
#        {'doc_count': 4, 'key': 'field'},
#        {'doc_count': 4, 'key': 'label'},
#        {'doc_count': 4, 'key': 'map'},
#        {'doc_count': 4, 'key': 'maximizing'},
#        {'doc_count': 4, 'key': 'maximum'},
#        {'doc_count': 4, 'key': 'mcmc'},
#        {'doc_count': 4, 'key': 'neighbor'},
#        {'doc_count': 4, 'key': 'nonparametric'},
#        {'doc_count': 4, 'key': 'objective'},
#        {'doc_count': 4, 'key': 'parallel'},
#        {'doc_count': 4, 'key': 'point'},
#        {'doc_count': 4, 'key': 'policy'},
#        {'doc_count': 4, 'key': 'prior'},
#        {'doc_count': 4, 'key': 'product'},
#        {'doc_count': 4, 'key': 'propagation'},
#        {'doc_count': 4, 'key': 'relaxation'},
#        {'doc_count': 4, 'key': 'response'},
#        {'doc_count': 4, 'key': 'safe'},
#        {'doc_count': 4, 'key': 'search'},
#        {'doc_count': 4, 'key': 'sequential'},
#        {'doc_count': 4, 'key': 'similarity'},
#        {'doc_count': 4, 'key': 'spike'},
#        {'doc_count': 4, 'key': 'state'},
#        {'doc_count': 4, 'key': 'strategic'},
#        {'doc_count': 4, 'key': 'structural'},
#        {'doc_count': 4, 'key': 'theory'},
#        {'doc_count': 4, 'key': 'tree'},
#        {'doc_count': 4, 'key': 'unified'},
#        {'doc_count': 4, 'key': 'video'},
#        {'doc_count': 3, 'key': 'adaptation'},
#        {'doc_count': 3, 'key': 'aggregation'},
#        {'doc_count': 3, 'key': 'approximation'},
#        {'doc_count': 3, 'key': 'armed'},
#        {'doc_count': 3, 'key': 'augmented'},
#        {'doc_count': 3, 'key': 'behavior'},
#        {'doc_count': 3, 'key': 'blind'},
#        {'doc_count': 3, 'key': 'boosting'},
#        {'doc_count': 3, 'key': 'class'},
#        {'doc_count': 3, 'key': 'code'},
#        {'doc_count': 3, 'key': 'collaborative'},
#        {'doc_count': 3, 'key': 'composition'},
#        {'doc_count': 3, 'key': 'coordinate'},
#        {'doc_count': 3, 'key': 'crowdsourcing'},
#        {'doc_count': 3, 'key': 'density'},
#        {'doc_count': 3, 'key': 'dimension'},
#        {'doc_count': 3, 'key': 'distribution'},
#        {'doc_count': 3, 'key': 'error'},
#        {'doc_count': 3, 'key': 'exploiting'},
#        {'doc_count': 3, 'key': 'exponential'},
#        {'doc_count': 3, 'key': 'factor'},
#        {'doc_count': 3, 'key': 'filtering'},
#        {'doc_count': 3, 'key': 'forward'},
#        {'doc_count': 3, 'key': 'functional'},
#        {'doc_count': 3, 'key': 'guided'},
#        {'doc_count': 3, 'key': 'hashing'},
#        {'doc_count': 3, 'key': 'human'},
#        {'doc_count': 3, 'key': 'inverse'},
#        {'doc_count': 3, 'key': 'learn'},
#        {'doc_count': 3, 'key': 'low'},
#        {'doc_count': 3, 'key': 'measure'},
#        {'doc_count': 3, 'key': 'mixture'},
#        {'doc_count': 3, 'key': 'noise'},
#        {'doc_count': 3, 'key': 'parametric'},
#        {'doc_count': 3, 'key': 'path'},
#        {'doc_count': 3, 'key': 'posterior'},
#        {'doc_count': 3, 'key': 'programming'},
#        {'doc_count': 3, 'key': 'regularized'},
#        {'doc_count': 3, 'key': 'resolution'},
#        {'doc_count': 3, 'key': 'reward'},
#        {'doc_count': 3, 'key': 'semi'},
#        {'doc_count': 3, 'key': 'sensing'},
#        {'doc_count': 3, 'key': 'simple'},
#        {'doc_count': 3, 'key': 'smooth'},
#        {'doc_count': 3, 'key': 'solving'},
#        {'doc_count': 3, 'key': 'subspace'},
#        {'doc_count': 3, 'key': 'supervision'},
#        {'doc_count': 3, 'key': 'temporal'},
#        {'doc_count': 3, 'key': 'testing'},
#        {'doc_count': 3, 'key': 'topic'},
#        {'doc_count': 3, 'key': 'unlabeled'},
#        {'doc_count': 3, 'key': 'weight'},
#        {'doc_count': 3, 'key': 'word'},
#        {'doc_count': 2, 'key': 'acceleration'},
#        {'doc_count': 2, 'key': 'alignment'},
#        {'doc_count': 2, 'key': 'backpropagation'},
#        {'doc_count': 2, 'key': 'baye'},
#        {'doc_count': 2, 'key': 'case'},
#        {'doc_count': 2, 'key': 'choice'},
#        {'doc_count': 2, 'key': 'circuit'},
#        {'doc_count': 2, 'key': 'classifier'},
#        {'doc_count': 2, 'key': 'comparison'},
#        {'doc_count': 2, 'key': 'component'},
#        {'doc_count': 2, 'key': 'computation'},
#        {'doc_count': 2, 'key': 'computational'},
#        {'doc_count': 2, 'key': 'constrained'},
#        {'doc_count': 2, 'key': 'context'},
#        {'doc_count': 2, 'key': 'control'},
#        {'doc_count': 2, 'key': 'covariance'},
#        {'doc_count': 2, 'key': 'cover'},
#        {'doc_count': 2, 'key': 'dataset'},
#        {'doc_count': 2, 'key': 'design'},
#        {'doc_count': 2, 'key': 'determinantal'},
#        {'doc_count': 2, 'key': 'differential'},
#        {'doc_count': 2, 'key': 'discriminative'},
#        {'doc_count': 2, 'key': 'driven'},
#        {'doc_count': 2, 'key': 'dropout'},
#        {'doc_count': 2, 'key': 'dynamical'},
#        {'doc_count': 2, 'key': 'entropy'},
#        {'doc_count': 2, 'key': 'environment'},
#        {'doc_count': 2, 'key': 'filter'},
#        {'doc_count': 2, 'key': 'gan'},
#        {'doc_count': 2, 'key': 'generation'},
#        {'doc_count': 2, 'key': 'geometric'},
#        {'doc_count': 2, 'key': 'group'},
#        {'doc_count': 2, 'key': 'guarantees'},
#        {'doc_count': 2, 'key': 'hidden'},
#        {'doc_count': 2, 'key': 'identification'},
#        {'doc_count': 2, 'key': 'identifying'},
#        {'doc_count': 2, 'key': 'incremental'},
#        {'doc_count': 2, 'key': 'infinite'},
#        {'doc_count': 2, 'key': 'labeled'},
#        {'doc_count': 2, 'key': 'language'},
#        {'doc_count': 2, 'key': 'laplacian'},
#        {'doc_count': 2, 'key': 'layer'},
#        {'doc_count': 2, 'key': 'matrice'},
#        {'doc_count': 2, 'key': 'natural'},
#        {'doc_count': 2, 'key': 'navigation'},
#        {'doc_count': 2, 'key': 'newton'},
#        {'doc_count': 2, 'key': 'noisy'},
#        {'doc_count': 2, 'key': 'optimality'},
#        {'doc_count': 2, 'key': 'optimistic'},
#        {'doc_count': 2, 'key': 'optimizing'},
#        {'doc_count': 2, 'key': 'poisson'},
#        {'doc_count': 2, 'key': 'polynomial'},
#        {'doc_count': 2, 'key': 'population'},
#        {'doc_count': 2, 'key': 'positive'},
#        {'doc_count': 2, 'key': 'predicting'},
#        {'doc_count': 2, 'key': 'primal'},
#        {'doc_count': 2, 'key': 'private'},
#        {'doc_count': 2, 'key': 'probability'},
#        {'doc_count': 2, 'key': 'rule'},
#        {'doc_count': 2, 'key': 'scaling'},
#        {'doc_count': 2, 'key': 'sery'},
#        {'doc_count': 2, 'key': 'shot'},
#        {'doc_count': 2, 'key': 'size'},
#        {'doc_count': 2, 'key': 'sound'},
#        {'doc_count': 2, 'key': 'symmetric'},
#        {'doc_count': 2, 'key': 'task'},
#        {'doc_count': 2, 'key': 'technique'},
#        {'doc_count': 2, 'key': 'term'},
#        {'doc_count': 2, 'key': 'theoretical'},
#        {'doc_count': 2, 'key': 'tight'},
#        {'doc_count': 2, 'key': 'transfer'},
#        {'doc_count': 2, 'key': 'trees'},
#        {'doc_count': 2, 'key': 'unknown'},
#        {'doc_count': 2, 'key': 'weighted'},
#        {'doc_count': 1, 'key': 'accuracy'},
#        {'doc_count': 1, 'key': 'additive'},
#        {'doc_count': 1, 'key': 'agent'},
#        {'doc_count': 1, 'key': 'associative'},
#        {'doc_count': 1, 'key': 'automatic'},
#        {'doc_count': 1, 'key': 'average'},
#        {'doc_count': 1, 'key': 'cell'},
#        {'doc_count': 1, 'key': 'channel'},
#        {'doc_count': 1, 'key': 'coding'},
#        {'doc_count': 1, 'key': 'competitive'},
#        {'doc_count': 1, 'key': 'computer'},
#        {'doc_count': 1, 'key': 'connection'},
#        {'doc_count': 1, 'key': 'construction'},
#        {'doc_count': 1, 'key': 'correlation'},
#        {'doc_count': 1, 'key': 'coupled'},
#        {'doc_count': 1, 'key': 'curve'},
#        {'doc_count': 1, 'key': 'decomposable'},
#        {'doc_count': 1, 'key': 'dictionary'},
#        {'doc_count': 1, 'key': 'dirichlet'},
#        {'doc_count': 1, 'key': 'discriminant'},
#        {'doc_count': 1, 'key': 'distance'},
#        {'doc_count': 1, 'key': 'eeg'},
#        {'doc_count': 1, 'key': 'effect'},
#        {'doc_count': 1, 'key': 'evaluation'},
#        {'doc_count': 1, 'key': 'expectation'},
#        {'doc_count': 1, 'key': 'expert'},
#        {'doc_count': 1, 'key': 'extraction'},
#        {'doc_count': 1, 'key': 'fairness'},
#        {'doc_count': 1, 'key': 'forest'},
#        {'doc_count': 1, 'key': 'frank'},
#        {'doc_count': 1, 'key': 'generalization'},
#        {'doc_count': 1, 'key': 'geometrical'},
#        {'doc_count': 1, 'key': 'hilbert'},
#        {'doc_count': 1, 'key': 'hmm'},
#        {'doc_count': 1, 'key': 'implicit'},
#        {'doc_count': 1, 'key': 'improving'},
#        {'doc_count': 1, 'key': 'input'},
#        {'doc_count': 1, 'key': 'integrated'},
#        {'doc_count': 1, 'key': 'invariant'},
#        {'doc_count': 1, 'key': 'knowledge'},
#        {'doc_count': 1, 'key': 'lasso'},
#        {'doc_count': 1, 'key': 'law'},
#        {'doc_count': 1, 'key': 'localization'},
#        {'doc_count': 1, 'key': 'logistic'},
#        {'doc_count': 1, 'key': 'manifold'},
#        {'doc_count': 1, 'key': 'mapping'},
#        {'doc_count': 1, 'key': 'margin'},
#        {'doc_count': 1, 'key': 'message'},
#        {'doc_count': 1, 'key': 'mirror'},
#        {'doc_count': 1, 'key': 'mixing'},
#        {'doc_count': 1, 'key': 'modelling'},
#        {'doc_count': 1, 'key': 'multiclass'},
#        {'doc_count': 1, 'key': 'output'},
#        {'doc_count': 1, 'key': 'overlapping'},
#        {'doc_count': 1, 'key': 'partitioning'},
#        {'doc_count': 1, 'key': 'pattern'},
#        {'doc_count': 1, 'key': 'perceptron'},
#        {'doc_count': 1, 'key': 'plasticity'},
#        {'doc_count': 1, 'key': 'practical'},
#        {'doc_count': 1, 'key': 'predictive'},
#        {'doc_count': 1, 'key': 'protein'},
#        {'doc_count': 1, 'key': 'radial'},
#        {'doc_count': 1, 'key': 'ranking'},
#        {'doc_count': 1, 'key': 'rational'},
#        {'doc_count': 1, 'key': 'real'},
#        {'doc_count': 1, 'key': 'recording'},
#        {'doc_count': 1, 'key': 'second'},
#        {'doc_count': 1, 'key': 'selective'},
#        {'doc_count': 1, 'key': 'separation'},
#        {'doc_count': 1, 'key': 'setting'},
#        {'doc_count': 1, 'key': 'short'},
#        {'doc_count': 1, 'key': 'signal'},
#        {'doc_count': 1, 'key': 'simulation'},
#        {'doc_count': 1, 'key': 'spiking'},
#        {'doc_count': 1, 'key': 'statistic'},
#        {'doc_count': 1, 'key': 'stimulus'},
#        {'doc_count': 1, 'key': 'strategy'},
#        {'doc_count': 1, 'key': 'streaming'},
#        {'doc_count': 1, 'key': 'subset'},
#        {'doc_count': 1, 'key': 'support'},
#        {'doc_count': 1, 'key': 'surface'},
#        {'doc_count': 1, 'key': 'thompson'},
#        {'doc_count': 1, 'key': 'tracking'},
#        {'doc_count': 1, 'key': 'tractable'},
#        {'doc_count': 1, 'key': 'transformation'},
#        {'doc_count': 1, 'key': 'uncertainty'},
#        {'doc_count': 1, 'key': 'unit'},
#        {'doc_count': 1, 'key': 'vector'},
#        {'doc_count': 1, 'key': 'winner'},
#        {'doc_count': 1, 'key': 'wolfe'}],
#       'doc_count_error_upper_bound': 0,
#       'sum_other_doc_count': 0}},
#     {'doc_count': 411,
#      'key': '2014',
#      'keywords': {'buckets': [{'doc_count': 85, 'key': 'learning'},
#        {'doc_count': 66, 'key': 'model'},
#        {'doc_count': 37, 'key': 'network'},
#        {'doc_count': 30, 'key': 'inference'},
#        {'doc_count': 28, 'key': 'neural'},
#        {'doc_count': 22, 'key': 'deep'},
#        {'doc_count': 22, 'key': 'estimation'},
#        {'doc_count': 21, 'key': 'sparse'},
#        {'doc_count': 20, 'key': 'based'},
#        {'doc_count': 19, 'key': 'data'},
#        {'doc_count': 18, 'key': 'bayesian'},
#        {'doc_count': 16, 'key': 'distributed'},
#        {'doc_count': 16, 'key': 'graphical'},
#        {'doc_count': 16, 'key': 'method'},
#        {'doc_count': 16, 'key': 'optimization'},
#        {'doc_count': 15, 'key': 'algorithm'},
#        {'doc_count': 15, 'key': 'classification'},
#        {'doc_count': 15, 'key': 'convex'},
#        {'doc_count': 15, 'key': 'efficient'},
#        {'doc_count': 15, 'key': 'gaussian'},
#        {'doc_count': 15, 'key': 'stochastic'},
#        {'doc_count': 14, 'key': 'multi'},
#        {'doc_count': 14, 'key': 'time'},
#        {'doc_count': 13, 'key': 'analysi'},
#        {'doc_count': 13, 'key': 'clustering'},
#        {'doc_count': 13, 'key': 'graph'},
#        {'doc_count': 12, 'key': 'fast'},
#        {'doc_count': 12, 'key': 'kernel'},
#        {'doc_count': 12, 'key': 'linear'},
#        {'doc_count': 12, 'key': 'rank'},
#        {'doc_count': 12, 'key': 'sampling'},
#        {'doc_count': 11, 'key': 'high'},
#        {'doc_count': 11, 'key': 'online'},
#        {'doc_count': 11, 'key': 'process'},
#        {'doc_count': 10, 'key': 'application'},
#        {'doc_count': 10, 'key': 'representation'},
#        {'doc_count': 10, 'key': 'scale'},
#        {'doc_count': 10, 'key': 'selection'},
#        {'doc_count': 10, 'key': 'spectral'},
#        {'doc_count': 10, 'key': 'structured'},
#        {'doc_count': 10, 'key': 'variational'},
#        {'doc_count': 9, 'key': 'dimensional'},
#        {'doc_count': 9, 'key': 'function'},
#        {'doc_count': 9, 'key': 'image'},
#        {'doc_count': 9, 'key': 'large'},
#        {'doc_count': 9, 'key': 'low'},
#        {'doc_count': 9, 'key': 'map'},
#        {'doc_count': 9, 'key': 'markov'},
#        {'doc_count': 8, 'key': 'bandit'},
#        {'doc_count': 8, 'key': 'convolutional'},
#        {'doc_count': 8, 'key': 'factorization'},
#        {'doc_count': 8, 'key': 'mixture'},
#        {'doc_count': 8, 'key': 'parallel'},
#        {'doc_count': 8, 'key': 'probabilistic'},
#        {'doc_count': 8, 'key': 'problem'},
#        {'doc_count': 8, 'key': 'robust'},
#        {'doc_count': 8, 'key': 'space'},
#        {'doc_count': 8, 'key': 'structure'},
#        {'doc_count': 7, 'key': 'approximation'},
#        {'doc_count': 7, 'key': 'detection'},
#        {'doc_count': 7, 'key': 'machine'},
#        {'doc_count': 7, 'key': 'matrix'},
#        {'doc_count': 7, 'key': 'parameter'},
#        {'doc_count': 7, 'key': 'prediction'},
#        {'doc_count': 7, 'key': 'random'},
#        {'doc_count': 7, 'key': 'regression'},
#        {'doc_count': 7, 'key': 'search'},
#        {'doc_count': 7, 'key': 'spike'},
#        {'doc_count': 7, 'key': 'submodular'},
#        {'doc_count': 7, 'key': 'tensor'},
#        {'doc_count': 6, 'key': 'approach'},
#        {'doc_count': 6, 'key': 'carlo'},
#        {'doc_count': 6, 'key': 'decision'},
#        {'doc_count': 6, 'key': 'dynamic'},
#        {'doc_count': 6, 'key': 'local'},
#        {'doc_count': 6, 'key': 'modeling'},
#        {'doc_count': 6, 'key': 'monte'},
#        {'doc_count': 6, 'key': 'polynomial'},
#        {'doc_count': 6, 'key': 'regularization'},
#        {'doc_count': 6, 'key': 'state'},
#        {'doc_count': 6, 'key': 'statistical'},
#        {'doc_count': 6, 'key': 'support'},
#        {'doc_count': 6, 'key': 'training'},
#        {'doc_count': 5, 'key': 'bound'},
#        {'doc_count': 5, 'key': 'completion'},
#        {'doc_count': 5, 'key': 'continuous'},
#        {'doc_count': 5, 'key': 'coordinate'},
#        {'doc_count': 5, 'key': 'decomposition'},
#        {'doc_count': 5, 'key': 'density'},
#        {'doc_count': 5, 'key': 'generative'},
#        {'doc_count': 5, 'key': 'human'},
#        {'doc_count': 5, 'key': 'latent'},
#        {'doc_count': 5, 'key': 'metric'},
#        {'doc_count': 5, 'key': 'minimization'},
#        {'doc_count': 5, 'key': 'pattern'},
#        {'doc_count': 5, 'key': 'pca'},
#        {'doc_count': 5, 'key': 'prior'},
#        {'doc_count': 5, 'key': 'ranking'},
#        {'doc_count': 5, 'key': 'reinforcement'},
#        {'doc_count': 5, 'key': 'supervised'},
#        {'doc_count': 5, 'key': 'temporal'},
#        {'doc_count': 5, 'key': 'weighted'},
#        {'doc_count': 4, 'key': 'activity'},
#        {'doc_count': 4, 'key': 'adaptive'},
#        {'doc_count': 4, 'key': 'attribute'},
#        {'doc_count': 4, 'key': 'balanced'},
#        {'doc_count': 4, 'key': 'boosting'},
#        {'doc_count': 4, 'key': 'covariance'},
#        {'doc_count': 4, 'key': 'dependent'},
#        {'doc_count': 4, 'key': 'design'},
#        {'doc_count': 4, 'key': 'distribution'},
#        {'doc_count': 4, 'key': 'embedding'},
#        {'doc_count': 4, 'key': 'feedback'},
#        {'doc_count': 4, 'key': 'field'},
#        {'doc_count': 4, 'key': 'filtering'},
#        {'doc_count': 4, 'key': 'making'},
#        {'doc_count': 4, 'key': 'margin'},
#        {'doc_count': 4, 'key': 'nonparametric'},
#        {'doc_count': 4, 'key': 'population'},
#        {'doc_count': 4, 'key': 'positive'},
#        {'doc_count': 4, 'key': 'processe'},
#        {'doc_count': 4, 'key': 'programming'},
#        {'doc_count': 4, 'key': 'recognition'},
#        {'doc_count': 4, 'key': 'relaxation'},
#        {'doc_count': 4, 'key': 'scalable'},
#        {'doc_count': 4, 'key': 'sequential'},
#        {'doc_count': 4, 'key': 'set'},
#        {'doc_count': 4, 'key': 'signal'},
#        {'doc_count': 4, 'key': 'subspace'},
#        {'doc_count': 4, 'key': 'task'},
#        {'doc_count': 4, 'key': 'tight'},
#        {'doc_count': 4, 'key': 'tree'},
#        {'doc_count': 4, 'key': 'variable'},
#        {'doc_count': 4, 'key': 'vector'},
#        {'doc_count': 3, 'key': 'active'},
#        {'doc_count': 3, 'key': 'adversarial'},
#        {'doc_count': 3, 'key': 'agent'},
#        {'doc_count': 3, 'key': 'armed'},
#        {'doc_count': 3, 'key': 'attention'},
#        {'doc_count': 3, 'key': 'correlation'},
#        {'doc_count': 3, 'key': 'decomposable'},
#        {'doc_count': 3, 'key': 'deconvolution'},
#        {'doc_count': 3, 'key': 'differential'},
#        {'doc_count': 3, 'key': 'dimension'},
#        {'doc_count': 3, 'key': 'direction'},
#        {'doc_count': 3, 'key': 'discriminative'},
#        {'doc_count': 3, 'key': 'expectation'},
#        {'doc_count': 3, 'key': 'exploiting'},
#        {'doc_count': 3, 'key': 'exponential'},
#        {'doc_count': 3, 'key': 'factor'},
#        {'doc_count': 3, 'key': 'general'},
#        {'doc_count': 3, 'key': 'hidden'},
#        {'doc_count': 3, 'key': 'hierarchical'},
#        {'doc_count': 3, 'key': 'hilbert'},
#        {'doc_count': 3, 'key': 'incremental'},
#        {'doc_count': 3, 'key': 'joint'},
#        {'doc_count': 3, 'key': 'matching'},
#        {'doc_count': 3, 'key': 'measure'},
#        {'doc_count': 3, 'key': 'memory'},
#        {'doc_count': 3, 'key': 'message'},
#        {'doc_count': 3, 'key': 'multiple'},
#        {'doc_count': 3, 'key': 'object'},
#        {'doc_count': 3, 'key': 'passing'},
#        {'doc_count': 3, 'key': 'permutation'},
#        {'doc_count': 3, 'key': 'point'},
#        {'doc_count': 3, 'key': 'poisson'},
#        {'doc_count': 3, 'key': 'policy'},
#        {'doc_count': 3, 'key': 'real'},
#        {'doc_count': 3, 'key': 'recurrent'},
#        {'doc_count': 3, 'key': 'sample'},
#        {'doc_count': 3, 'key': 'strategic'},
#        {'doc_count': 3, 'key': 'strategy'},
#        {'doc_count': 3, 'key': 'subset'},
#        {'doc_count': 3, 'key': 'testing'},
#        {'doc_count': 3, 'key': 'theory'},
#        {'doc_count': 3, 'key': 'trees'},
#        {'doc_count': 3, 'key': 'video'},
#        {'doc_count': 3, 'key': 'visual'},
#        {'doc_count': 3, 'key': 'word'},
#        {'doc_count': 2, 'key': 'action'},
#        {'doc_count': 2, 'key': 'adaptation'},
#        {'doc_count': 2, 'key': 'additive'},
#        {'doc_count': 2, 'key': 'aggregation'},
#        {'doc_count': 2, 'key': 'alignment'},
#        {'doc_count': 2, 'key': 'approximate'},
#        {'doc_count': 2, 'key': 'asynchronous'},
#        {'doc_count': 2, 'key': 'cascade'},
#        {'doc_count': 2, 'key': 'case'},
#        {'doc_count': 2, 'key': 'choice'},
#        {'doc_count': 2, 'key': 'classifier'},
#        {'doc_count': 2, 'key': 'cluster'},
#        {'doc_count': 2, 'key': 'code'},
#        {'doc_count': 2, 'key': 'coding'},
#        {'doc_count': 2, 'key': 'component'},
#        {'doc_count': 2, 'key': 'conditional'},
#        {'doc_count': 2, 'key': 'constrained'},
#        {'doc_count': 2, 'key': 'crowdsourcing'},
#        {'doc_count': 2, 'key': 'dependency'},
#        {'doc_count': 2, 'key': 'dictionary'},
#        {'doc_count': 2, 'key': 'distance'},
#        {'doc_count': 2, 'key': 'domain'},
#        {'doc_count': 2, 'key': 'environment'},
#        {'doc_count': 2, 'key': 'finite'},
#        {'doc_count': 2, 'key': 'group'},
#        {'doc_count': 2, 'key': 'identification'},
#        {'doc_count': 2, 'key': 'identifying'},
#        {'doc_count': 2, 'key': 'implicit'},
#        {'doc_count': 2, 'key': 'inferring'},
#        {'doc_count': 2, 'key': 'input'},
#        {'doc_count': 2, 'key': 'inverse'},
#        {'doc_count': 2, 'key': 'label'},
#        {'doc_count': 2, 'key': 'language'},
#        {'doc_count': 2, 'key': 'layer'},
#        {'doc_count': 2, 'key': 'lifted'},
#        {'doc_count': 2, 'key': 'logistic'},
#        {'doc_count': 2, 'key': 'mapping'},
#        {'doc_count': 2, 'key': 'matrice'},
#        {'doc_count': 2, 'key': 'natural'},
#        {'doc_count': 2, 'key': 'neighbor'},
#        {'doc_count': 2, 'key': 'net'},
#        {'doc_count': 2, 'key': 'neuron'},
#        {'doc_count': 2, 'key': 'neuronal'},
#        {'doc_count': 2, 'key': 'noise'},
#        {'doc_count': 2, 'key': 'optimizing'},
#        {'doc_count': 2, 'key': 'order'},
#        {'doc_count': 2, 'key': 'output'},
#        {'doc_count': 2, 'key': 'partitioning'},
#        {'doc_count': 2, 'key': 'performance'},
#        {'doc_count': 2, 'key': 'predictive'},
#        {'doc_count': 2, 'key': 'recovery'},
#        {'doc_count': 2, 'key': 'reduction'},
#        {'doc_count': 2, 'key': 'rule'},
#        {'doc_count': 2, 'key': 'scaling'},
#        {'doc_count': 2, 'key': 'semantic'},
#        {'doc_count': 2, 'key': 'semi'},
#        {'doc_count': 2, 'key': 'sensory'},
#        {'doc_count': 2, 'key': 'similarity'},
#        {'doc_count': 2, 'key': 'single'},
#        {'doc_count': 2, 'key': 'sparsity'},
#        {'doc_count': 2, 'key': 'spiking'},
#        {'doc_count': 2, 'key': 'streaming'},
#        {'doc_count': 2, 'key': 'system'},
#        {'doc_count': 2, 'key': 'theoretical'},
#        {'doc_count': 2, 'key': 'topic'},
#        {'doc_count': 2, 'key': 'uncertainty'},
#        {'doc_count': 2, 'key': 'unknown'},
#        {'doc_count': 1, 'key': '3d'},
#        {'doc_count': 1, 'key': 'acceleration'},
#        {'doc_count': 1, 'key': 'analog'},
#        {'doc_count': 1, 'key': 'architecture'},
#        {'doc_count': 1, 'key': 'assumption'},
#        {'doc_count': 1, 'key': 'asymmetric'},
#        {'doc_count': 1, 'key': 'auditory'},
#        {'doc_count': 1, 'key': 'automatic'},
#        {'doc_count': 1, 'key': 'average'},
#        {'doc_count': 1, 'key': 'backpropagation'},
#        {'doc_count': 1, 'key': 'baye'},
#        {'doc_count': 1, 'key': 'belief'},
#        {'doc_count': 1, 'key': 'blind'},
#        {'doc_count': 1, 'key': 'cell'},
#        {'doc_count': 1, 'key': 'chain'},
#        {'doc_count': 1, 'key': 'circuit'},
#        {'doc_count': 1, 'key': 'class'},
#        {'doc_count': 1, 'key': 'collaborative'},
#        {'doc_count': 1, 'key': 'computation'},
#        {'doc_count': 1, 'key': 'computational'},
#        {'doc_count': 1, 'key': 'computer'},
#        {'doc_count': 1, 'key': 'connection'},
#        {'doc_count': 1, 'key': 'constraint'},
#        {'doc_count': 1, 'key': 'context'},
#        {'doc_count': 1, 'key': 'contextual'},
#        {'doc_count': 1, 'key': 'control'},
#        {'doc_count': 1, 'key': 'cortical'},
#        {'doc_count': 1, 'key': 'delay'},
#        {'doc_count': 1, 'key': 'determinantal'},
#        {'doc_count': 1, 'key': 'dirichlet'},
#        {'doc_count': 1, 'key': 'dropout'},
#        {'doc_count': 1, 'key': 'em'},
#        {'doc_count': 1, 'key': 'entropy'},
#        {'doc_count': 1, 'key': 'evaluation'},
#        {'doc_count': 1, 'key': 'expert'},
#        {'doc_count': 1, 'key': 'extraction'},
#        {'doc_count': 1, 'key': 'factored'},
#        {'doc_count': 1, 'key': 'fairness'},
#        {'doc_count': 1, 'key': 'filter'},
#        {'doc_count': 1, 'key': 'forest'},
#        {'doc_count': 1, 'key': 'forward'},
#        {'doc_count': 1, 'key': 'functional'},
#        {'doc_count': 1, 'key': 'guided'},
#        {'doc_count': 1, 'key': 'hashing'},
#        {'doc_count': 1, 'key': 'hippocampal'},
#        {'doc_count': 1, 'key': 'hmm'},
#        {'doc_count': 1, 'key': 'independent'},
#        {'doc_count': 1, 'key': 'infinite'},
#        {'doc_count': 1, 'key': 'integrated'},
#        {'doc_count': 1, 'key': 'internal'},
#        {'doc_count': 1, 'key': 'labeled'},
#        {'doc_count': 1, 'key': 'lasso'},
#        {'doc_count': 1, 'key': 'law'},
#        {'doc_count': 1, 'key': 'learn'},
#        {'doc_count': 1, 'key': 'localization'},
#        {'doc_count': 1, 'key': 'manifold'},
#        {'doc_count': 1, 'key': 'maximum'},
#        {'doc_count': 1, 'key': 'mixing'},
#        {'doc_count': 1, 'key': 'multiclass'},
#        {'doc_count': 1, 'key': 'multilayer'},
#        {'doc_count': 1, 'key': 'newton'},
#        {'doc_count': 1, 'key': 'noisy'},
#        {'doc_count': 1, 'key': 'objective'},
#        {'doc_count': 1, 'key': 'observable'},
#        {'doc_count': 1, 'key': 'observation'},
#        {'doc_count': 1, 'key': 'optimistic'},
# ...
#        {'doc_count': 1, 'key': 'cascade'},
#        {'doc_count': 1, 'key': 'character'},
#        {'doc_count': 1, 'key': 'classification'},
#        {'doc_count': 1, 'key': 'clustering'},
#        {'doc_count': 1, 'key': 'code'},
#        {'doc_count': 1, 'key': 'competitive'},
#        {'doc_count': 1, 'key': 'connection'},
#        {'doc_count': 1, 'key': 'constrained'},
#        {'doc_count': 1, 'key': 'continuous'},
#        {'doc_count': 1, 'key': 'contour'},
#        {'doc_count': 1, 'key': 'correlation'},
#        {'doc_count': 1, 'key': 'coupled'},
#        {'doc_count': 1, 'key': 'curve'},
#        {'doc_count': 1, 'key': 'decision'},
#        {'doc_count': 1, 'key': 'dependent'},
#        {'doc_count': 1, 'key': 'discrimination'},
#        {'doc_count': 1, 'key': 'efficient'},
#        {'doc_count': 1, 'key': 'electronic'},
#        {'doc_count': 1, 'key': 'embedding'},
#        {'doc_count': 1, 'key': 'extraction'},
#        {'doc_count': 1, 'key': 'eye'},
#        {'doc_count': 1, 'key': 'fast'},
#        {'doc_count': 1, 'key': 'filter'},
#        {'doc_count': 1, 'key': 'finite'},
#        {'doc_count': 1, 'key': 'group'},
#        {'doc_count': 1, 'key': 'hand'},
#        {'doc_count': 1, 'key': 'hierarchical'},
#        {'doc_count': 1, 'key': 'hybrid'},
#        {'doc_count': 1, 'key': 'incremental'},
#        {'doc_count': 1, 'key': 'independent'},
#        {'doc_count': 1, 'key': 'input'},
#        {'doc_count': 1, 'key': 'internal'},
#        {'doc_count': 1, 'key': 'invariant'},
#        {'doc_count': 1, 'key': 'large'},
#        {'doc_count': 1, 'key': 'layer'},
#        {'doc_count': 1, 'key': 'learn'},
#        {'doc_count': 1, 'key': 'machine'},
#        {'doc_count': 1, 'key': 'matrix'},
#        {'doc_count': 1, 'key': 'method'},
#        {'doc_count': 1, 'key': 'motor'},
#        {'doc_count': 1, 'key': 'movement'},
#        {'doc_count': 1, 'key': 'multi'},
#        {'doc_count': 1, 'key': 'neuronal'},
#        {'doc_count': 1, 'key': 'output'},
#        {'doc_count': 1, 'key': 'parallel'},
#        {'doc_count': 1, 'key': 'pattern'},
#        {'doc_count': 1, 'key': 'perceptron'},
#        {'doc_count': 1, 'key': 'practical'},
#        {'doc_count': 1, 'key': 'predicting'},
#        {'doc_count': 1, 'key': 'prior'},
#        {'doc_count': 1, 'key': 'processe'},
#        {'doc_count': 1, 'key': 'processor'},
#        {'doc_count': 1, 'key': 'property'},
#        {'doc_count': 1, 'key': 'protein'},
#        {'doc_count': 1, 'key': 'reduction'},
#        {'doc_count': 1, 'key': 'reinforcement'},
#        {'doc_count': 1, 'key': 'sampling'},
#        {'doc_count': 1, 'key': 'scale'},
#        {'doc_count': 1, 'key': 'scaling'},
#        {'doc_count': 1, 'key': 'segmentation'},
#        {'doc_count': 1, 'key': 'selection'},
#        {'doc_count': 1, 'key': 'selective'},
#        {'doc_count': 1, 'key': 'sensory'},
#        {'doc_count': 1, 'key': 'separation'},
#        {'doc_count': 1, 'key': 'sequential'},
#        {'doc_count': 1, 'key': 'set'},
#        {'doc_count': 1, 'key': 'sound'},
#        {'doc_count': 1, 'key': 'sparse'},
#        {'doc_count': 1, 'key': 'specific'},
#        {'doc_count': 1, 'key': 'spiking'},
#        {'doc_count': 1, 'key': 'statistical'},
#        {'doc_count': 1, 'key': 'stimulus'},
#        {'doc_count': 1, 'key': 'stochastic'},
#        {'doc_count': 1, 'key': 'structure'},
#        {'doc_count': 1, 'key': 'structured'},
#        {'doc_count': 1, 'key': 'study'},
#        {'doc_count': 1, 'key': 'technique'},
#        {'doc_count': 1, 'key': 'unit'}],
#       'doc_count_error_upper_bound': 0,
#       'sum_other_doc_count': 0}},
#     {'doc_count': 94,
#      'key': '1988',
#      'keywords': {'buckets': [{'doc_count': 37, 'key': 'network'},
#        {'doc_count': 31, 'key': 'neural'},
#        {'doc_count': 15, 'key': 'learning'},
#        {'doc_count': 9, 'key': 'analog'},
#        {'doc_count': 7, 'key': 'model'},
#        {'doc_count': 7, 'key': 'system'},
#        {'doc_count': 5, 'key': 'adaptive'},
#        {'doc_count': 5, 'key': 'temporal'},
#        {'doc_count': 4, 'key': 'algorithm'},
#        {'doc_count': 4, 'key': 'connectionist'},
#        {'doc_count': 4, 'key': 'distributed'},
#        {'doc_count': 4, 'key': 'dynamic'},
#        {'doc_count': 4, 'key': 'learn'},
#        {'doc_count': 4, 'key': 'modeling'},
#        {'doc_count': 4, 'key': 'representation'},
#        {'doc_count': 4, 'key': 'speech'},
#        {'doc_count': 4, 'key': 'training'},
#        {'doc_count': 3, 'key': 'annealing'},
#        {'doc_count': 3, 'key': 'application'},
#        {'doc_count': 3, 'key': 'approach'},
#        {'doc_count': 3, 'key': 'associative'},
#        {'doc_count': 3, 'key': 'control'},
#        {'doc_count': 3, 'key': 'expert'},
#        {'doc_count': 3, 'key': 'field'},
#        {'doc_count': 3, 'key': 'generalization'},
#        {'doc_count': 3, 'key': 'image'},
#        {'doc_count': 3, 'key': 'map'},
#        {'doc_count': 3, 'key': 'multi'},
#        {'doc_count': 3, 'key': 'net'},
#        {'doc_count': 3, 'key': 'pattern'},
#        {'doc_count': 3, 'key': 'perceptron'},
#        {'doc_count': 3, 'key': 'propagation'},
#        {'doc_count': 3, 'key': 'recognition'},
#        {'doc_count': 3, 'key': 'sensory'},
#        {'doc_count': 3, 'key': 'winner'},
#        {'doc_count': 2, 'key': 'backpropagation'},
#        {'doc_count': 2, 'key': 'chip'},
#        {'doc_count': 2, 'key': 'classification'},
#        {'doc_count': 2, 'key': 'computer'},
#        {'doc_count': 2, 'key': 'construction'},
#        {'doc_count': 2, 'key': 'delay'},
#        {'doc_count': 2, 'key': 'detection'},
#        {'doc_count': 2, 'key': 'electronic'},
#        {'doc_count': 2, 'key': 'linear'},
#        {'doc_count': 2, 'key': 'local'},
#        {'doc_count': 2, 'key': 'machine'},
#        {'doc_count': 2, 'key': 'multilayer'},
#        {'doc_count': 2, 'key': 'neuron'},
#        {'doc_count': 2, 'key': 'neuronal'},
#        {'doc_count': 2, 'key': 'noise'},
#        {'doc_count': 2, 'key': 'organization'},
#        {'doc_count': 2, 'key': 'organizing'},
#        {'doc_count': 2, 'key': 'parallel'},
#        {'doc_count': 2, 'key': 'performance'},
#        {'doc_count': 2, 'key': 'problem'},
#        {'doc_count': 2, 'key': 'recurrent'},
#        {'doc_count': 2, 'key': 'resolution'},
#        {'doc_count': 2, 'key': 'rule'},
#        {'doc_count': 2, 'key': 'signal'},
#        {'doc_count': 2, 'key': 'statistical'},
#        {'doc_count': 2, 'key': 'theory'},
#        {'doc_count': 2, 'key': 'time'},
#        {'doc_count': 2, 'key': 'vlsi'},
#        {'doc_count': 1, 'key': 'analysi'},
#        {'doc_count': 1, 'key': 'architecture'},
#        {'doc_count': 1, 'key': 'automatic'},
#        {'doc_count': 1, 'key': 'based'},
#        {'doc_count': 1, 'key': 'behavior'},
#        {'doc_count': 1, 'key': 'binding'},
#        {'doc_count': 1, 'key': 'case'},
#        {'doc_count': 1, 'key': 'character'},
#        {'doc_count': 1, 'key': 'choice'},
#        {'doc_count': 1, 'key': 'circuit'},
#        {'doc_count': 1, 'key': 'classifier'},
#        {'doc_count': 1, 'key': 'code'},
#        {'doc_count': 1, 'key': 'coding'},
#        {'doc_count': 1, 'key': 'color'},
#        {'doc_count': 1, 'key': 'comparison'},
#        {'doc_count': 1, 'key': 'computational'},
#        {'doc_count': 1, 'key': 'constraint'},
#        {'doc_count': 1, 'key': 'context'},
#        {'doc_count': 1, 'key': 'cortex'},
#        {'doc_count': 1, 'key': 'cortical'},
#        {'doc_count': 1, 'key': 'coupled'},
#        {'doc_count': 1, 'key': 'covariance'},
#        {'doc_count': 1, 'key': 'efficient'},
#        {'doc_count': 1, 'key': 'environment'},
#        {'doc_count': 1, 'key': 'error'},
#        {'doc_count': 1, 'key': 'estimation'},
#        {'doc_count': 1, 'key': 'fast'},
#        {'doc_count': 1, 'key': 'forward'},
#        {'doc_count': 1, 'key': 'gaussian'},
#        {'doc_count': 1, 'key': 'guided'},
#        {'doc_count': 1, 'key': 'hand'},
#        {'doc_count': 1, 'key': 'hidden'},
#        {'doc_count': 1, 'key': 'human'},
#        {'doc_count': 1, 'key': 'identification'},
#        {'doc_count': 1, 'key': 'implementation'},
#        {'doc_count': 1, 'key': 'internal'},
#        {'doc_count': 1, 'key': 'language'},
#        {'doc_count': 1, 'key': 'large'},
#        {'doc_count': 1, 'key': 'layer'},
#        {'doc_count': 1, 'key': 'link'},
#        {'doc_count': 1, 'key': 'low'},
#        {'doc_count': 1, 'key': 'making'},
#        {'doc_count': 1, 'key': 'mapping'},
#        {'doc_count': 1, 'key': 'markov'},
#        {'doc_count': 1, 'key': 'matching'},
#        {'doc_count': 1, 'key': 'matrix'},
#        {'doc_count': 1, 'key': 'maximum'},
#        {'doc_count': 1, 'key': 'measurement'},
#        {'doc_count': 1, 'key': 'memory'},
#        {'doc_count': 1, 'key': 'motion'},
#        {'doc_count': 1, 'key': 'motor'},
#        {'doc_count': 1, 'key': 'multiple'},
#        {'doc_count': 1, 'key': 'natural'},
#        {'doc_count': 1, 'key': 'noisy'},
#        {'doc_count': 1, 'key': 'optimality'},
#        {'doc_count': 1, 'key': 'optimization'},
#        {'doc_count': 1, 'key': 'point'},
#        {'doc_count': 1, 'key': 'prediction'},
#        {'doc_count': 1, 'key': 'processing'},
#        {'doc_count': 1, 'key': 'programming'},
#        {'doc_count': 1, 'key': 'property'},
#        {'doc_count': 1, 'key': 'robust'},
#        {'doc_count': 1, 'key': 'scaling'},
#        {'doc_count': 1, 'key': 'search'},
#        {'doc_count': 1, 'key': 'segmentation'},
#        {'doc_count': 1, 'key': 'sensing'},
#        {'doc_count': 1, 'key': 'sequential'},
#        {'doc_count': 1, 'key': 'simple'},
#        {'doc_count': 1, 'key': 'simulation'},
#        {'doc_count': 1, 'key': 'size'},
#        {'doc_count': 1, 'key': 'sparse'},
#        {'doc_count': 1, 'key': 'stochastic'},
#        {'doc_count': 1, 'key': 'structure'},
#        {'doc_count': 1, 'key': 'study'},
#        {'doc_count': 1, 'key': 'surface'},
#        {'doc_count': 1, 'key': 'technique'},
#        {'doc_count': 1, 'key': 'term'},
#        {'doc_count': 1, 'key': 'unified'},
#        {'doc_count': 1, 'key': 'unit'}],
#       'doc_count_error_upper_bound': 0,
#       'sum_other_doc_count': 0}},
#     {'doc_count': 90,
#      'key': '1987',
#      'keywords': {'buckets': [{'doc_count': 43, 'key': 'network'},
#        {'doc_count': 39, 'key': 'neural'},
#        {'doc_count': 11, 'key': 'learning'},
#        {'doc_count': 10, 'key': 'memory'},
#        {'doc_count': 9, 'key': 'associative'},
#        {'doc_count': 8, 'key': 'neuron'},
#        {'doc_count': 7, 'key': 'model'},
#        {'doc_count': 6, 'key': 'application'},
#        {'doc_count': 6, 'key': 'pattern'},
#        {'doc_count': 6, 'key': 'processing'},
#        {'doc_count': 6, 'key': 'system'},
#        {'doc_count': 5, 'key': 'net'},
#        {'doc_count': 4, 'key': 'analysi'},
#        {'doc_count': 4, 'key': 'artificial'},
#        {'doc_count': 4, 'key': 'based'},
#        {'doc_count': 4, 'key': 'classification'},
#        {'doc_count': 4, 'key': 'cortex'},
#        {'doc_count': 4, 'key': 'learn'},
#        {'doc_count': 4, 'key': 'simulation'},
#        {'doc_count': 3, 'key': 'approach'},
#        {'doc_count': 3, 'key': 'computational'},
#        {'doc_count': 3, 'key': 'computer'},
#        {'doc_count': 3, 'key': 'connection'},
#        {'doc_count': 3, 'key': 'connectionist'},
#        {'doc_count': 3, 'key': 'distributed'},
#        {'doc_count': 3, 'key': 'electronic'},
#        {'doc_count': 3, 'key': 'implementation'},
#        {'doc_count': 3, 'key': 'optimization'},
#        {'doc_count': 3, 'key': 'order'},
#        {'doc_count': 3, 'key': 'organization'},
#        {'doc_count': 3, 'key': 'problem'},
#        {'doc_count': 3, 'key': 'propagation'},
#        {'doc_count': 3, 'key': 'property'},
#        {'doc_count': 3, 'key': 'speech'},
#        {'doc_count': 3, 'key': 'temporal'},
#        {'doc_count': 2, 'key': 'adaptive'},
#        {'doc_count': 2, 'key': 'algorithm'},
#        {'doc_count': 2, 'key': 'classifier'},
#        {'doc_count': 2, 'key': 'coding'},
#        {'doc_count': 2, 'key': 'comparison'},
#        {'doc_count': 2, 'key': 'control'},
#        {'doc_count': 2, 'key': 'density'},
#        {'doc_count': 2, 'key': 'design'},
#        {'doc_count': 2, 'key': 'error'},
#        {'doc_count': 2, 'key': 'field'},
#        {'doc_count': 2, 'key': 'hierarchical'},
#        {'doc_count': 2, 'key': 'high'},
#        {'doc_count': 2, 'key': 'machine'},
#        {'doc_count': 2, 'key': 'map'},
#        {'doc_count': 2, 'key': 'method'},
#        {'doc_count': 2, 'key': 'motion'},
#        {'doc_count': 2, 'key': 'object'},
#        {'doc_count': 2, 'key': 'performance'},
#        {'doc_count': 2, 'key': 'probabilistic'},
#        {'doc_count': 2, 'key': 'recognition'},
#        {'doc_count': 2, 'key': 'representation'},
#        {'doc_count': 2, 'key': 'sequential'},
#        {'doc_count': 2, 'key': 'structure'},
#        {'doc_count': 2, 'key': 'theory'},
#        {'doc_count': 2, 'key': 'time'},
#        {'doc_count': 2, 'key': 'training'},
#        {'doc_count': 2, 'key': 'visual'},
#        {'doc_count': 1, 'key': 'action'},
#        {'doc_count': 1, 'key': 'activity'},
#        {'doc_count': 1, 'key': 'architecture'},
#        {'doc_count': 1, 'key': 'behavior'},
#        {'doc_count': 1, 'key': 'chip'},
#        {'doc_count': 1, 'key': 'circuit'},
#        {'doc_count': 1, 'key': 'class'},
#        {'doc_count': 1, 'key': 'code'},
#        {'doc_count': 1, 'key': 'color'},
#        {'doc_count': 1, 'key': 'computation'},
#        {'doc_count': 1, 'key': 'constrained'},
#        {'doc_count': 1, 'key': 'convex'},
#        {'doc_count': 1, 'key': 'cortical'},
#        {'doc_count': 1, 'key': 'data'},
#        {'doc_count': 1, 'key': 'decision'},
#        {'doc_count': 1, 'key': 'detection'},
#        {'doc_count': 1, 'key': 'differential'},
#        {'doc_count': 1, 'key': 'distribution'},
#        {'doc_count': 1, 'key': 'dynamic'},
#        {'doc_count': 1, 'key': 'dynamical'},
#        {'doc_count': 1, 'key': 'efficient'},
#        {'doc_count': 1, 'key': 'entropy'},
#        {'doc_count': 1, 'key': 'exponential'},
#        {'doc_count': 1, 'key': 'filtering'},
#        {'doc_count': 1, 'key': 'functional'},
#        {'doc_count': 1, 'key': 'general'},
#        {'doc_count': 1, 'key': 'generalization'},
#        {'doc_count': 1, 'key': 'geometric'},
#        {'doc_count': 1, 'key': 'hippocampal'},
#        {'doc_count': 1, 'key': 'human'},
#        {'doc_count': 1, 'key': 'invariant'},
#        {'doc_count': 1, 'key': 'layer'},
#        {'doc_count': 1, 'key': 'mapping'},
#        {'doc_count': 1, 'key': 'matching'},
#        {'doc_count': 1, 'key': 'matrix'},
#        {'doc_count': 1, 'key': 'measure'},
#        {'doc_count': 1, 'key': 'modeling'},
#        {'doc_count': 1, 'key': 'motor'},
#        {'doc_count': 1, 'key': 'multi'},
#        {'doc_count': 1, 'key': 'neuronal'},
#        {'doc_count': 1, 'key': 'novel'},
#        {'doc_count': 1, 'key': 'organizing'},
#        {'doc_count': 1, 'key': 'orientation'},
#        {'doc_count': 1, 'key': 'partitioning'},
#        {'doc_count': 1, 'key': 'perceptron'},
#        {'doc_count': 1, 'key': 'probability'},
#        {'doc_count': 1, 'key': 'process'},
#        {'doc_count': 1, 'key': 'real'},
#        {'doc_count': 1, 'key': 'recurrent'},
#        {'doc_count': 1, 'key': 'robot'},
#        {'doc_count': 1, 'key': 'robust'},
#        {'doc_count': 1, 'key': 'scaling'},
#        {'doc_count': 1, 'key': 'sensory'},
#        {'doc_count': 1, 'key': 'sery'},
#        {'doc_count': 1, 'key': 'set'},
#        {'doc_count': 1, 'key': 'signal'},
#        {'doc_count': 1, 'key': 'simple'},
#        {'doc_count': 1, 'key': 'solving'},
#        {'doc_count': 1, 'key': 'sparse'},
#        {'doc_count': 1, 'key': 'spatial'},
#        {'doc_count': 1, 'key': 'spike'},
#        {'doc_count': 1, 'key': 'stable'},
#        {'doc_count': 1, 'key': 'state'},
#        {'doc_count': 1, 'key': 'stochastic'},
#        {'doc_count': 1, 'key': 'strategy'},
#        {'doc_count': 1, 'key': 'structured'},
#        {'doc_count': 1, 'key': 'supervised'},
#        {'doc_count': 1, 'key': 'task'},
#        {'doc_count': 1, 'key': 'technique'},
#        {'doc_count': 1, 'key': 'template'},
#        {'doc_count': 1, 'key': 'unit'}],
#       'doc_count_error_upper_bound': 0,
#       'sum_other_doc_count': 0}}],
#    'doc_count_error_upper_bound': 0,
#    'sum_other_doc_count': 0}},
#  'hits': {'hits': [], 'max_score': 0.0, 'total': 7241},
#  'timed_out': False,
#  'took': 20}

# %%
import csv

#columns needed: 1) keyword, 2) year, 3) score, 4) score proportion, 5) fg_count, 6) doc_count by year,
# 7) proportion in fg, 8) proportion in bg

sig_list = []

data = sig_terms_res['aggregations']['keywords_by_years']['buckets']
tot_num_docs = es.count(index="nips_papers")['count']

#get a list of keywords and how many times they show up in the entire index
cnt_keywords = {}
for year in data:
    words = year['keywords']['buckets']
    for word in words:
        if word['key'] not in cnt_keywords:
            cnt_keywords[word['key']] = word['doc_count']
        else:
            cnt_keywords[word['key']] += word['doc_count']

cnt_keywords
# Out:
# {'2': 11,
#  '3d': 36,
#  'acceleration': 7,
#  'accuracy': 18,
#  'action': 44,
#  'active': 88,
#  'activity': 41,
#  'adaptation': 47,
#  'adaptive': 161,
#  'additive': 15,
#  'adversarial': 43,
#  'agent': 30,
#  'aggregation': 13,
#  'algorithm': 330,
#  'alignment': 22,
#  'analog': 67,
#  'analysi': 244,
#  'annealing': 10,
#  'annotation': 8,
#  'application': 162,
#  'approach': 140,
#  'approximate': 75,
#  'approximation': 96,
#  'architecture': 44,
#  'armed': 20,
#  'array': 10,
#  'artificial': 20,
#  'associative': 35,
#  'assumption': 6,
#  'asymmetric': 7,
#  'asynchronous': 17,
#  'attention': 41,
#  'attribute': 12,
#  'auditory': 30,
#  'augmented': 10,
#  'automatic': 25,
#  'average': 16,
#  'backpropagation': 27,
#  'balanced': 11,
#  'bandit': 92,
#  'based': 280,
#  'basi': 30,
#  'baye': 40,
#  'bayesian': 293,
#  'behavior': 23,
#  'belief': 59,
#  'binding': 10,
#  'blind': 28,
#  'boosting': 58,
#  'bound': 124,
#  'budget': 11,
#  'carlo': 53,
#  'cascade': 17,
#  'case': 28,
#  'cell': 39,
#  'central': 5,
#  'chain': 24,
#  'channel': 21,
#  'character': 12,
#  'chip': 28,
#  'choice': 19,
#  'circuit': 33,
#  'class': 38,
#  'classification': 212,
#  'classifier': 73,
#  'cluster': 24,
#  'clustering': 177,
#  'code': 50,
#  'coding': 61,
#  'cold': 3,
#  'collaborative': 20,
#  'color': 12,
#  'comparison': 43,
#  'competition': 12,
#  'competitive': 15,
#  'completion': 35,
#  'component': 67,
#  'composition': 6,
#  'compressed': 10,
#  'computation': 45,
#  'computational': 37,
#  'computer': 39,
#  'conditional': 44,
#  'conjugate': 8,
#  'connection': 23,
#  'connectionist': 46,
#  'constrained': 34,
#  'constraint': 48,
#  'construction': 13,
#  'context': 32,
#  'contextual': 19,
#  'continuous': 88,
#  'contour': 17,
#  'control': 98,
#  'convex': 101,
#  'convolutional': 55,
#  'coordinate': 27,
#  'correlation': 36,
#  'cortex': 40,
#  'cortical': 31,
#  'coupled': 9,
#  'covariance': 34,
#  'cover': 10,
#  'critic': 10,
#  'crowdsourcing': 13,
#  'cue': 11,
#  'cursive': 5,
#  'curve': 31,
#  'data': 281,
#  'dataset': 12,
#  'decision': 92,
#  'decomposable': 9,
#  'decomposition': 50,
#  'deconvolution': 9,
#  'deep': 184,
#  'delay': 17,
#  'density': 66,
#  'dependence': 6,
#  'dependency': 25,
#  'dependent': 50,
#  'design': 38,
#  'detection': 110,
#  'determinantal': 9,
#  'development': 17,
#  'dictionary': 11,
#  'differential': 28,
#  'dimension': 47,
#  'dimensional': 90,
#  'direction': 18,
#  'dirichlet': 37,
#  'discriminant': 18,
#  'discrimination': 15,
#  'discriminative': 48,
#  'disentangled': 4,
#  'distance': 39,
#  'distributed': 85,
#  'distribution': 82,
#  'domain': 46,
#  'driven': 22,
#  'dropout': 8,
#  'dynamic': 207,
#  'dynamical': 45,
#  'eeg': 13,
#  'effect': 25,
#  'efficient': 178,
#  'electronic': 7,
#  'em': 27,
#  'embedding': 72,
#  'entropy': 40,
#  'environment': 27,
#  'error': 62,
#  'estimate': 19,
#  'estimating': 44,
#  'estimation': 204,
#  'evaluation': 20,
#  'expectation': 25,
#  'expert': 36,
#  'exploiting': 16,
#  'exponential': 37,
#  'expression': 13,
#  'extraction': 30,
#  'eye': 17,
#  'factor': 40,
#  'factored': 13,
#  'factorization': 42,
#  'fairness': 8,
#  'fast': 147,
#  'feedback': 32,
#  'field': 91,
#  'filter': 34,
#  'filtering': 42,
#  'finite': 41,
#  'fmri': 16,
#  'forest': 13,
#  'forward': 26,
#  'frank': 7,
#  'function': 192,
#  'functional': 30,
#  'gan': 16,
#  'gated': 7,
#  'gaussian': 223,
#  'general': 40,
#  'generalization': 72,
#  'generation': 19,
#  'generative': 67,
#  'geometric': 19,
#  'geometrical': 4,
#  'graph': 146,
#  'graphical': 89,
#  'group': 32,
#  'guarantees': 16,
#  'guided': 9,
#  'hand': 18,
#  'hashing': 16,
#  'hebbian': 19,
#  'hidden': 67,
#  'hierarchical': 103,
#  'high': 103,
#  'hilbert': 9,
#  'hippocampal': 13,
#  'hmm': 21,
#  'human': 94,
#  'hybrid': 21,
#  'identification': 33,
#  'identifying': 17,
#  'image': 211,
#  'implementation': 38,
#  'implicit': 18,
#  'improving': 23,
#  'incremental': 25,
#  'independent': 41,
#  'induction': 18,
#  'inference': 263,
#  'inferring': 20,
#  'infinite': 34,
#  'input': 32,
#  'integrated': 12,
#  'interface': 12,
#  'internal': 8,
#  'interpretable': 12,
#  'invariant': 42,
#  'inverse': 41,
#  'joint': 35,
#  'kernel': 247,
#  'knowledge': 27,
#  'label': 48,
#  'labeled': 13,
#  'language': 39,
#  'laplacian': 19,
#  'large': 144,
#  'lasso': 22,
#  'latent': 94,
#  'law': 14,
#  'layer': 29,
#  'learn': 33,
#  'learning': 1547,
#  'lifted': 9,
#  'linear': 194,
#  'link': 14,
#  'local': 94,
#  'localization': 25,
#  'logistic': 15,
#  'low': 58,
#  'machine': 158,
#  'making': 33,
#  'manifold': 48,
#  'map': 77,
#  'mapping': 20,
#  'margin': 62,
#  'markov': 139,
#  'matching': 67,
#  'matrice': 26,
#  'matrix': 98,
#  'maximizing': 9,
#  'maximum': 63,
#  'mcmc': 21,
#  'measure': 38,
#  'measurement': 10,
#  'memory': 85,
#  'message': 21,
#  'method': 206,
#  'metric': 62,
#  'minimization': 72,
#  'mirror': 8,
#  'mixing': 9,
#  'mixture': 119,
#  'model': 883,
#  'modeling': 116,
#  'modelling': 19,
#  'monte': 53,
#  'motion': 57,
#  'motor': 33,
#  'movement': 32,
#  'multi': 226,
#  'multiclass': 22,
#  'multilayer': 15,
#  'multiple': 98,
#  'natural': 73,
#  'navigation': 12,
#  'neighbor': 35,
#  'net': 62,
#  'network': 860,
#  'neural': 645,
#  'neuron': 120,
#  'neuronal': 37,
#  'newton': 10,
#  'noise': 61,
#  'noisy': 34,
#  'nonparametric': 63,
#  'novel': 19,
#  'object': 115,
#  'objective': 18,
#  'observable': 13,
#  'observation': 29,
#  'online': 154,
#  'optimality': 11,
#  'optimistic': 12,
#  'optimization': 216,
#  'optimizing': 16,
#  'oracle': 9,
#  'order': 69,
#  'organization': 17,
#  'organizing': 22,
#  'orientation': 21,
#  'output': 28,
#  'overlapping': 10,
#  'parallel': 54,
#  'parameter': 55,
#  'parametric': 38,
#  'partially': 22,
#  'particle': 23,
#  'partitioning': 15,
#  'passing': 18,
#  'path': 18,
#  'pattern': 63,
#  'pca': 47,
#  'penalty': 11,
#  'perceptron': 32,
#  'performance': 41,
#  'permutation': 12,
#  'plasticity': 31,
#  'point': 56,
#  'poisson': 19,
#  'policy': 79,
#  'polynomial': 28,
#  'pomdp': 21,
#  'population': 49,
#  'positive': 16,
#  'posterior': 16,
#  'practical': 18,
#  'predicting': 26,
#  'prediction': 131,
#  'predictive': 34,
#  'primal': 8,
#  'prior': 66,
#  'private': 16,
#  'probabilistic': 129,
#  'probability': 51,
#  'problem': 111,
#  'process': 130,
#  'processe': 134,
#  'processing': 51,
#  'processor': 11,
#  'product': 30,
#  'programming': 58,
#  'propagation': 79,
#  'property': 38,
#  'proposal': 3,
#  'protein': 15,
#  'radial': 19,
#  'random': 110,
#  'rank': 68,
#  'ranking': 46,
#  'rational': 14,
#  'rbf': 5,
#  'real': 50,
#  'recognition': 172,
#  'recording': 11,
#  'recovery': 37,
#  'recurrent': 111,
#  'reduction': 48,
#  'regression': 161,
#  'regularization': 77,
#  'regularized': 48,
#  'reinforcement': 158,
#  'relational': 26,
#  'relaxation': 34,
#  'representation': 142,
#  'resolution': 22,
#  'response': 42,
#  'return': 4,
#  'reward': 20,
#  'risk': 47,
#  'robot': 18,
#  'robust': 104,
#  'robustness': 16,
#  'rule': 54,
#  'safe': 12,
#  'sample': 75,
#  'sampling': 98,
#  'scalable': 42,
#  'scale': 99,
#  'scaling': 21,
#  'search': 88,
#  'second': 21,
#  'segmentation': 47,
#  'selection': 103,
#  'selective': 27,
#  'semantic': 23,
#  'semi': 75,
#  'sensing': 22,
#  'sensory': 18,
#  'separation': 36,
#  'sequential': 50,
#  'sery': 35,
#  'set': 54,
#  'setting': 12,
#  'sgd': 7,
#  'short': 18,
#  'shot': 12,
#  'signal': 58,
#  'silicon': 22,
#  'similarity': 36,
#  'simple': 29,
#  'simulation': 24,
#  'single': 49,
#  'size': 23,
#  'slow': 9,
#  'smooth': 18,
#  'solving': 19,
#  'sound': 23,
#  'source': 35,
#  'space': 93,
#  'sparse': 222,
#  'sparsity': 33,
#  'spatial': 36,
#  'specific': 14,
#  'spectral': 80,
#  'speech': 80,
#  'spike': 77,
#  'spiking': 59,
#  'stable': 17,
#  'state': 75,
#  'statistic': 30,
#  'statistical': 85,
#  'stimulus': 18,
#  'stochastic': 193,
#  'strategic': 10,
#  'strategy': 21,
#  'streaming': 17,
#  'string': 7,
#  'structural': 27,
#  'structure': 116,
#  'structured': 107,
#  'study': 26,
#  'submodular': 51,
#  'subset': 9,
#  'subspace': 31,
#  'supervised': 104,
#  'supervision': 7,
#  'support': 73,
#  'surface': 13,
#  'symmetric': 17,
#  'system': 145,
#  'task': 73,
#  'technique': 24,
#  'template': 10,
#  'temporal': 77,
#  'tensor': 41,
#  'term': 19,
#  'testing': 20,
#  'theoretical': 12,
#  'theory': 71,
#  'thompson': 7,
#  'tight': 12,
#  'time': 201,
#  'timing': 20,
#  'topic': 33,
#  'tracking': 36,
#  'tractable': 10,
#  'training': 112,
#  'transfer': 30,
#  'transformation': 25,
#  'tree': 52,
#  'trees': 52,
#  'tuned': 3,
#  'uncertainty': 22,
#  'unified': 23,
#  'unit': 23,
#  'unknown': 20,
#  'unlabeled': 18,
#  'variable': 79,
#  'variational': 121,
#  'vector': 99,
#  'video': 24,
#  'visual': 153,
#  'vlsi': 60,
#  'walk': 12,
#  'weight': 41,
#  'weighted': 25,
#  'winner': 13,
#  'wolfe': 8,
#  'word': 22}

# %%
for year in data:
    words = year['keywords']['buckets']
    
    #creating csv lines
    for word in words:
        bg_prop = cnt_keywords[word['key']]/tot_num_docs
        fg_prop = word['doc_count']/year['doc_count']
        line = {
            'score': fg_prop/bg_prop,
            'bg_prop': bg_prop,
            'fg_prop': fg_prop,
            'total_docs_year': year['doc_count'],
            'doc_count': word['doc_count'],
            'year': year['key'],
            'keyword': word['key']
        }
        sig_list.append(line)
        
        
with open('sig_terms_res_v2.csv', 'w', newline='') as f:
    header_present = False
    for doc in sig_list:
        if not header_present:
            w = csv.DictWriter(f, doc.keys())
            w.writeheader()
            header_present = True
        w.writerow(doc)
